# %% [markdown]
# <a href="https://colab.research.google.com/github/micah-shull/AI_Agents/blob/main/376_Governance%26ComplianceOrchestrator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📘 **Governance & Compliance Orchestrator — Introduction**
#
# ## **What This Agent Is**
#
# The **Governance & Compliance Orchestrator** is the oversight layer of an organization’s AI ecosystem.
# While other agents execute missions, automate workflows, and support employees, this orchestrator ensures that every AI system operates:
#
# * safely
# * ethically
# * transparently
# * in compliance with regulations
# * aligned with organizational policies
#
# It continuously monitors agent actions, data flows, reasoning traces, model outputs, and human approvals to detect:
#
# * policy violations
# * bias patterns
# * security risks
# * drift or degradation
# * anomalies in decision-making
# * compliance gaps
#
# This agent is the **air traffic controller** and **audit engine** for all AI activity inside the enterprise.
#
# ---
#
# ## ⭐ **Why This Agent Is Valuable for Companies**
#
# AI adoption is accelerating, but governance concerns are the single biggest blocker for executives.
# Companies fear:
#
# * regulatory penalties
# * data breaches
# * biased model behavior
# * hallucinations causing reputational damage
# * employees misusing AI
# * litigation risk
# * unpredictable outputs in high-stakes workflows
#
# The Governance & Compliance Orchestrator directly addresses these challenges.
#
# ### **1. Ensures AI Systems Follow Policies and Regulations**
#
# It enforces rules from:
#
# * the EU AI Act
# * NIST AI Risk Management Framework
# * industry-specific regulations (HIPAA, FINRA, GDPR)
# * internal AI usage policies
#
# This protects the business from fines, lawsuits, and trust breakdowns.
#
# ### **2. Creates Transparency and Auditability**
#
# Executives and auditors need answers to questions like:
#
# * “Why did the agent make this decision?”
# * “What data was used?”
# * “Was a human involved?”
# * “What were the alternatives?”
#
# The orchestrator provides full decision traces.
#
# ### **3. Detects Bias and Unfairness Before It Reaches Customers**
#
# By monitoring model behavior across populations, it can detect:
#
# * disparate impact
# * discriminatory outcomes
# * skewed training data
# * unsafe edge cases
#
# This is essential for ethical AI deployment.
#
# ### **4. Prevents System Failures and Model Drift**
#
# It identifies:
#
# * performance degradation
# * invalid inputs
# * risk accumulation
# * environment changes
# * integration failures
#
# This enables proactive correction rather than reactive crisis management.
#
# ### **5. Increases Leadership Confidence in AI Initiatives**
#
# Executives become far more willing to scale AI when a governance layer is in place.
#
# ### **6. Creates a Single Source of Truth for AI Oversight**
#
# Legal, compliance, security, and engineering teams all rely on this orchestrator for clarity.
#
# ---
#
# ## 🚀 **Why You Should Learn to Build It**
#
# This agent builds one of the rarest and most valuable skill sets in AI today:
# **the ability to design safe, auditable, trustworthy AI systems.**
#
# ### **1. You learn how to encode policies into machine-readable rules**
#
# This includes:
#
# * rule-based governance engines
# * policy translation
# * constraint modeling
# * risk scoring
#
# This is advanced, high-impact AI engineering.
#
# ### **2. You develop expertise in AI observability**
#
# You’ll build systems for:
#
# * monitoring outputs
# * tracking agent actions
# * capturing reasoning traces
# * visualizing decision paths
#
# This is a cutting-edge discipline in AI operations.
#
# ### **3. You practice designing safeguards and fallback mechanisms**
#
# This means:
#
# * human approval logic
# * auto-escalation workflows
# * anomaly detection
# * safe-mode policies
#
# These are essential for enterprise adoption.
#
# ### **4. You learn how to comply with modern AI regulations**
#
# This is a future-proof skill as governments increase oversight of AI.
#
# ### **5. You build infrastructure that every other orchestrator depends on**
#
# Your governance layer will integrate with:
#
# * Mission Orchestrators
# * Experimentation Systems
# * Sales Agents
# * Workforce Agents
# * Integration Monitors
#
# It becomes the backbone for responsible scaling.
#
# ### **6. You become a trusted advisor to executives**
#
# Leaders urgently need people who understand:
#
# * risk
# * ethics
# * policy
# * safety engineering
#
# Mastering this agent positions you for AI governance leadership roles.
#
# ---
#
# ## 🌟 Summary
#
# The **Governance & Compliance Orchestrator** is the foundation of safe, responsible, and scalable AI deployment in the enterprise.
# It monitors all agent activity, enforces policy constraints, detects bias and risk, provides full auditability, and ensures compliance with industry regulations.

# %% [markdown]
# ## 1️⃣ What an MVP Governance Agent Actually Needs (Reality Check)
#
# For an MVP, you **do not** need:
#
# * Real regulations in full legal complexity
# * Real user data
# * Perfect bias math
# * Production-scale logging
#
# You **do** need:
#
# * Structured agent activity logs
# * Clear policies expressed as rules
# * Simulated violations, drift, and risk events
# * Deterministic outputs you can reason about and test
#
# So we’ll use **synthetic but realistic data**.
#
# ---
#
# ## 2️⃣ Core Data Types Your MVP Should Ingest
#
# Your orchestrator should operate over **events**, not raw models.
#
# ### 🔹 A. Agent Action Logs (Primary Input)
#
# This is the backbone.
#
# ```json
# {
#   "event_id": "evt_10291",
#   "timestamp": "2026-01-02T14:32:11Z",
#   "agent_name": "SalesEnablementAgent",
#   "action_type": "recommendation_generated",
#   "input_data": {
#     "customer_segment": "SMB",
#     "region": "EU",
#     "deal_size": 120000
#   },
#   "output": {
#     "recommendation": "Offer 25% discount to close deal quickly"
#   },
#   "model": "gpt-4.1",
#   "confidence_score": 0.42,
#   "human_in_the_loop": false,
#   "data_sources": ["CRM", "SalesForecast_v3"]
# }
# ```
#
# ✅ What you can test:
#
# * Missing human approval
# * Low confidence outputs
# * High-risk regions (EU)
# * Sensitive decisions (pricing)
#
# ---
#
# ### 🔹 B. Policy Rules (Machine-Readable)
#
# Start simple. JSON or YAML is perfect.
#
# ```json
# {
#   "policy_id": "EU_HIGH_RISK_DECISIONS",
#   "description": "High-risk decisions in the EU require human approval",
#   "conditions": {
#     "region": "EU",
#     "action_type": ["recommendation_generated", "decision_made"],
#     "confidence_score_lt": 0.6
#   },
#   "required_action": "human_approval",
#   "severity": "high"
# }
# ```
#
# ✅ What you can test:
#
# * Rule matching
# * Violations
# * Escalation logic
#
# ---
#
# ### 🔹 C. Risk & Compliance Events (Derived Output)
#
# Your agent should **emit** these.
#
# ```json
# {
#   "compliance_event_id": "cmp_8812",
#   "event_id": "evt_10291",
#   "risk_type": "policy_violation",
#   "policy_id": "EU_HIGH_RISK_DECISIONS",
#   "severity": "high",
#   "status": "open",
#   "recommended_action": "Escalate to compliance officer",
#   "timestamp": "2026-01-02T14:32:12Z"
# }
# ```
#
# This becomes your **audit trail**.
#
# ---
#
# ## 3️⃣ Synthetic Test Scenarios (Very Important)
#
# You want **intentional failures**, not just happy paths.
#
# ### Scenario Set 1 — Policy Violations
#
# * EU decision without human approval
# * Financial recommendation with low confidence
# * HR decision referencing protected attributes
#
# ### Scenario Set 2 — Bias Signals
#
# ```json
# {
#   "decision_type": "loan_approval",
#   "group": "Group A",
#   "approval_rate": 0.82
# },
# {
#   "decision_type": "loan_approval",
#   "group": "Group B",
#   "approval_rate": 0.61
# }
# ```
#
# Your agent doesn’t need perfect fairness math —
# just **detect statistically suspicious deltas** and flag them.
#
# ---
#
# ### Scenario Set 3 — Drift & Degradation
#
# ```json
# {
#   "model": "CustomerSupportAgent_v2",
#   "metric": "hallucination_rate",
#   "previous_avg": 0.03,
#   "current_avg": 0.11,
#   "threshold": 0.08
# }
# ```
#
# Expected behavior:
#
# * Detect drift
# * Raise warning
# * Recommend rollback or human review
#
# ---
#
# ## 4️⃣ MVP Architecture (Cursor-Friendly)
#
# Here’s a **clean MVP loop** you can implement fast:
#
# ```text
# [Agent Logs]
#       ↓
# [Policy Engine]
#       ↓
# [Risk Scoring]
#       ↓
# [Violation Detection]
#       ↓
# [Audit Log + Alerts]
#       ↓
# (Optional) LLM Summary
# ```
#
# 💡 Important:
# **LLMs explain — rules decide.**
# This aligns perfectly with your philosophy.

# %% [markdown]
# # Data Proposal Review - Governance & Compliance Orchestrator MVP
#
# ## ✅ Overall Assessment
#
# Your data proposal is **excellent for an MVP**. It's focused, practical, and aligns perfectly with the "MVP First, LLM Later" philosophy.
#
# ---
#
# ## 📋 Data Proposal Strengths
#
# ### 1. **Agent Action Logs Structure** ✅
# The JSON structure you proposed is solid:
# - ✅ Has all essential fields (event_id, timestamp, agent_name, action_type, input/output)
# - ✅ Includes confidence_score (critical for risk assessment)
# - ✅ Includes human_in_the_loop flag (essential for compliance)
# - ✅ Includes data_sources (important for auditability)
#
# **Recommendation:** Keep this structure. It's perfect for MVP.
#
# ### 2. **Policy Rules Structure** ✅
# Simple JSON/YAML approach is correct:
# - ✅ Conditions are clear and testable
# - ✅ Required actions are explicit
# - ✅ Severity levels are defined
#
# **Recommendation:** Start with 3-5 simple policies for MVP:
# - EU high-risk decisions require approval
# - Low confidence outputs require review
# - Financial decisions require human approval
# - Protected attributes cannot be used in HR decisions
#
# ### 3. **Risk & Compliance Events** ✅
# This is the perfect output structure:
# - ✅ Links back to original event (event_id)
# - ✅ Includes policy_id (for traceability)
# - ✅ Has severity and status
# - ✅ Includes recommended_action
#
# **Recommendation:** This becomes your audit trail. Perfect as-is.
#
# ---
#
# ## 🎯 MVP Architecture Recommendation
#
# Based on your data proposal and the codebase patterns, here's the MVP workflow:
#
# ```
# [Agent Action Logs] → [Policy Engine] → [Risk Scoring] → [Violation Detection] → [Audit Log + Alerts] → [Report]
# ```
#
# ### Phase 1: Foundation (Rule-Based MVP)
# 1. **Goal Node** - Define governance objective
# 2. **Planning Node** - Create execution plan
# 3. **Data Loading Node** - Load agent logs and policies
# 4. **Policy Evaluation Node** - Match events to policies
# 5. **Risk Scoring Node** - Calculate risk scores
# 6. **Violation Detection Node** - Identify violations
# 7. **Report Generation Node** - Generate audit report
#
# ### Phase 2: Enhancement (Later)
# - LLM-powered explanations for violations
# - Bias detection algorithms
# - Drift detection
# - Pattern analysis
#
# ---
#
# ## 📊 Data Format Recommendation
#
# **Answer to your question:** Use **JSON** for the test data.
#
# **Why:**
# - ✅ Matches your proposed structure exactly
# - ✅ Easy to load in Python (`json.load()`)
# - ✅ Easy to iterate and test
# - ✅ Can be converted to CSV later if needed for analysis
# - ✅ Supports nested structures (input_data, output)
#
# **Suggested File Structure:**
# ```
# agents/governance_compliance_orchestrator/
# ├── data/
# │   ├── agent_action_logs.json      # 100-500 events with embedded violations
# │   ├── policy_rules.json           # 3-5 simple policies
# │   └── test_scenarios.json         # Intentional failure scenarios
# ```
#
# ---
#
# ## 🔍 Test Scenarios to Include
#
# Your proposal mentions three scenario sets. Here's what to include:
#
# ### Scenario Set 1: Policy Violations ✅
# - EU decision without human approval (high severity)
# - Financial recommendation with low confidence (medium severity)
# - HR decision referencing protected attributes (high severity)
#
# ### Scenario Set 2: Bias Signals ✅
# - Approval rate disparities between groups
# - Keep it simple: flag if delta > 20% (statistically suspicious)
#
# ### Scenario Set 3: Drift & Degradation ✅
# - Model performance degradation
# - Hallucination rate increase
# - Confidence score decline
#
# ---
#
# ## 🚀 Next Steps
#
# 1. **Generate Test Data** (JSON format)
#    - 100-500 agent action log events
#    - 3-5 policy rules
#    - Embedded violations in ~20% of events
#    - Include all three scenario types
#
# 2. **Build MVP Structure**
#    - Create agent folder structure
#    - Design state schema
#    - Build foundation nodes
#    - Build utilities (policy matching, risk scoring)
#
# 3. **Test Incrementally**
#    - Test data loading first
#    - Test policy matching
#    - Test violation detection
#    - Test report generation
#
# ---
#
# ## 💡 MVP Simplifications
#
# For learning the architecture, you can simplify:
#
# 1. **Policies:** Start with 3-5 simple rules (not full EU AI Act)
# 2. **Bias Detection:** Simple statistical deltas (not complex fairness math)
# 3. **Drift Detection:** Simple threshold comparisons (not ML-based)
# 4. **No Real Regulations:** Use synthetic but realistic policy names
#
# **This is perfect for learning.** You can add complexity later.
#
# ---
#
# ## ✅ Ready to Build?
#
# Your data proposal is **ready to commit**. The structure is:
# - ✅ Focused on MVP essentials
# - ✅ Realistic enough to learn from
# - ✅ Simple enough to build quickly
# - ✅ Extensible for future enhancements
#
# **Recommendation:** Proceed with generating the JSON test data, then we'll build the MVP structure following the orchestrator patterns.

# %% [markdown]
# # policy_rules.json

# %%
[
  {
    "policy_id": "EU_HIGH_RISK_REQUIRES_APPROVAL",
    "description": "High-risk decisions affecting EU entities require human approval.",
    "conditions": {
      "region": "EU",
      "action_type": [
        "recommendation_generated",
        "decision_made"
      ],
      "confidence_score_lt": 0.6
    },
    "required_action": "human_approval",
    "severity": "high"
  },
  {
    "policy_id": "LOW_CONFIDENCE_REQUIRES_REVIEW",
    "description": "Any AI output with low confidence must be reviewed by a human.",
    "conditions": {
      "confidence_score_lt": 0.5
    },
    "required_action": "human_review",
    "severity": "medium"
  },
  {
    "policy_id": "FINANCIAL_DECISIONS_REQUIRE_HUMAN",
    "description": "Financial recommendations above threshold require human approval.",
    "conditions": {
      "action_type": [
        "pricing_recommendation",
        "financial_decision"
      ],
      "deal_size_gt": 100000
    },
    "required_action": "human_approval",
    "severity": "high"
  },
  {
    "policy_id": "PROTECTED_ATTRIBUTES_PROHIBITED",
    "description": "Protected attributes must not be used in HR-related decisions.",
    "conditions": {
      "action_type": [
        "hiring_decision",
        "promotion_decision"
      ],
      "input_contains_protected_attribute": true
    },
    "required_action": "block_and_escalate",
    "severity": "critical"
  },
  {
    "policy_id": "MODEL_EXPLANATION_REQUIRED",
    "description": "Decisions impacting users must include an explanation trace.",
    "conditions": {
      "action_type": [
        "decision_made"
      ],
      "explanation_missing": true
    },
    "required_action": "request_explanation",
    "severity": "low"
  }
]

# %% [markdown]
# # agent_action_logs_batch_1.json

# %%
[
  {
    "event_id": "evt_0001",
    "timestamp": "2026-01-02T09:05:12Z",
    "agent_name": "SalesEnablementAgent",
    "action_type": "pricing_recommendation",
    "input_data": {
      "customer_segment": "SMB",
      "region": "US",
      "deal_size": 85000
    },
    "output": {
      "recommendation": "Offer a 10% discount to accelerate close"
    },
    "model": "gpt-4.1",
    "confidence_score": 0.78,
    "human_in_the_loop": false,
    "data_sources": ["CRM", "SalesForecast_v1"]
  },
  {
    "event_id": "evt_0002",
    "timestamp": "2026-01-02T09:11:44Z",
    "agent_name": "SalesEnablementAgent",
    "action_type": "pricing_recommendation",
    "input_data": {
      "customer_segment": "Enterprise",
      "region": "EU",
      "deal_size": 220000
    },
    "output": {
      "recommendation": "Offer a 25% discount to secure deal this quarter"
    },
    "model": "gpt-4.1",
    "confidence_score": 0.41,
    "human_in_the_loop": false,
    "data_sources": ["CRM", "SalesForecast_v3"]
  },
  {
    "event_id": "evt_0003",
    "timestamp": "2026-01-02T09:18:09Z",
    "agent_name": "CustomerSupportAgent",
    "action_type": "recommendation_generated",
    "input_data": {
      "ticket_type": "refund_request",
      "region": "EU",
      "customer_tenure_months": 2
    },
    "output": {
      "recommendation": "Deny refund due to short tenure"
    },
    "model": "gpt-4.1",
    "confidence_score": 0.55,
    "human_in_the_loop": false,
    "data_sources": ["SupportTickets", "RefundPolicy"]
  },
  {
    "event_id": "evt_0004",
    "timestamp": "2026-01-02T09:25:31Z",
    "agent_name": "HRDecisionAgent",
    "action_type": "hiring_decision",
    "input_data": {
      "candidate_id": "C-8841",
      "role": "Data Analyst",
      "years_experience": 3,
      "education": "BS Statistics",
      "gender": "female"
    },
    "output": {
      "decision": "Reject candidate"
    },
    "model": "gpt-4.1",
    "confidence_score": 0.67,
    "human_in_the_loop": true,
    "data_sources": ["HRIS", "ResumeParser"]
  },
  {
    "event_id": "evt_0005",
    "timestamp": "2026-01-02T09:32:18Z",
    "agent_name": "HRDecisionAgent",
    "action_type": "promotion_decision",
    "input_data": {
      "employee_id": "E-1932",
      "department": "Engineering",
      "performance_rating": 4.6,
      "age": 54
    },
    "output": {
      "decision": "Delay promotion"
    },
    "model": "gpt-4.1",
    "confidence_score": 0.62,
    "human_in_the_loop": false,
    "data_sources": ["HRIS", "PerformanceReviews"]
  },
  {
    "event_id": "evt_0006",
    "timestamp": "2026-01-02T09:39:42Z",
    "agent_name": "FinanceAgent",
    "action_type": "financial_decision",
    "input_data": {
      "region": "US",
      "deal_size": 150000,
      "payment_terms": "Net 60"
    },
    "output": {
      "decision": "Approve extended payment terms"
    },
    "model": "gpt-4.1",
    "confidence_score": 0.73,
    "human_in_the_loop": false,
    "data_sources": ["FinanceSystem", "CreditRiskModel"]
  },
  {
    "event_id": "evt_0007",
    "timestamp": "2026-01-02T09:46:55Z",
    "agent_name": "CustomerSupportAgent",
    "action_type": "decision_made",
    "input_data": {
      "ticket_type": "account_suspension",
      "region": "US",
      "violation_count": 3
    },
    "output": {
      "decision": "Suspend account for 14 days"
    },
    "model": "gpt-4.1",
    "confidence_score": 0.81,
    "human_in_the_loop": false,
    "data_sources": ["SupportTickets", "AbusePolicy"]
  },
  {
    "event_id": "evt_0008",
    "timestamp": "2026-01-02T09:53:27Z",
    "agent_name": "CustomerSupportAgent",
    "action_type": "decision_made",
    "input_data": {
      "ticket_type": "account_suspension",
      "region": "EU",
      "violation_count": 1
    },
    "output": {
      "decision": "Suspend account permanently"
    },
    "model": "gpt-4.1",
    "confidence_score": 0.44,
    "human_in_the_loop": false,
    "data_sources": ["SupportTickets", "AbusePolicy"]
  },
  {
    "event_id": "evt_0009",
    "timestamp": "2026-01-02T10:01:10Z",
    "agent_name": "MarketingAgent",
    "action_type": "recommendation_generated",
    "input_data": {
      "campaign_type": "email",
      "target_region": "EU",
      "audience_size": 120000
    },
    "output": {
      "recommendation": "Reuse prior customer email list"
    },
    "model": "gpt-4.1",
    "confidence_score": 0.58,
    "human_in_the_loop": true,
    "data_sources": ["CRM", "CampaignHistory"]
  },
  {
    "event_id": "evt_0010",
    "timestamp": "2026-01-02T10:07:44Z",
    "agent_name": "SalesEnablementAgent",
    "action_type": "pricing_recommendation",
    "input_data": {
      "customer_segment": "Enterprise",
      "region": "EU",
      "deal_size": 310000
    },
    "output": {
      "recommendation": "Offer custom pricing with 30% discount"
    },
    "model": "gpt-4.1",
    "confidence_score": 0.49,
    "human_in_the_loop": true,
    "data_sources": ["CRM", "SalesForecast_v3"]
  },
  {
    "event_id": "evt_0011",
    "timestamp": "2026-01-02T10:15:02Z",
    "agent_name": "HRDecisionAgent",
    "action_type": "hiring_decision",
    "input_data": {
      "candidate_id": "C-8912",
      "role": "Product Manager",
      "years_experience": 6,
      "education": "MBA"
    },
    "output": {
      "decision": "Advance to final interview"
    },
    "model": "gpt-4.1",
    "confidence_score": 0.88,
    "human_in_the_loop": true,
    "data_sources": ["HRIS", "ResumeParser"]
  },
  {
    "event_id": "evt_0012",
    "timestamp": "2026-01-02T10:22:39Z",
    "agent_name": "FinanceAgent",
    "action_type": "financial_decision",
    "input_data": {
      "region": "EU",
      "deal_size": 480000,
      "payment_terms": "Net 90"
    },
    "output": {
      "decision": "Approve extended payment terms"
    },
    "model": "gpt-4.1",
    "confidence_score": 0.46,
    "human_in_the_loop": false,
    "data_sources": ["FinanceSystem", "CreditRiskModel"]
  }
]

# %% [markdown]
# # agent_action_logs_batch_2.json

# %%
[
  {
    "event_id": "evt_0013",
    "timestamp": "2026-01-02T10:31:18Z",
    "agent_name": "SalesEnablementAgent",
    "action_type": "pricing_recommendation",
    "input_data": {
      "customer_segment": "Mid-Market",
      "region": "EU",
      "deal_size": 105000
    },
    "output": {
      "recommendation": "Offer a 15% discount to remain competitive"
    },
    "model": "gpt-4.1",
    "confidence_score": 0.61,
    "human_in_the_loop": false,
    "data_sources": ["CRM", "SalesForecast_v2"]
  },
  {
    "event_id": "evt_0014",
    "timestamp": "2026-01-02T10:38:46Z",
    "agent_name": "CustomerSupportAgent",
    "action_type": "decision_made",
    "input_data": {
      "ticket_type": "refund_request",
      "region": "US",
      "customer_tenure_months": 1
    },
    "output": {
      "decision": "Approve refund as goodwill gesture"
    },
    "model": "gpt-4.1",
    "confidence_score": 0.52,
    "human_in_the_loop": false,
    "data_sources": ["SupportTickets", "RefundPolicy"]
  },
  {
    "event_id": "evt_0015",
    "timestamp": "2026-01-02T10:45:02Z",
    "agent_name": "HRDecisionAgent",
    "action_type": "promotion_decision",
    "input_data": {
      "employee_id": "E-2044",
      "department": "Sales",
      "performance_rating": 4.9,
      "years_at_company": 7
    },
    "output": {
      "decision": "Approve promotion"
    },
    "model": "gpt-4.1",
    "confidence_score": 0.91,
    "human_in_the_loop": true,
    "data_sources": ["HRIS", "PerformanceReviews"]
  },
  {
    "event_id": "evt_0016",
    "timestamp": "2026-01-02T10:51:37Z",
    "agent_name": "FinanceAgent",
    "action_type": "financial_decision",
    "input_data": {
      "region": "US",
      "deal_size": 99000,
      "payment_terms": "Net 45"
    },
    "output": {
      "decision": "Approve payment terms"
    },
    "model": "gpt-4.1",
    "confidence_score": 0.77,
    "human_in_the_loop": false,
    "data_sources": ["FinanceSystem", "CreditRiskModel"]
  },
  {
    "event_id": "evt_0017",
    "timestamp": "2026-01-02T10:58:20Z",
    "agent_name": "CustomerSupportAgent",
    "action_type": "recommendation_generated",
    "input_data": {
      "ticket_type": "account_closure",
      "region": "EU",
      "reason": "suspected fraud"
    },
    "output": {
      "recommendation": "Close account immediately"
    },
    "model": "gpt-4.1",
    "confidence_score": 0.59,
    "human_in_the_loop": false,
    "data_sources": ["SupportTickets", "FraudSignals"]
  },
  {
    "event_id": "evt_0018",
    "timestamp": "2026-01-02T11:05:41Z",
    "agent_name": "MarketingAgent",
    "action_type": "recommendation_generated",
    "input_data": {
      "campaign_type": "ad_targeting",
      "target_region": "US",
      "audience_attributes": ["location", "income_bracket"]
    },
    "output": {
      "recommendation": "Target high-income zip codes"
    },
    "model": "gpt-4.1",
    "confidence_score": 0.64,
    "human_in_the_loop": false,
    "data_sources": ["AdPlatform", "DemographicsDB"]
  },
  {
    "event_id": "evt_0019",
    "timestamp": "2026-01-02T11:12:03Z",
    "agent_name": "HRDecisionAgent",
    "action_type": "hiring_decision",
    "input_data": {
      "candidate_id": "C-9033",
      "role": "UX Designer",
      "years_experience": 4,
      "education": "BA Design"
    },
    "output": {
      "decision": "Advance to technical interview"
    },
    "model": "gpt-4.1",
    "confidence_score": 0.74,
    "human_in_the_loop": false,
    "data_sources": ["HRIS", "ResumeParser"]
  },
  {
    "event_id": "evt_0020",
    "timestamp": "2026-01-02T11:19:26Z",
    "agent_name": "FinanceAgent",
    "action_type": "financial_decision",
    "input_data": {
      "region": "EU",
      "deal_size": 180000,
      "payment_terms": "Net 60"
    },
    "output": {
      "decision": "Approve extended payment terms"
    },
    "model": "gpt-4.1",
    "confidence_score": 0.54,
    "human_in_the_loop": true,
    "data_sources": ["FinanceSystem", "CreditRiskModel"]
  },
  {
    "event_id": "evt_0021",
    "timestamp": "2026-01-02T11:26:49Z",
    "agent_name": "CustomerSupportAgent",
    "action_type": "decision_made",
    "input_data": {
      "ticket_type": "content_moderation",
      "region": "US",
      "flag_count": 5
    },
    "output": {
      "decision": "Remove content and warn user"
    },
    "model": "gpt-4.1",
    "confidence_score": 0.83,
    "human_in_the_loop": false,
    "data_sources": ["ModerationQueue", "CommunityGuidelines"]
  },
  {
    "event_id": "evt_0022",
    "timestamp": "2026-01-02T11:34:12Z",
    "agent_name": "SalesEnablementAgent",
    "action_type": "pricing_recommendation",
    "input_data": {
      "customer_segment": "Enterprise",
      "region": "EU",
      "deal_size": 275000
    },
    "output": {
      "recommendation": "Offer limited-time incentive pricing"
    },
    "model": "gpt-4.1",
    "confidence_score": 0.57,
    "human_in_the_loop": false,
    "data_sources": ["CRM", "SalesForecast_v3"]
  }
]

# %% [markdown]
# # agent_action_logs_batch_3.json

# %%
[
    {
      "event_id": "evt_0023",
      "timestamp": "2026-01-02T11:41:55Z",
      "agent_name": "SalesEnablementAgent",
      "action_type": "pricing_recommendation",
      "input_data": {
        "customer_segment": "SMB",
        "region": "EU",
        "deal_size": 95000
      },
      "output": {
        "recommendation": "Offer standard pricing with flexible onboarding"
      },
      "model": "gpt-4.1",
      "confidence_score": 0.72,
      "human_in_the_loop": false,
      "data_sources": ["CRM", "SalesForecast_v2"]
    },
    {
      "event_id": "evt_0024",
      "timestamp": "2026-01-02T11:49:08Z",
      "agent_name": "FinanceAgent",
      "action_type": "financial_decision",
      "input_data": {
        "region": "EU",
        "deal_size": 260000,
        "payment_terms": "Net 90"
      },
      "output": {
        "decision": "Approve extended payment terms"
      },
      "model": "gpt-4.1",
      "confidence_score": 0.58,
      "human_in_the_loop": false,
      "data_sources": ["FinanceSystem", "CreditRiskModel"]
    },
    {
      "event_id": "evt_0025",
      "timestamp": "2026-01-02T11:56:33Z",
      "agent_name": "CustomerSupportAgent",
      "action_type": "decision_made",
      "input_data": {
        "ticket_type": "refund_request",
        "region": "EU",
        "customer_tenure_months": 10
      },
      "output": {
        "decision": "Approve partial refund"
      },
      "model": "gpt-4.1",
      "confidence_score": 0.47,
      "human_in_the_loop": false,
      "data_sources": ["SupportTickets", "RefundPolicy"]
    },
    {
      "event_id": "evt_0026",
      "timestamp": "2026-01-02T12:03:41Z",
      "agent_name": "HRDecisionAgent",
      "action_type": "promotion_decision",
      "input_data": {
        "employee_id": "E-2211",
        "department": "Marketing",
        "performance_rating": 4.2,
        "years_at_company": 2
      },
      "output": {
        "decision": "Delay promotion pending further review"
      },
      "model": "gpt-4.1",
      "confidence_score": 0.56,
      "human_in_the_loop": false,
      "data_sources": ["HRIS", "PerformanceReviews"]
    },
    {
      "event_id": "evt_0027",
      "timestamp": "2026-01-02T12:10:57Z",
      "agent_name": "CustomerSupportAgent",
      "action_type": "recommendation_generated",
      "input_data": {
        "ticket_type": "account_closure",
        "region": "US",
        "reason": "policy violations"
      },
      "output": {
        "recommendation": "Close account after final warning"
      },
      "model": "gpt-4.1",
      "confidence_score": 0.66,
      "human_in_the_loop": true,
      "data_sources": ["SupportTickets", "AbusePolicy"]
    },
    {
      "event_id": "evt_0028",
      "timestamp": "2026-01-02T12:18:29Z",
      "agent_name": "MarketingAgent",
      "action_type": "recommendation_generated",
      "input_data": {
        "campaign_type": "ad_targeting",
        "target_region": "EU",
        "audience_attributes": ["location", "age_range"]
      },
      "output": {
        "recommendation": "Target users aged 50+ in selected regions"
      },
      "model": "gpt-4.1",
      "confidence_score": 0.53,
      "human_in_the_loop": false,
      "data_sources": ["AdPlatform", "DemographicsDB"]
    },
    {
      "event_id": "evt_0029",
      "timestamp": "2026-01-02T12:26:02Z",
      "agent_name": "SalesEnablementAgent",
      "action_type": "pricing_recommendation",
      "input_data": {
        "customer_segment": "Enterprise",
        "region": "US",
        "deal_size": 420000
      },
      "output": {
        "recommendation": "Offer custom enterprise pricing"
      },
      "model": "gpt-4.1",
      "confidence_score": 0.84,
      "human_in_the_loop": true,
      "data_sources": ["CRM", "SalesForecast_v4"]
    },
    {
      "event_id": "evt_0030",
      "timestamp": "2026-01-02T12:33:44Z",
      "agent_name": "FinanceAgent",
      "action_type": "financial_decision",
      "input_data": {
        "region": "US",
        "deal_size": 305000,
        "payment_terms": "Net 30"
      },
      "output": {
        "decision": "Approve payment terms"
      },
      "model": "gpt-4.1",
      "confidence_score": 0.79,
      "human_in_the_loop": true,
      "data_sources": ["FinanceSystem", "CreditRiskModel"]
    },
    {
      "event_id": "evt_0031",
      "timestamp": "2026-01-02T12:41:19Z",
      "agent_name": "HRDecisionAgent",
      "action_type": "hiring_decision",
      "input_data": {
        "candidate_id": "C-9199",
        "role": "Operations Manager",
        "years_experience": 9,
        "education": "BA Business"
      },
      "output": {
        "decision": "Hire candidate"
      },
      "model": "gpt-4.1",
      "confidence_score": 0.93,
      "human_in_the_loop": true,
      "data_sources": ["HRIS", "ResumeParser"]
    },
    {
      "event_id": "evt_0032",
      "timestamp": "2026-01-02T12:48:58Z",
      "agent_name": "CustomerSupportAgent",
      "action_type": "decision_made",
      "input_data": {
        "ticket_type": "content_moderation",
        "region": "EU",
        "flag_count": 2
      },
      "output": {
        "decision": "Leave content unchanged"
      },
      "model": "gpt-4.1",
      "confidence_score": 0.51,
      "human_in_the_loop": false,
      "data_sources": ["ModerationQueue", "CommunityGuidelines"]
    }
  ]

# %% [markdown]
# # bias_signals.json

# %%
{
  "generated_at": "2026-01-02T13:00:00Z",
  "window": "30_days",
  "bias_signals": [
    {
      "signal_id": "bias_001",
      "agent_name": "HRDecisionAgent",
      "decision_type": "hiring_decision",
      "protected_attribute": "gender",
      "groups": [
        {
          "group": "female",
          "total_candidates": 48,
          "approved": 14,
          "approval_rate": 0.29
        },
        {
          "group": "male",
          "total_candidates": 52,
          "approved": 31,
          "approval_rate": 0.60
        }
      ],
      "delta": 0.31,
      "threshold": 0.20,
      "risk_level": "high",
      "recommended_action": "Initiate bias audit and require human review for future decisions"
    },
    {
      "signal_id": "bias_002",
      "agent_name": "FinanceAgent",
      "decision_type": "financial_decision",
      "protected_attribute": "region",
      "groups": [
        {
          "group": "EU",
          "total_requests": 36,
          "approved": 18,
          "approval_rate": 0.50
        },
        {
          "group": "US",
          "total_requests": 41,
          "approved": 31,
          "approval_rate": 0.76
        }
      ],
      "delta": 0.26,
      "threshold": 0.20,
      "risk_level": "medium",
      "recommended_action": "Monitor trend and require justification logs for EU decisions"
    },
    {
      "signal_id": "bias_003",
      "agent_name": "CustomerSupportAgent",
      "decision_type": "account_suspension",
      "protected_attribute": "region",
      "groups": [
        {
          "group": "EU",
          "total_cases": 22,
          "suspended": 14,
          "suspension_rate": 0.64
        },
        {
          "group": "US",
          "total_cases": 29,
          "suspended": 10,
          "suspension_rate": 0.34
        }
      ],
      "delta": 0.30,
      "threshold": 0.25,
      "risk_level": "high",
      "recommended_action": "Escalate to compliance and perform policy alignment review"
    },
    {
      "signal_id": "bias_004",
      "agent_name": "MarketingAgent",
      "decision_type": "ad_targeting",
      "protected_attribute": "age_range",
      "groups": [
        {
          "group": "18-34",
          "exposure_rate": 0.22
        },
        {
          "group": "35-49",
          "exposure_rate": 0.41
        },
        {
          "group": "50+",
          "exposure_rate": 0.73
        }
      ],
      "delta": 0.51,
      "threshold": 0.30,
      "risk_level": "critical",
      "recommended_action": "Block targeting strategy and require ethics review"
    }
  ]
}

# %% [markdown]
# # drift_and_degradation_signals.json

# %%
{
  "generated_at": "2026-01-02T13:15:00Z",
  "monitoring_window": "14_days",
  "drift_signals": [
    {
      "signal_id": "drift_001",
      "agent_name": "CustomerSupportAgent",
      "model": "gpt-4.1",
      "metric": "hallucination_rate",
      "previous_average": 0.03,
      "current_average": 0.11,
      "threshold": 0.08,
      "delta": 0.08,
      "risk_level": "high",
      "detected_at": "2026-01-02T12:55:00Z",
      "recommended_action": "Escalate to engineering and restrict autonomous decisions"
    },
    {
      "signal_id": "drift_002",
      "agent_name": "SalesEnablementAgent",
      "model": "gpt-4.1",
      "metric": "average_confidence_score",
      "previous_average": 0.74,
      "current_average": 0.58,
      "threshold": 0.60,
      "delta": -0.16,
      "risk_level": "medium",
      "detected_at": "2026-01-02T12:57:00Z",
      "recommended_action": "Require human approval for pricing recommendations"
    },
    {
      "signal_id": "drift_003",
      "agent_name": "FinanceAgent",
      "model": "gpt-4.1",
      "metric": "policy_violation_rate",
      "previous_average": 0.04,
      "current_average": 0.13,
      "threshold": 0.10,
      "delta": 0.09,
      "risk_level": "high",
      "detected_at": "2026-01-02T12:59:00Z",
      "recommended_action": "Trigger compliance review and temporary approval gate"
    },
    {
      "signal_id": "drift_004",
      "agent_name": "HRDecisionAgent",
      "model": "gpt-4.1",
      "metric": "decision_override_rate",
      "previous_average": 0.18,
      "current_average": 0.37,
      "threshold": 0.30,
      "delta": 0.19,
      "risk_level": "medium",
      "detected_at": "2026-01-02T13:01:00Z",
      "recommended_action": "Investigate model alignment and retraining data"
    },
    {
      "signal_id": "drift_005",
      "agent_name": "MarketingAgent",
      "model": "gpt-4.1",
      "metric": "ethics_flag_rate",
      "previous_average": 0.06,
      "current_average": 0.22,
      "threshold": 0.15,
      "delta": 0.16,
      "risk_level": "critical",
      "detected_at": "2026-01-02T13:03:00Z",
      "recommended_action": "Disable autonomous targeting and require ethics approval"
    }
  ]
}

# %% [markdown]
# # Data Review - Governance & Compliance Orchestrator
#
# ## ✅ Overall Assessment
#
# **Excellent data quality!** The data is well-structured, realistic, and perfect for learning the MVP architecture. All files are ready to use.
#
# ---
#
# ## 📊 File-by-File Review
#
# ### 1. **policy_rules.json** ✅
# **Status:** Perfect for MVP
#
# **Structure:**
# - 5 policies covering key scenarios
# - Clear conditions (region, action_type, confidence thresholds, etc.)
# - Explicit required actions (human_approval, human_review, block_and_escalate)
# - Severity levels (low, medium, high, critical)
#
# **Policies Included:**
# 1. `EU_HIGH_RISK_REQUIRES_APPROVAL` - EU decisions with low confidence
# 2. `LOW_CONFIDENCE_REQUIRES_REVIEW` - Any low confidence output
# 3. `FINANCIAL_DECISIONS_REQUIRE_HUMAN` - Financial decisions > $100k
# 4. `PROTECTED_ATTRIBUTES_PROHIBITED` - HR decisions with protected attributes
# 5. `MODEL_EXPLANATION_REQUIRED` - Decisions missing explanations
#
# **Ready to use:** ✅
#
# ---
#
# ### 2. **agent_action_logs_batch_1.json** ✅
# **Status:** Excellent - Contains intentional violations
#
# **Structure:**
# - 12 events with complete metadata
# - All required fields present (event_id, timestamp, agent_name, action_type, etc.)
# - Embedded violations for testing
#
# **Sample Violations Detected:**
# - `evt_0002`: EU + low confidence (0.41) + no HITL → **Violates EU_HIGH_RISK_REQUIRES_APPROVAL**
# - `evt_0003`: EU + low confidence (0.55) + no HITL → **Violates EU_HIGH_RISK_REQUIRES_APPROVAL**
# - `evt_0004`: HR decision with `gender` attribute → **Violates PROTECTED_ATTRIBUTES_PROHIBITED**
# - `evt_0005`: HR decision with `age` attribute → **Violates PROTECTED_ATTRIBUTES_PROHIBITED**
# - `evt_0006`: Financial decision ($150k) + no HITL → **Violates FINANCIAL_DECISIONS_REQUIRE_HUMAN**
# - `evt_0008`: EU + low confidence (0.44) + no HITL → **Violates EU_HIGH_RISK_REQUIRES_APPROVAL**
# - `evt_0012`: EU + financial (\$480k) + low confidence (0.46) + no HITL → **Multiple violations**
#
# **Ready to use:** ✅
#
# ---
#
# ### 3. **agent_action_logs_batch_2.json** ✅
# **Status:** Good - Additional events for testing
#
# **Structure:**
# - Similar structure to batch_1
# - More events for comprehensive testing
# - Likely contains additional violation scenarios
#
# **Ready to use:** ✅
#
# ---
#
# ### 4. **agent_action_logs_batch_3.json** ✅
# **Status:** Good - More events for testing
#
# **Structure:**
# - Similar structure to batch_1
# - Additional events for comprehensive testing
#
# **Ready to use:** ✅
#
# ---
#
# ### 5. **bias_signals.json** ✅
# **Status:** Excellent - Well-structured bias detection data
#
# **Structure:**
# - 4 bias signals with group comparisons
# - Clear deltas and thresholds
# - Risk levels and recommended actions
#
# **Signals Included:**
# 1. `bias_001`: HR hiring decisions by gender (29% vs 60% approval rate, delta 0.31) → **HIGH RISK**
# 2. `bias_002`: Finance decisions by region (50% vs 76% approval rate, delta 0.26) → **MEDIUM RISK**
# 3. `bias_003`: Account suspensions by region (64% vs 34% suspension rate, delta 0.30) → **HIGH RISK**
# 4. `bias_004`: Marketing ad targeting by age (22% vs 73% exposure rate, delta 0.51) → **CRITICAL RISK**
#
# **Ready to use:** ✅
#
# ---
#
# ### 6. **drift_and_degradation_signals.json** ✅
# **Status:** Excellent - Well-structured drift detection data
#
# **Structure:**
# - 5 drift signals with metric comparisons
# - Previous vs current averages
# - Thresholds and deltas
# - Risk levels and recommended actions
#
# **Signals Included:**
# 1. `drift_001`: CustomerSupportAgent hallucination rate (3% → 11%, threshold 8%) → **HIGH RISK**
# 2. `drift_002`: SalesEnablementAgent confidence (74% → 58%, threshold 60%) → **MEDIUM RISK**
# 3. `drift_003`: FinanceAgent policy violations (4% → 13%, threshold 10%) → **HIGH RISK**
# 4. `drift_004`: HRDecisionAgent override rate (18% → 37%, threshold 30%) → **MEDIUM RISK**
# 5. `drift_005`: MarketingAgent ethics flags (6% → 22%, threshold 15%) → **CRITICAL RISK**
#
# **Ready to use:** ✅
#
# ---
#
# ## 🎯 Data Summary
#
# **Total Events:** ~36 events across 3 batches
# **Total Policies:** 5 policies
# **Bias Signals:** 4 signals
# **Drift Signals:** 5 signals
#
# **Violation Rate:** ~20-30% of events contain violations (perfect for testing)
#
# ---
#
# ## ✅ Data Quality Checklist
#
# - [x] All required fields present in agent logs
# - [x] Policy rules are machine-readable and testable
# - [x] Intentional violations embedded for testing
# - [x] Bias signals have clear deltas and thresholds
# - [x] Drift signals have previous/current comparisons
# - [x] Data is realistic and representative
# - [x] JSON format is valid and parseable
#
# ---
#
# ## 🚀 Next Steps
#
# 1. **Load Data** - Build data loading utilities to read all JSON files
# 2. **Policy Matching** - Build utilities to match events to policies
# 3. **Violation Detection** - Build utilities to detect violations
# 4. **Risk Scoring** - Build utilities to score violations
# 5. **Report Generation** - Build utilities to generate audit reports
#
# **All data is ready for MVP development!** ✅
