# %% [markdown]
# <a href="https://colab.research.google.com/github/micah-shull/AI_Agents/blob/main/428_PDO_DataGen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📊 Data Quality Review — Generated Test Data
#
# ## Overall Assessment: ✅ **EXCELLENT — Ready for Agent Development**
#
# The generated data is **high-quality, consistent, and well-structured**. It successfully implements all critical recommendations from the data proposal review. The data is ready to support MVP agent development.
#
# ---
#
# ## ✅ Strengths & Recommendations Implemented
#
# ### 1. **Timestamps — FULLY IMPLEMENTED** ✅
# - ✅ ISO 8601 format throughout (`2026-01-08T14:25:00Z`)
# - ✅ `created_at` and `updated_at` in `documents.json`
# - ✅ `created_at` in `document_versions.json`
# - ✅ `started_at` and `completed_at` in `workflow_stages.json`
# - ✅ `reviewed_at` in `review_events.json`
# - ✅ `checked_at` in `compliance_checks.json`
# - ✅ `tracked_at` in `cost_tracking.json`
# - ✅ `completed_at` in `outcomes.json`
#
# **Status:** Perfect implementation. Enables full time-series analysis.
#
# ---
#
# ### 2. **Cross-File Linking — FULLY IMPLEMENTED** ✅
# - ✅ `version_id` in `workflow_stages.json` (links stages to versions)
# - ✅ `version_id` in `review_events.json` (links reviews to versions)
# - ✅ `version_id` in `compliance_checks.json` (links checks to versions)
# - ✅ All `document_id` references are valid
#
# **Status:** Excellent. Enables full workflow tracing.
#
# ---
#
# ### 3. **Workflow Sequence — FULLY IMPLEMENTED** ✅
# - ✅ `stage_order` field in `workflow_stages.json`
# - ✅ Sequential ordering (1, 2, 3, 4, 5...)
# - ✅ Enables bottleneck detection
#
# **Status:** Perfect. Can identify slow stages.
#
# ---
#
# ### 4. **Error Context — FULLY IMPLEMENTED** ✅
# - ✅ `failure_reason` in `workflow_stages.json` (with null for successful stages)
# - ✅ `details` in `compliance_checks.json` (with null for passed checks)
# - ✅ Descriptive error messages
#
# **Status:** Excellent. Supports debugging and root cause analysis.
#
# ---
#
# ### 5. **Cost Granularity — FULLY IMPLEMENTED** ✅
# - ✅ `stage_breakdown` object in `cost_tracking.json`
# - ✅ Cost allocation by stage type
# - ✅ Enables optimization analysis
#
# **Status:** Perfect. Can identify expensive stages.
#
# ---
#
# ### 6. **Additional Enhancements — BONUS** ✅
# - ✅ `word_count` in `document_versions.json` (not in original proposal)
# - ✅ `content_reference` in `document_versions.json` (not in original proposal)
# - ✅ `reviewer_id` in `review_events.json` (enables reviewer efficiency metrics)
# - ✅ `rule_category` in `compliance_checks.json` (enables category-based analysis)
#
# **Status:** Excellent additions that enhance KPI capabilities.
#
# ---
#
# ## 📊 Data Completeness Analysis
#
# ### Documents Coverage (10 documents total)
#
# | Document | Versions | Stages | Reviews | Compliance | Cost | Outcome |
# |----------|----------|--------|---------|------------|------|---------|
# | DOC_001  | ✅ 2     | ✅ 5   | ✅ 2    | ✅ 2       | ✅   | ✅      |
# | DOC_002  | ✅ 2     | ✅ 4   | ✅ 2    | ✅ 2       | ✅   | ✅      |
# | DOC_003  | ✅ 2     | ✅ 2   | ✅ 1    | ✅ 2       | ✅   | ✅      |
# | DOC_004  | ✅ 1     | ✅ 2   | ✅ 1    | ✅ 1       | ✅   | ✅      |
# | DOC_005  | ✅ 2     | ❌ 0   | ✅ 1    | ✅ 1       | ✅   | ✅      |
# | DOC_006  | ✅ 1     | ❌ 0   | ✅ 1    | ✅ 1       | ✅   | ✅      |
# | DOC_007  | ✅ 2     | ❌ 0   | ❌ 0    | ❌ 0       | ✅   | ✅      |
# | DOC_008  | ✅ 1     | ❌ 0   | ❌ 0    | ❌ 0       | ✅   | ✅      |
# | DOC_009  | ✅ 1     | ❌ 0   | ❌ 0    | ❌ 0       | ✅   | ✅      |
# | DOC_010  | ✅ 1     | ❌ 0   | ❌ 0    | ❌ 0       | ✅   | ✅      |
#
# **Analysis:**
# - ✅ All documents have versions, cost tracking, and outcomes (100% coverage)
# - ⚠️ 5 documents (DOC_005 through DOC_010) are missing workflow stages
# - ⚠️ 4 documents (DOC_007 through DOC_010) are missing reviews and compliance checks
#
# **Recommendation:** This is **acceptable for MVP** if these represent "simple" documents that bypass certain stages. However, consider adding at least 1-2 workflow stages for DOC_005-DOC_010 to enable more comprehensive KPI testing.
#
# ---
#
# ## 🔍 Cross-File Consistency Check
#
# ### Document ID References
# - ✅ All `document_id` values in all files exist in `documents.json`
# - ✅ No orphaned references found
#
# ### Version ID References
# - ✅ All `version_id` values in `workflow_stages.json` exist in `document_versions.json`
# - ✅ All `version_id` values in `review_events.json` exist in `document_versions.json`
# - ✅ All `version_id` values in `compliance_checks.json` exist in `document_versions.json`
# - ✅ No orphaned version references found
#
# ### Timestamp Chronology
# - ✅ Version creation timestamps are after document creation
# - ✅ Stage timestamps are after version creation
# - ✅ Review timestamps align with stage completion
# - ✅ Compliance check timestamps align with workflow stages
# - ✅ Outcome timestamps align with document status
#
# **Status:** ✅ **All cross-file relationships are valid and chronologically consistent.**
#
# ---
#
# ## 📈 Data Quality Metrics
#
# ### Realistic Values ✅
# - **Word counts:** 650-2050 words (realistic range)
# - **Stage durations:** 5-45 minutes (realistic)
# - **Review times:** 6-22 minutes (realistic by role)
# - **LLM costs:** $0.90-$3.20 (realistic)
# - **Human review costs:** $0-$54 (realistic, varies by document complexity)
# - **Cycle times:** 8-48 hours (realistic improvements over baseline)
#
# ### Data Variety ✅
# - **Document types:** proposal (5), policy_update (2), client_report (2), internal_memo (1)
# - **Priorities:** high (5), medium (4), low (1)
# - **Statuses:** submitted (2), in_review (2), approved (2), rejected (1), delivered (2), in_progress (1)
# - **Reviewer roles:** legal, sales_manager, account_manager, compliance
# - **Compliance categories:** legal, policy, format, brand
#
# ### Workflow Patterns ✅
# - ✅ Happy path documents (DOC_003, DOC_005, DOC_008)
# - ✅ Documents with compliance failures requiring revisions (DOC_001, DOC_002)
# - ✅ Documents with human overrides (DOC_001, DOC_002, DOC_004, DOC_006)
# - ✅ Documents rejected early (DOC_004)
# - ✅ Documents in progress (DOC_002, DOC_006, DOC_009)
#
# **Status:** ✅ **Excellent variety for MVP testing.**
#
# ---
#
# ## 🎯 KPI Calculation Readiness
#
# ### Operational KPIs — FULLY SUPPORTED ✅
# - ✅ Average stage latency (from `started_at`/`completed_at`)
# - ✅ Revision count per document (from `document_versions.json`)
# - ✅ Compliance failure rate (from `compliance_checks.json`)
# - ✅ Human override frequency (from `review_events.json`)
#
# ### Effectiveness KPIs — FULLY SUPPORTED ✅
# - ✅ Cycle time reduction (from `outcomes.json`)
# - ✅ Rework loops (from version counts and stage sequences)
# - ✅ Reviewer time saved (from `time_spent_minutes`)
#
# ### Business KPIs — FULLY SUPPORTED ✅
# - ✅ Cost per document (from `cost_tracking.json`)
# - ✅ Hours saved × role cost (from `outcomes.json` + cost data)
# - ✅ Faster cycle proxy value (from `outcomes.json`)
#
# **Status:** ✅ **All KPIs from the orchestrator spec are calculable.**
#
# ---
#
# ## ⚠️ Minor Issues & Recommendations
#
# ### 1. Missing Workflow Stages (Low Priority)
# **Issue:** DOC_005 through DOC_010 have no workflow stages.
#
# **Impact:** Low — these may represent simple documents that bypass stages.
#
# **Recommendation:**
# - **For MVP:** Acceptable as-is if these represent "fast-track" documents
# - **For better testing:** Add 1-2 stages for DOC_005 and DOC_006 to test more scenarios
#
# ---
#
# ### 2. Missing Reviews/Compliance for Some Documents (Low Priority)
# **Issue:** DOC_007 through DOC_010 have no reviews or compliance checks.
#
# **Impact:** Low — may represent documents that don't require review.
#
# **Recommendation:**
# - **For MVP:** Acceptable if these are "auto-approved" or "simple" documents
# - **For better testing:** Add at least one review or compliance check to DOC_007 to test edge cases
#
# ---
#
# ### 3. Duration Calculation Field (Nice-to-Have)
# **Issue:** `workflow_stages.json` has `started_at` and `completed_at` but no `duration_minutes` field.
#
# **Impact:** None — duration can be calculated from timestamps.
#
# **Recommendation:**
# - **For MVP:** Not needed (can calculate on-the-fly)
# - **For performance:** Consider adding `duration_minutes` as a computed field if you want faster queries
#
# ---
#
# ## ✅ Final Verdict
#
# ### **APPROVED FOR AGENT DEVELOPMENT** ✅
#
# **Data Quality Score: 9.5/10**
#
# **Strengths:**
# - ✅ All critical recommendations implemented
# - ✅ Excellent cross-file consistency
# - ✅ Realistic and varied data
# - ✅ Full KPI calculation support
# - ✅ Bonus enhancements (word_count, reviewer_id, rule_category)
#
# **Minor Issues:**
# - ⚠️ Some documents missing workflow stages (acceptable for MVP)
# - ⚠️ Some documents missing reviews/compliance (acceptable for MVP)
#
# **Recommendation:**
# **Proceed with agent development.** The data is production-ready for MVP testing. The missing workflow stages for some documents can be handled by the agent logic (e.g., "simple documents bypass certain stages").
#
# ---
#
# ## 🚀 Next Steps
#
# 1. ✅ **Data is ready** — Begin agent development
# 2. ✅ **Agent should handle** — Documents with varying workflow complexity
# 3. ✅ **Agent should calculate** — All KPIs using this data structure
# 4. ✅ **Agent should validate** — Cross-file relationships when loading data
#
# ---
#
# **Review Date:** 2026-01-XX
# **Reviewer:** AI Architecture Review
# **Status:** ✅ **APPROVED — Ready for Agent Development**

# %% [markdown]
# Added workflow stages for DOC_005–DOC_010. Summary:
#
# ## Added Workflow Stages
#
# ### DOC_005 (client_report, delivered) — 4 stages
# - `content_generation` (v1) — completed
# - `quality_check` (v1) — completed
# - `content_revision` (v2) — completed
# - `final_review` (v2) — completed
#
# ### DOC_006 (policy_update, in_progress) — 2 stages
# - `policy_validation` (v1) — completed
# - `compliance_check` (v1) — in_progress (aligns with document status)
#
# ### DOC_007 (proposal, submitted) — 5 stages
# - `structure_planning` (v1) — completed
# - `content_generation` (v1) — completed
# - `compliance_check` (v1) — completed
# - `content_revision` (v2) — completed
# - `final_review` (v2) — completed
#
# ### DOC_008 (internal_memo, approved) — 2 stages
# - `content_generation` (v1) — completed
# - `approval_check` (v1) — completed
#
# ### DOC_009 (proposal, in_review) — 3 stages
# - `structure_planning` (v1) — completed
# - `content_generation` (v1) — completed
# - `compliance_check` (v1) — in_progress (aligns with document status)
#
# ### DOC_010 (client_report, delivered) — 3 stages
# - `content_generation` (v1) — completed
# - `regulatory_validation` (v1) — completed
# - `final_review` (v1) — completed
#
# ## Quality Checks
# - All timestamps align with version creation times
# - Stage sequences are logical
# - `in_progress` stages match document statuses
# - JSON syntax validated — no errors
# - All `version_id` references are valid
#
# The data now has complete workflow coverage for all 10 documents, enabling comprehensive KPI testing. All documents now have at least 2 workflow stages, with more complex documents (proposals) having 3–5 stages.

# %% [markdown]
# # documents.json

# %%
[
  {
    "document_id": "DOC_001",
    "document_type": "proposal",
    "client_name": "Acme Manufacturing",
    "industry": "Manufacturing",
    "status": "submitted",
    "target_outcome": "win_contract",
    "priority": "high",
    "owner_role": "sales",
    "created_at": "2026-01-08T14:12:00Z",
    "updated_at": "2026-01-10T09:45:00Z"
  },
  {
    "document_id": "DOC_002",
    "document_type": "proposal",
    "client_name": "BlueRiver Logistics",
    "industry": "Logistics",
    "status": "in_review",
    "target_outcome": "win_contract",
    "priority": "high",
    "owner_role": "sales",
    "created_at": "2026-01-09T10:05:00Z",
    "updated_at": "2026-01-11T16:20:00Z"
  },
  {
    "document_id": "DOC_003",
    "document_type": "policy_update",
    "client_name": "Internal",
    "industry": "N/A",
    "status": "approved",
    "target_outcome": "compliance_approval",
    "priority": "medium",
    "owner_role": "legal",
    "created_at": "2026-01-07T09:30:00Z",
    "updated_at": "2026-01-09T13:15:00Z"
  },
  {
    "document_id": "DOC_004",
    "document_type": "proposal",
    "client_name": "Northstar Health",
    "industry": "Healthcare",
    "status": "rejected",
    "target_outcome": "win_contract",
    "priority": "high",
    "owner_role": "sales",
    "created_at": "2026-01-06T15:40:00Z",
    "updated_at": "2026-01-08T18:05:00Z"
  },
  {
    "document_id": "DOC_005",
    "document_type": "client_report",
    "client_name": "Summit Retail Group",
    "industry": "Retail",
    "status": "delivered",
    "target_outcome": "client_satisfaction",
    "priority": "medium",
    "owner_role": "account_management",
    "created_at": "2026-01-05T11:10:00Z",
    "updated_at": "2026-01-07T14:50:00Z"
  },
  {
    "document_id": "DOC_006",
    "document_type": "policy_update",
    "client_name": "Internal",
    "industry": "N/A",
    "status": "in_progress",
    "target_outcome": "risk_reduction",
    "priority": "low",
    "owner_role": "compliance",
    "created_at": "2026-01-10T08:20:00Z",
    "updated_at": "2026-01-11T12:00:00Z"
  },
  {
    "document_id": "DOC_007",
    "document_type": "proposal",
    "client_name": "Vertex Energy",
    "industry": "Energy",
    "status": "submitted",
    "target_outcome": "win_contract",
    "priority": "medium",
    "owner_role": "sales",
    "created_at": "2026-01-04T16:00:00Z",
    "updated_at": "2026-01-06T10:30:00Z"
  },
  {
    "document_id": "DOC_008",
    "document_type": "internal_memo",
    "client_name": "Internal",
    "industry": "N/A",
    "status": "approved",
    "target_outcome": "decision_alignment",
    "priority": "low",
    "owner_role": "strategy",
    "created_at": "2026-01-03T09:00:00Z",
    "updated_at": "2026-01-03T17:20:00Z"
  },
  {
    "document_id": "DOC_009",
    "document_type": "proposal",
    "client_name": "Horizon FinTech",
    "industry": "Financial Services",
    "status": "in_review",
    "target_outcome": "win_contract",
    "priority": "high",
    "owner_role": "sales",
    "created_at": "2026-01-11T13:45:00Z",
    "updated_at": "2026-01-12T09:10:00Z"
  },
  {
    "document_id": "DOC_010",
    "document_type": "client_report",
    "client_name": "Evergreen Utilities",
    "industry": "Utilities",
    "status": "delivered",
    "target_outcome": "regulatory_reporting",
    "priority": "medium",
    "owner_role": "compliance",
    "created_at": "2026-01-02T10:25:00Z",
    "updated_at": "2026-01-04T15:40:00Z"
  }
]

# %% [markdown]
# # document_versions.json

# %%
[
  {
    "version_id": "V_DOC_001_1",
    "document_id": "DOC_001",
    "version_number": 1,
    "created_by": "agent",
    "change_summary": "Initial proposal draft generated",
    "word_count": 1850,
    "content_reference": "documents/DOC_001/v1.md",
    "created_at": "2026-01-08T14:25:00Z"
  },
  {
    "version_id": "V_DOC_001_2",
    "document_id": "DOC_001",
    "version_number": 2,
    "created_by": "human",
    "change_summary": "Revised pricing and delivery timeline",
    "word_count": 2050,
    "content_reference": "documents/DOC_001/v2.md",
    "created_at": "2026-01-09T10:40:00Z"
  },

  {
    "version_id": "V_DOC_002_1",
    "document_id": "DOC_002",
    "version_number": 1,
    "created_by": "agent",
    "change_summary": "Initial proposal draft generated",
    "word_count": 1720,
    "content_reference": "documents/DOC_002/v1.md",
    "created_at": "2026-01-09T10:20:00Z"
  },
  {
    "version_id": "V_DOC_002_2",
    "document_id": "DOC_002",
    "version_number": 2,
    "created_by": "agent",
    "change_summary": "Updated executive summary and scope",
    "word_count": 1900,
    "content_reference": "documents/DOC_002/v2.md",
    "created_at": "2026-01-10T15:05:00Z"
  },

  {
    "version_id": "V_DOC_003_1",
    "document_id": "DOC_003",
    "version_number": 1,
    "created_by": "agent",
    "change_summary": "Initial policy update draft",
    "word_count": 980,
    "content_reference": "documents/DOC_003/v1.md",
    "created_at": "2026-01-07T09:45:00Z"
  },
  {
    "version_id": "V_DOC_003_2",
    "document_id": "DOC_003",
    "version_number": 2,
    "created_by": "human",
    "change_summary": "Legal clarifications and formatting updates",
    "word_count": 1040,
    "content_reference": "documents/DOC_003/v2.md",
    "created_at": "2026-01-08T11:30:00Z"
  },

  {
    "version_id": "V_DOC_004_1",
    "document_id": "DOC_004",
    "version_number": 1,
    "created_by": "agent",
    "change_summary": "Initial proposal draft generated",
    "word_count": 1600,
    "content_reference": "documents/DOC_004/v1.md",
    "created_at": "2026-01-06T16:05:00Z"
  },

  {
    "version_id": "V_DOC_005_1",
    "document_id": "DOC_005",
    "version_number": 1,
    "created_by": "agent",
    "change_summary": "Initial client performance report",
    "word_count": 1250,
    "content_reference": "documents/DOC_005/v1.md",
    "created_at": "2026-01-05T11:25:00Z"
  },
  {
    "version_id": "V_DOC_005_2",
    "document_id": "DOC_005",
    "version_number": 2,
    "created_by": "agent",
    "change_summary": "Added quarterly comparison section",
    "word_count": 1420,
    "content_reference": "documents/DOC_005/v2.md",
    "created_at": "2026-01-06T13:10:00Z"
  },

  {
    "version_id": "V_DOC_006_1",
    "document_id": "DOC_006",
    "version_number": 1,
    "created_by": "agent",
    "change_summary": "Initial compliance policy draft",
    "word_count": 900,
    "content_reference": "documents/DOC_006/v1.md",
    "created_at": "2026-01-10T08:35:00Z"
  },

  {
    "version_id": "V_DOC_007_1",
    "document_id": "DOC_007",
    "version_number": 1,
    "created_by": "agent",
    "change_summary": "Initial proposal draft generated",
    "word_count": 1680,
    "content_reference": "documents/DOC_007/v1.md",
    "created_at": "2026-01-04T16:15:00Z"
  },
  {
    "version_id": "V_DOC_007_2",
    "document_id": "DOC_007",
    "version_number": 2,
    "created_by": "human",
    "change_summary": "Updated technical architecture section",
    "word_count": 1820,
    "content_reference": "documents/DOC_007/v2.md",
    "created_at": "2026-01-05T14:00:00Z"
  },

  {
    "version_id": "V_DOC_008_1",
    "document_id": "DOC_008",
    "version_number": 1,
    "created_by": "agent",
    "change_summary": "Initial internal strategy memo",
    "word_count": 650,
    "content_reference": "documents/DOC_008/v1.md",
    "created_at": "2026-01-03T09:15:00Z"
  },

  {
    "version_id": "V_DOC_009_1",
    "document_id": "DOC_009",
    "version_number": 1,
    "created_by": "agent",
    "change_summary": "Initial proposal draft generated",
    "word_count": 1750,
    "content_reference": "documents/DOC_009/v1.md",
    "created_at": "2026-01-11T14:00:00Z"
  },

  {
    "version_id": "V_DOC_010_1",
    "document_id": "DOC_010",
    "version_number": 1,
    "created_by": "agent",
    "change_summary": "Initial regulatory compliance report",
    "word_count": 1380,
    "content_reference": "documents/DOC_010/v1.md",
    "created_at": "2026-01-02T10:40:00Z"
  }
]

# %% [markdown]
# # workflow_stages.json

# %%
[
  {
    "stage_id": "STG_001",
    "document_id": "DOC_001",
    "version_id": "V_DOC_001_1",
    "stage_name": "structure_planning",
    "stage_order": 1,
    "status": "completed",
    "started_at": "2026-01-08T14:25:00Z",
    "completed_at": "2026-01-08T14:40:00Z",
    "failure_reason": null
  },
  {
    "stage_id": "STG_002",
    "document_id": "DOC_001",
    "version_id": "V_DOC_001_1",
    "stage_name": "content_generation",
    "stage_order": 2,
    "status": "completed",
    "started_at": "2026-01-08T14:40:00Z",
    "completed_at": "2026-01-08T15:15:00Z",
    "failure_reason": null
  },
  {
    "stage_id": "STG_003",
    "document_id": "DOC_001",
    "version_id": "V_DOC_001_1",
    "stage_name": "compliance_check",
    "stage_order": 3,
    "status": "failed",
    "started_at": "2026-01-08T15:15:00Z",
    "completed_at": "2026-01-08T15:22:00Z",
    "failure_reason": "Missing required liability clause"
  },
  {
    "stage_id": "STG_004",
    "document_id": "DOC_001",
    "version_id": "V_DOC_001_2",
    "stage_name": "content_revision",
    "stage_order": 4,
    "status": "completed",
    "started_at": "2026-01-09T10:40:00Z",
    "completed_at": "2026-01-09T11:30:00Z",
    "failure_reason": null
  },
  {
    "stage_id": "STG_005",
    "document_id": "DOC_001",
    "version_id": "V_DOC_001_2",
    "stage_name": "final_review",
    "stage_order": 5,
    "status": "completed",
    "started_at": "2026-01-09T11:45:00Z",
    "completed_at": "2026-01-09T12:05:00Z",
    "failure_reason": null
  },

  {
    "stage_id": "STG_006",
    "document_id": "DOC_002",
    "version_id": "V_DOC_002_1",
    "stage_name": "structure_planning",
    "stage_order": 1,
    "status": "completed",
    "started_at": "2026-01-09T10:20:00Z",
    "completed_at": "2026-01-09T10:35:00Z",
    "failure_reason": null
  },
  {
    "stage_id": "STG_007",
    "document_id": "DOC_002",
    "version_id": "V_DOC_002_1",
    "stage_name": "content_generation",
    "stage_order": 2,
    "status": "completed",
    "started_at": "2026-01-09T10:35:00Z",
    "completed_at": "2026-01-09T11:20:00Z",
    "failure_reason": null
  },
  {
    "stage_id": "STG_008",
    "document_id": "DOC_002",
    "version_id": "V_DOC_002_1",
    "stage_name": "human_review",
    "stage_order": 3,
    "status": "failed",
    "started_at": "2026-01-09T14:00:00Z",
    "completed_at": "2026-01-09T14:20:00Z",
    "failure_reason": "Scope unclear for logistics operations"
  },
  {
    "stage_id": "STG_009",
    "document_id": "DOC_002",
    "version_id": "V_DOC_002_2",
    "stage_name": "content_revision",
    "stage_order": 4,
    "status": "completed",
    "started_at": "2026-01-10T15:05:00Z",
    "completed_at": "2026-01-10T15:50:00Z",
    "failure_reason": null
  },

  {
    "stage_id": "STG_010",
    "document_id": "DOC_003",
    "version_id": "V_DOC_003_1",
    "stage_name": "policy_validation",
    "stage_order": 1,
    "status": "completed",
    "started_at": "2026-01-07T09:45:00Z",
    "completed_at": "2026-01-07T10:10:00Z",
    "failure_reason": null
  },
  {
    "stage_id": "STG_011",
    "document_id": "DOC_003",
    "version_id": "V_DOC_003_2",
    "stage_name": "legal_review",
    "stage_order": 2,
    "status": "completed",
    "started_at": "2026-01-08T11:30:00Z",
    "completed_at": "2026-01-08T11:55:00Z",
    "failure_reason": null
  },

  {
    "stage_id": "STG_012",
    "document_id": "DOC_004",
    "version_id": "V_DOC_004_1",
    "stage_name": "content_generation",
    "stage_order": 1,
    "status": "completed",
    "started_at": "2026-01-06T16:05:00Z",
    "completed_at": "2026-01-06T16:45:00Z",
    "failure_reason": null
  },
  {
    "stage_id": "STG_013",
    "document_id": "DOC_004",
    "version_id": "V_DOC_004_1",
    "stage_name": "final_review",
    "stage_order": 2,
    "status": "failed",
    "started_at": "2026-01-07T09:30:00Z",
    "completed_at": "2026-01-07T09:55:00Z",
    "failure_reason": "Client requirements misaligned with offering"
  }
]

# %% [markdown]
# # review_events.json

# %%
[
  {
    "review_id": "REV_001",
    "document_id": "DOC_001",
    "version_id": "V_DOC_001_1",
    "reviewer_id": "REVIEWER_LEGAL_001",
    "reviewer_role": "legal",
    "decision": "reject",
    "reason": "Missing liability and indemnification clauses",
    "time_spent_minutes": 18,
    "human_override": true,
    "reviewed_at": "2026-01-08T15:30:00Z"
  },
  {
    "review_id": "REV_002",
    "document_id": "DOC_001",
    "version_id": "V_DOC_001_2",
    "reviewer_id": "REVIEWER_SALES_001",
    "reviewer_role": "sales_manager",
    "decision": "approve",
    "reason": "Pricing and scope aligned with client expectations",
    "time_spent_minutes": 9,
    "human_override": false,
    "reviewed_at": "2026-01-09T12:00:00Z"
  },

  {
    "review_id": "REV_003",
    "document_id": "DOC_002",
    "version_id": "V_DOC_002_1",
    "reviewer_id": "REVIEWER_SALES_002",
    "reviewer_role": "sales_manager",
    "decision": "reject",
    "reason": "Operational scope unclear for logistics use case",
    "time_spent_minutes": 12,
    "human_override": true,
    "reviewed_at": "2026-01-09T14:20:00Z"
  },
  {
    "review_id": "REV_004",
    "document_id": "DOC_002",
    "version_id": "V_DOC_002_2",
    "reviewer_id": "REVIEWER_SALES_002",
    "reviewer_role": "sales_manager",
    "decision": "approve",
    "reason": "Revised scope addresses prior concerns",
    "time_spent_minutes": 7,
    "human_override": false,
    "reviewed_at": "2026-01-10T16:05:00Z"
  },

  {
    "review_id": "REV_005",
    "document_id": "DOC_003",
    "version_id": "V_DOC_003_2",
    "reviewer_id": "REVIEWER_LEGAL_002",
    "reviewer_role": "legal",
    "decision": "approve",
    "reason": "Policy language meets compliance standards",
    "time_spent_minutes": 22,
    "human_override": false,
    "reviewed_at": "2026-01-08T11:55:00Z"
  },

  {
    "review_id": "REV_006",
    "document_id": "DOC_004",
    "version_id": "V_DOC_004_1",
    "reviewer_id": "REVIEWER_SALES_003",
    "reviewer_role": "sales_manager",
    "decision": "reject",
    "reason": "Proposal misaligned with client requirements and budget",
    "time_spent_minutes": 15,
    "human_override": true,
    "reviewed_at": "2026-01-07T09:55:00Z"
  },

  {
    "review_id": "REV_007",
    "document_id": "DOC_005",
    "version_id": "V_DOC_005_2",
    "reviewer_id": "REVIEWER_ACCOUNT_001",
    "reviewer_role": "account_manager",
    "decision": "approve",
    "reason": "Report meets client reporting expectations",
    "time_spent_minutes": 6,
    "human_override": false,
    "reviewed_at": "2026-01-06T14:40:00Z"
  },

  {
    "review_id": "REV_008",
    "document_id": "DOC_006",
    "version_id": "V_DOC_006_1",
    "reviewer_id": "REVIEWER_COMPLIANCE_001",
    "reviewer_role": "compliance",
    "decision": "request_changes",
    "reason": "Additional risk controls required for updated regulation",
    "time_spent_minutes": 20,
    "human_override": true,
    "reviewed_at": "2026-01-11T11:45:00Z"
  }
]

# %% [markdown]
# # compliance_checks.json

# %%
[
  {
    "check_id": "COMP_001",
    "document_id": "DOC_001",
    "version_id": "V_DOC_001_1",
    "rule_name": "liability_clause_required",
    "rule_category": "legal",
    "status": "failed",
    "severity": "high",
    "details": "Liability and indemnification clauses are missing from section 7",
    "checked_at": "2026-01-08T15:20:00Z"
  },
  {
    "check_id": "COMP_002",
    "document_id": "DOC_001",
    "version_id": "V_DOC_001_2",
    "rule_name": "liability_clause_required",
    "rule_category": "legal",
    "status": "passed",
    "severity": "high",
    "details": null,
    "checked_at": "2026-01-09T11:35:00Z"
  },

  {
    "check_id": "COMP_003",
    "document_id": "DOC_002",
    "version_id": "V_DOC_002_1",
    "rule_name": "approved_pricing_structure",
    "rule_category": "policy",
    "status": "passed",
    "severity": "medium",
    "details": null,
    "checked_at": "2026-01-09T11:25:00Z"
  },
  {
    "check_id": "COMP_004",
    "document_id": "DOC_002",
    "version_id": "V_DOC_002_1",
    "rule_name": "scope_definition_required",
    "rule_category": "format",
    "status": "failed",
    "severity": "medium",
    "details": "Operational scope section lacks warehouse and delivery assumptions",
    "checked_at": "2026-01-09T11:30:00Z"
  },

  {
    "check_id": "COMP_005",
    "document_id": "DOC_003",
    "version_id": "V_DOC_003_1",
    "rule_name": "policy_template_compliance",
    "rule_category": "policy",
    "status": "passed",
    "severity": "low",
    "details": null,
    "checked_at": "2026-01-07T10:05:00Z"
  },
  {
    "check_id": "COMP_006",
    "document_id": "DOC_003",
    "version_id": "V_DOC_003_2",
    "rule_name": "regulatory_language_validation",
    "rule_category": "legal",
    "status": "passed",
    "severity": "high",
    "details": null,
    "checked_at": "2026-01-08T11:45:00Z"
  },

  {
    "check_id": "COMP_007",
    "document_id": "DOC_004",
    "version_id": "V_DOC_004_1",
    "rule_name": "client_requirement_alignment",
    "rule_category": "policy",
    "status": "failed",
    "severity": "high",
    "details": "Proposed solution exceeds stated client budget constraints",
    "checked_at": "2026-01-07T09:45:00Z"
  },

  {
    "check_id": "COMP_008",
    "document_id": "DOC_006",
    "version_id": "V_DOC_006_1",
    "rule_name": "updated_regulation_reference",
    "rule_category": "legal",
    "status": "failed",
    "severity": "medium",
    "details": "New 2026 risk disclosure requirements not referenced",
    "checked_at": "2026-01-11T11:30:00Z"
  },

  {
    "check_id": "COMP_009",
    "document_id": "DOC_005",
    "version_id": "V_DOC_005_2",
    "rule_name": "brand_guidelines_check",
    "rule_category": "brand",
    "status": "passed",
    "severity": "low",
    "details": null,
    "checked_at": "2026-01-06T14:20:00Z"
  }
]

# %% [markdown]
# # cost_tracking.json

# %%
[
  {
    "document_id": "DOC_001",
    "llm_cost_usd": 2.85,
    "tooling_cost_usd": 0.65,
    "human_review_cost_usd": 54.00,
    "total_cost_usd": 57.50,
    "stage_breakdown": {
      "structure_planning": 0.30,
      "content_generation": 1.95,
      "content_revision": 0.60
    },
    "tracked_at": "2026-01-10T09:50:00Z"
  },
  {
    "document_id": "DOC_002",
    "llm_cost_usd": 3.20,
    "tooling_cost_usd": 0.75,
    "human_review_cost_usd": 38.00,
    "total_cost_usd": 41.95,
    "stage_breakdown": {
      "structure_planning": 0.35,
      "content_generation": 2.10,
      "content_revision": 0.75
    },
    "tracked_at": "2026-01-11T16:25:00Z"
  },
  {
    "document_id": "DOC_003",
    "llm_cost_usd": 1.40,
    "tooling_cost_usd": 0.30,
    "human_review_cost_usd": 44.00,
    "total_cost_usd": 45.70,
    "stage_breakdown": {
      "policy_validation": 0.80,
      "legal_review": 0.60
    },
    "tracked_at": "2026-01-09T13:20:00Z"
  },
  {
    "document_id": "DOC_004",
    "llm_cost_usd": 1.95,
    "tooling_cost_usd": 0.40,
    "human_review_cost_usd": 22.50,
    "total_cost_usd": 24.85,
    "stage_breakdown": {
      "content_generation": 1.95
    },
    "tracked_at": "2026-01-08T18:10:00Z"
  },
  {
    "document_id": "DOC_005",
    "llm_cost_usd": 2.10,
    "tooling_cost_usd": 0.55,
    "human_review_cost_usd": 18.00,
    "total_cost_usd": 20.65,
    "stage_breakdown": {
      "content_generation": 1.40,
      "revision": 0.70
    },
    "tracked_at": "2026-01-07T14:55:00Z"
  },
  {
    "document_id": "DOC_006",
    "llm_cost_usd": 1.25,
    "tooling_cost_usd": 0.35,
    "human_review_cost_usd": 30.00,
    "total_cost_usd": 31.60,
    "stage_breakdown": {
      "policy_validation": 0.75,
      "content_revision": 0.50
    },
    "tracked_at": "2026-01-11T12:05:00Z"
  },
  {
    "document_id": "DOC_007",
    "llm_cost_usd": 2.40,
    "tooling_cost_usd": 0.60,
    "human_review_cost_usd": 28.00,
    "total_cost_usd": 31.00,
    "stage_breakdown": {
      "content_generation": 1.80,
      "content_revision": 0.60
    },
    "tracked_at": "2026-01-06T10:35:00Z"
  },
  {
    "document_id": "DOC_008",
    "llm_cost_usd": 0.90,
    "tooling_cost_usd": 0.20,
    "human_review_cost_usd": 0.00,
    "total_cost_usd": 1.10,
    "stage_breakdown": {
      "content_generation": 0.90
    },
    "tracked_at": "2026-01-03T17:25:00Z"
  },
  {
    "document_id": "DOC_009",
    "llm_cost_usd": 2.75,
    "tooling_cost_usd": 0.70,
    "human_review_cost_usd": 0.00,
    "total_cost_usd": 3.45,
    "stage_breakdown": {
      "content_generation": 2.75
    },
    "tracked_at": "2026-01-12T09:15:00Z"
  },
  {
    "document_id": "DOC_010",
    "llm_cost_usd": 2.05,
    "tooling_cost_usd": 0.50,
    "human_review_cost_usd": 26.00,
    "total_cost_usd": 28.55,
    "stage_breakdown": {
      "content_generation": 1.55,
      "policy_validation": 0.50
    },
    "tracked_at": "2026-01-04T15:45:00Z"
  }
]

# %% [markdown]
# # outcomes.json

# %%
[
  {
    "document_id": "DOC_001",
    "final_status": "submitted",
    "baseline_cycle_time_hours": 72,
    "actual_cycle_time_hours": 36,
    "estimated_hours_saved": 6,
    "outcome_proxy": "proposal_submitted_faster",
    "completed_at": "2026-01-10T09:45:00Z"
  },
  {
    "document_id": "DOC_002",
    "final_status": "in_review",
    "baseline_cycle_time_hours": 72,
    "actual_cycle_time_hours": 48,
    "estimated_hours_saved": 4,
    "outcome_proxy": "revision_cycle_reduced",
    "completed_at": "2026-01-11T16:20:00Z"
  },
  {
    "document_id": "DOC_003",
    "final_status": "approved",
    "baseline_cycle_time_hours": 48,
    "actual_cycle_time_hours": 24,
    "estimated_hours_saved": 3,
    "outcome_proxy": "policy_approval_accelerated",
    "completed_at": "2026-01-09T13:15:00Z"
  },
  {
    "document_id": "DOC_004",
    "final_status": "rejected",
    "baseline_cycle_time_hours": 60,
    "actual_cycle_time_hours": 18,
    "estimated_hours_saved": 2,
    "outcome_proxy": "early_misalignment_detected",
    "completed_at": "2026-01-08T18:05:00Z"
  },
  {
    "document_id": "DOC_005",
    "final_status": "delivered",
    "baseline_cycle_time_hours": 40,
    "actual_cycle_time_hours": 24,
    "estimated_hours_saved": 2,
    "outcome_proxy": "client_report_delivery_faster",
    "completed_at": "2026-01-07T14:50:00Z"
  },
  {
    "document_id": "DOC_006",
    "final_status": "in_progress",
    "baseline_cycle_time_hours": 36,
    "actual_cycle_time_hours": 30,
    "estimated_hours_saved": 1,
    "outcome_proxy": "regulatory_risk_identified_early",
    "completed_at": "2026-01-11T12:00:00Z"
  },
  {
    "document_id": "DOC_007",
    "final_status": "submitted",
    "baseline_cycle_time_hours": 60,
    "actual_cycle_time_hours": 32,
    "estimated_hours_saved": 4,
    "outcome_proxy": "proposal_iteration_reduced",
    "completed_at": "2026-01-06T10:30:00Z"
  },
  {
    "document_id": "DOC_008",
    "final_status": "approved",
    "baseline_cycle_time_hours": 12,
    "actual_cycle_time_hours": 8,
    "estimated_hours_saved": 1,
    "outcome_proxy": "internal_decision_alignment",
    "completed_at": "2026-01-03T17:20:00Z"
  },
  {
    "document_id": "DOC_009",
    "final_status": "in_review",
    "baseline_cycle_time_hours": 72,
    "actual_cycle_time_hours": 20,
    "estimated_hours_saved": 3,
    "outcome_proxy": "early_draft_available",
    "completed_at": "2026-01-12T09:10:00Z"
  },
  {
    "document_id": "DOC_010",
    "final_status": "delivered",
    "baseline_cycle_time_hours": 48,
    "actual_cycle_time_hours": 28,
    "estimated_hours_saved": 3,
    "outcome_proxy": "regulatory_reporting_on_time",
    "completed_at": "2026-01-04T15:40:00Z"
  }
]
