# %% [markdown]
# <a href="https://colab.research.google.com/github/micah-shull/AI_Agents/blob/main/751_RGOv2_ReportGen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Revenue Gap Orchestrator v2 — Executive Report
#
# ## Revenue Exposure Overview
#
# - **Verdict:** LOW
# - **Exposure trend:** Declining ↑ 1436% vs prior run (0 days ago)
# - **Total revenue gap:** \$6,257.13
# - **Risk-weighted exposure (REI):** \$10,754.95
# - **Customers with gaps/at risk:** 193
# - **Concentration:** Top 20 customers account for 42% of risk-weighted exposure.
#
# - **Recovery upside (top 20):** \$2,118.42 — potential recoverable revenue (~34% of total gap)
#
# - **Data quality:** OK (0 validation warnings)
#
# ## Targets vs Actuals
#
# - **Risk-weighted exposure:** \$10,754.95 (target ≤ \$15,000) — **On target**
# - **Customers with gaps:** 193 (target ≤ 150) — **Above target**
#
# **So what:** Risk-weighted revenue exposure \$10,755 across 193 customer(s). Top 20 interventions prioritized. Root causes: operational_stockout, demand_softness, structural_decline. Revenue and Customer Success must act on top priorities.
#
# **One ask:** Assign top 5 priority customers to owners; require intervention status within 5 business days.
#
# *Data as of: 2026-02-16 17:18:17 UTC*
#
# ---
#
# ## Exposure by Tier
#
# | Tier | Risk-weighted exposure (REI) |
# |------|-----------------------------|
# | standard | \$9,414.48 |
# | high | \$1,340.47 |
#
# ## Exposure by Root Cause
#
# | Root cause | Risk-weighted exposure (REI) |
# |------------|-----------------------------|
# | operational_stockout | \$10,525.34 |
# | structural_decline | \$228.15 |
# | demand_softness | \$1.46 |
#
# ## Top Priority Interventions
#
# | # | Customer ID | Gap (\$) | REI | Tier | Root cause |
# |---|------------|--------|-----|------|------------|
# | 1 | 152 | 135.03 | 283.56 | standard | operational_stockout |
# | 2 | 28 | 134.06 | 281.53 | standard | operational_stockout |
# | 3 | 175 | 125.47 | 263.49 | standard | operational_stockout |
# | 4 | 154 | 122.42 | 257.08 | standard | operational_stockout |
# | 5 | 31 | 113.79 | 238.96 | standard | operational_stockout |
# | 6 | 107 | 109.75 | 230.47 | standard | operational_stockout |
# | 7 | 188 | 109.42 | 229.78 | standard | operational_stockout |
# | 8 | 183 | 107.52 | 225.79 | standard | operational_stockout |
# | 9 | 159 | 107.33 | 225.39 | standard | operational_stockout |
# | 10 | 48 | 96.68 | 219.95 | high | operational_stockout |
# | 11 | 164 | 103.19 | 216.70 | standard | operational_stockout |
# | 12 | 82 | 102.84 | 215.96 | standard | operational_stockout |
# | 13 | 149 | 100.98 | 212.06 | standard | structural_decline |
# | 14 | 193 | 99.80 | 209.58 | standard | operational_stockout |
# | 15 | 6 | 95.64 | 200.84 | standard | operational_stockout |
# | 16 | 200 | 92.08 | 193.37 | standard | operational_stockout |
# | 17 | 4 | 92.05 | 193.30 | standard | operational_stockout |
# | 18 | 148 | 91.52 | 192.19 | standard | operational_stockout |
# | 19 | 16 | 90.79 | 190.66 | standard | operational_stockout |
# | 20 | 80 | 88.06 | 184.93 | standard | operational_stockout |
#
# ## Next Steps
#
# 1. Assign top 5 priority customers to owners; require intervention status within 5 business days.
# 2. Review exposure by root cause; assign operational vs demand vs retention actions.
# 3. Track recovery on top 20; re-run next cycle for trend.

# %% [markdown]
# # Revenue Gap Orchestrator v2 — Executive Report
#
# ## Revenue Exposure Overview
#
# - **Verdict:** LOW
# - **Exposure trend:** Improving ↓ 33% vs prior run (0 days ago)
# - **Total revenue gap:** \$4,642.40
# - **Risk-weighted exposure (REI):** \$7,249.54
# - **Customers with gaps/at risk:** 186
# - **Concentration:** Top 20 customers account for 41% of risk-weighted exposure.
#
# - **Recovery upside (top 20):** \$1,596.14 — potential recoverable revenue (~34% of total gap)
#
# - **Data quality:** OK (0 validation warnings)
#
# ## Targets vs Actuals
#
# - **Risk-weighted exposure:** \$7,249.54 (target ≤ \$15,000) — **On target**
# - **Customers with gaps:** 186 (target ≤ 150) — **Above target**
#
# **So what:** Risk-weighted revenue exposure \$7,250 across 186 customer(s). Top 20 interventions prioritized. Root causes: operational_stockout, demand_softness, structural_decline. Revenue and Customer Success must act on top priorities.
#
# **One ask:** Assign top 5 priority customers to owners; require intervention status within 5 business days.
#
# *Data as of: 2026-02-16 17:19:41 UTC*
#
# ---
#
# ## Exposure by Tier
#
# | Tier | Risk-weighted exposure (REI) |
# |------|-----------------------------|
# | standard | \$6,220.95 |
# | high | \$1,028.59 |
#
# ## Exposure by Root Cause
#
# | Root cause | Risk-weighted exposure (REI) |
# |------------|-----------------------------|
# | operational_stockout | \$7,017.26 |
# | structural_decline | \$157.86 |
# | demand_softness | \$74.42 |
#
# ## Top Priority Interventions
#
# | # | Customer ID | Gap (\$) | REI | Tier | Root cause |
# |---|------------|--------|-----|------|------------|
# | 1 | 48 | 127.46 | 234.21 | high | operational_stockout |
# | 2 | 152 | 85.04 | 178.58 | standard | operational_stockout |
# | 3 | 28 | 84.92 | 178.33 | standard | operational_stockout |
# | 4 | 150 | 114.50 | 168.31 | standard | operational_stockout |
# | 5 | 181 | 110.80 | 162.88 | standard | operational_stockout |
# | 6 | 31 | 76.74 | 161.15 | standard | operational_stockout |
# | 7 | 171 | 107.39 | 157.86 | standard | structural_decline |
# | 8 | 175 | 74.49 | 156.43 | standard | operational_stockout |
# | 9 | 149 | 70.13 | 147.27 | standard | operational_stockout |
# | 10 | 107 | 93.83 | 137.93 | standard | operational_stockout |
# | 11 | 188 | 63.79 | 133.96 | standard | operational_stockout |
# | 12 | 93 | 90.39 | 132.87 | standard | operational_stockout |
# | 13 | 6 | 62.89 | 132.07 | standard | operational_stockout |
# | 14 | 159 | 61.23 | 128.58 | standard | operational_stockout |
# | 15 | 183 | 61.06 | 128.23 | standard | operational_stockout |
# | 16 | 164 | 59.51 | 124.97 | standard | operational_stockout |
# | 17 | 4 | 59.02 | 123.94 | standard | operational_stockout |
# | 18 | 154 | 58.47 | 122.79 | standard | operational_stockout |
# | 19 | 193 | 57.93 | 121.65 | standard | operational_stockout |
# | 20 | 10 | 76.55 | 112.53 | standard | operational_stockout |
#
# ## Next Steps
#
# 1. Assign top 5 priority customers to owners; require intervention status within 5 business days.
# 2. Review exposure by root cause; assign operational vs demand vs retention actions.
# 3. Track recovery on top 20; re-run next cycle for trend.

# %% [markdown]
# # Revenue Gap Orchestrator v2 — Executive Report
#
# ## Revenue Exposure Overview
#
# - **Verdict:** LOW
# - **Exposure trend:** Improving ↓ 60% vs prior run (0 days ago)
# - **Total revenue gap:** \$1,967.01
# - **Risk-weighted exposure (REI):** \$2,879.68
# - **Customers with gaps/at risk:** 160
# - **Concentration:** Top 20 customers account for 41% of risk-weighted exposure.
#
# - **Recovery upside (top 20):** \$665.38 — potential recoverable revenue (~34% of total gap)
#
# - **Data quality:** OK (0 validation warnings)
#
# ## Targets vs Actuals
#
# - **Risk-weighted exposure:** \$2,879.68 (target ≤ \$15,000) — **On target**
# - **Customers with gaps:** 160 (target ≤ 150) — **Above target**
#
# **So what:** Risk-weighted revenue exposure \$2,880 across 160 customer(s). Top 20 interventions prioritized. Root causes: operational_stockout, structural_decline, demand_softness. Revenue and Customer Success must act on top priorities.
#
# **One ask:** Assign top 5 priority customers to owners; require intervention status within 5 business days.
#
# *Data as of: 2026-02-16 17:21:19 UTC*
#
# ---
#
# ## Exposure by Tier
#
# | Tier | Risk-weighted exposure (REI) |
# |------|-----------------------------|
# | standard | \$2,250.26 |
# | high | \$629.42 |
#
# ## Exposure by Root Cause
#
# | Root cause | Risk-weighted exposure (REI) |
# |------------|-----------------------------|
# | operational_stockout | \$1,828.09 |
# | structural_decline | \$669.77 |
# | demand_softness | \$381.82 |
#
# ## Top Priority Interventions
#
# | # | Customer ID | Gap (\$) | REI | Tier | Root cause |
# |---|------------|--------|-----|------|------------|
# | 1 | 28 | 43.62 | 91.60 | standard | structural_decline |
# | 2 | 152 | 39.50 | 82.95 | standard | structural_decline |
# | 3 | 31 | 38.04 | 79.88 | standard | operational_stockout |
# | 4 | 48 | 45.94 | 75.37 | high | structural_decline |
# | 5 | 149 | 32.27 | 67.77 | standard | operational_stockout |
# | 6 | 181 | 46.00 | 67.62 | standard | operational_stockout |
# | 7 | 4 | 30.24 | 63.50 | standard | structural_decline |
# | 8 | 107 | 43.20 | 63.50 | standard | operational_stockout |
# | 9 | 150 | 45.91 | 60.26 | standard | structural_decline |
# | 10 | 6 | 27.86 | 58.51 | standard | structural_decline |
# | 11 | 93 | 37.29 | 54.82 | standard | operational_stockout |
# | 12 | 175 | 24.29 | 51.01 | standard | operational_stockout |
# | 13 | 171 | 38.85 | 50.99 | standard | operational_stockout |
# | 14 | 78 | 31.05 | 45.64 | standard | structural_decline |
# | 15 | 164 | 20.89 | 43.87 | standard | operational_stockout |
# | 16 | 188 | 20.43 | 42.90 | standard | operational_stockout |
# | 17 | 97 | 20.40 | 42.84 | standard | operational_stockout |
# | 18 | 192 | 29.00 | 42.63 | standard | structural_decline |
# | 19 | 159 | 20.10 | 42.21 | standard | operational_stockout |
# | 20 | 10 | 30.50 | 40.03 | standard | structural_decline |
#
# ## Next Steps
#
# 1. Assign top 5 priority customers to owners; require intervention status within 5 business days.
# 2. Review exposure by root cause; assign operational vs demand vs retention actions.
# 3. Track recovery on top 20; re-run next cycle for trend.

# %% [markdown]
# # Revenue Gap Orchestrator v2 — Executive Report
#
# ## Revenue Exposure Overview
#
# - **Verdict:** LOW
# - **Exposure trend:** Improving ↓ 44% vs prior run (0 days ago)
# - **Total revenue gap:** \$1,211.12
# - **Risk-weighted exposure (REI):** \$1,600.74
# - **Customers with gaps/at risk:** 137
# - **Concentration:** Top 20 customers account for 45% of risk-weighted exposure.
#
# - **Recovery upside (top 20):** \$492.48 — potential recoverable revenue (~41% of total gap)
#
# - **Data quality:** OK (0 validation warnings)
#
# ## Targets vs Actuals
#
# - **Risk-weighted exposure:** \$1,600.74 (target ≤ \$15,000) — **On target**
# - **Customers with gaps:** 137 (target ≤ 150) — **On target**
#
# **So what:** Risk-weighted revenue exposure \$1,601 across 137 customer(s). Top 20 interventions prioritized. Root causes: structural_decline, operational_stockout, demand_softness. Revenue and Customer Success must act on top priorities.
#
# **One ask:** Assign top 5 priority customers to owners; require intervention status within 5 business days.
#
# *Data as of: 2026-02-16 17:22:56 UTC*
#
# ---
#
# ## Exposure by Tier
#
# | Tier | Risk-weighted exposure (REI) |
# |------|-----------------------------|
# | standard | \$990.34 |
# | high | \$610.40 |
#
# ## Exposure by Root Cause
#
# | Root cause | Risk-weighted exposure (REI) |
# |------------|-----------------------------|
# | demand_softness | \$723.93 |
# | structural_decline | \$652.81 |
# | operational_stockout | \$224.00 |
#
# ## Top Priority Interventions
#
# | # | Customer ID | Gap (\$) | REI | Tier | Root cause |
# |---|------------|--------|-----|------|------------|
# | 1 | 70 | 34.08 | 49.20 | high | demand_softness |
# | 2 | 86 | 27.47 | 45.07 | high | structural_decline |
# | 3 | 93 | 29.82 | 43.84 | standard | structural_decline |
# | 4 | 91 | 26.60 | 43.64 | high | structural_decline |
# | 5 | 48 | 24.40 | 40.03 | high | structural_decline |
# | 6 | 77 | 27.24 | 39.33 | high | operational_stockout |
# | 7 | 181 | 28.75 | 37.73 | standard | structural_decline |
# | 8 | 150 | 27.12 | 35.59 | standard | structural_decline |
# | 9 | 73 | 23.91 | 34.52 | high | demand_softness |
# | 10 | 54 | 23.44 | 33.84 | high | demand_softness |
# | 11 | 66 | 22.96 | 33.15 | high | demand_softness |
# | 12 | 74 | 22.79 | 32.90 | high | demand_softness |
# | 13 | 84 | 22.69 | 32.76 | high | demand_softness |
# | 14 | 51 | 22.60 | 32.63 | high | demand_softness |
# | 15 | 62 | 22.34 | 32.25 | high | demand_softness |
# | 16 | 68 | 21.93 | 31.66 | high | demand_softness |
# | 17 | 78 | 21.29 | 31.30 | standard | structural_decline |
# | 18 | 88 | 23.02 | 30.21 | standard | structural_decline |
# | 19 | 81 | 20.85 | 30.10 | high | demand_softness |
# | 20 | 65 | 19.18 | 27.69 | high | operational_stockout |
#
# ## Next Steps
#
# 1. Assign top 5 priority customers to owners; require intervention status within 5 business days.
# 2. Review exposure by root cause; assign operational vs demand vs retention actions.
# 3. Track recovery on top 20; re-run next cycle for trend.
