# %% [markdown]
# <a href="https://colab.research.google.com/github/micah-shull/AI_Agents/blob/main/874_PCFDv2_ReportReview.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Product–Customer Fit Discovery — Executive Summary
#
# ## One view
#
# Product–Customer Fit Discovery completed. **Mixed signals** detected: expansion opportunities alongside declining products and segments to monitor.
#
# Signals detected: 10 bundle opportunities, 15 emerging products, 4 declining products, 5 fast-expanding segments.
#
# ---
#
# ## Traceability
#
# **Data:** bundle_opportunity_signals: 10, customer_journeys: 12, customer_metrics: 100, customers: 200, feature_demand_history: 30, feature_usage: 80, market_signals: 10, product_adoption_history: 100, product_catalog: 20, product_metrics: 20, segment_growth_history: 30, transactions: 1824 · Snapshot: 2026-03-10T13:41:37.716153+00:00
#
# **Data quality notes:** Retention risk metric not present in dataset. Product margin field detected but below configured threshold (25.0%).
#
# ---
#
# ## Customer intelligence
#
# High-value segments (by revenue):
#
# | Segment | Customers | Total revenue | Revenue % | Avg CLV | Avg retention risk |
# | --- | --- | --- | --- | --- | --- |
# | 35-44 | 70 | \$503,600 | 30.9 | \$21,557 | — |
# | 45-54 | 53 | \$463,500 | 28.4 | \$26,255 | — |
# | 18-24 | 46 | \$441,500 | 27 | \$28,598 | — |
# | 55+ | 31 | \$223,800 | 13.7 | \$21,339 | — |
#
# *Retention risk not present in dataset.*
#
# ---
#
# ## Product intelligence
#
# High-margin products:
#
# *No products exceed the configured high-margin threshold (25.0%). Consider reviewing product pricing strategy or margin threshold configuration.*
#
# ---
#
# ## Feature intelligence
#
# Feature demand surges:
#
# *Feature demand signals are driven by internal usage (and market requests where available).*
#
# *Strongest combined signal: Feature D.*
#
# | Feature | Usage count | Requests |
# | --- | --- | --- |
# | D | 368 | 3 |
# | C | 311 | 2 |
# | B | 255 | 0 |
# | A | 236 | 1 |
#
# ---
#
# ## Trend intelligence
#
# Emerging products:
#
# | Product ID | Product | Growth % |
# | --- | --- | --- |
# | P18 | Service | 460 |
# | P14 | Service | 428.6 |
# | P05 | Hardware | 361.1 |
# | P10 | Hardware | 337.5 |
# | P03 | Software | 331.8 |
# | P08 | Service | 83.3 |
# | P12 | Software | 81 |
# | P09 | Service | 80 |
# | P02 | Hardware | 71.4 |
# | P01 | Hardware | 71.1 |
# | P16 | Software | 69.6 |
# | P13 | Service | 64 |
# | P20 | Software | 62.5 |
# | P17 | Software | 48.1 |
# | P06 | Software | 29.4 |
#
# Declining products:
#
# | Product ID | Product | Growth % |
# | --- | --- | --- |
# | P04 | Service | -35 |
# | P07 | Service | -34.6 |
# | P19 | Service | -31.8 |
# | P15 | Software | -26.3 |
#
# Fast-expanding segments:
#
# | Segment | Growth % |
# | --- | --- |
# | Tech SMB | 336.4 |
# | Startup | 155 |
# | Healthcare SMB | 131.6 |
# | SMB | 93.8 |
# | Enterprise | 72.2 |
#
# ---
#
# ## Strategic signals
#
# ### Top opportunity detected
#
# **Software** + **Hardware**
# - Segment: Enterprise
# - Observed customers: 8
# - Average revenue per customer: \$9,200
# - Opportunity score: 96
#
# ### Revenue signal summary
#
# 10 bundle opportunities detected. 135 observed customers across segments. Average revenue potential: \$900 – \$9,200 per customer.
#
# Bundle / cross-sell opportunities:
#
# | Bundle | Product A | Product B | Product C | Segment | Customers | Avg revenue/cust | Score |
# | --- | --- | --- | --- | --- | --- | --- | --- |
# | B10 | Software | Hardware | Service | Enterprise | 8 | \$9,200 | 96 |
# | B05 | Software | Hardware | Hardware | Enterprise | 12 | \$8,400 | 94 |
# | B01 | Software | Service | Service | Tech SMB | 22 | \$4,800 | 92 |
# | B08 | Service | Service |  | Tech SMB | 11 | \$5,200 | 90 |
# | B02 | Hardware | Hardware |  | Enterprise | 16 | \$7,200 | 88 |
# | B03 | Hardware | Software | Service | SMB | 14 | \$3,600 | 76 |
# | B06 | Service | Software |  | SMB | 15 | \$3,300 | 72 |
# | B04 | Hardware | Service |  | Startup | 18 | \$2,400 | 70 |
# | B09 | Software | Software |  | Healthcare SMB | 10 | \$3,100 | 65 |
# | B07 | Service | Service |  | Individual | 9 | \$900 | 40 |
#
# ---
#
# ## Next steps
#
# 1. Prioritize top bundle opportunities for packaging or cross-sell campaigns.
# 2. Double down on emerging products (invest in capacity and marketing).
# 3. Review declining products for repositioning or sunset decisions.

# %% [markdown]
# This is **a major improvement over the original report**. The changes you implemented make it feel much closer to a **real executive briefing** rather than a raw analytics output. I'll give you a clear evaluation.
#
# ---
#
# # Overall Verdict
#
# Your updated report now has three qualities that matter for leadership audiences:
#
# * ✅ **Immediate clarity**
# * ✅ **Traceability and trust**
# * ✅ **Actionable intelligence**
#
# Structurally it now follows a very strong pattern:
#
# ```
# Situation
# ↓
# Evidence
# ↓
# Opportunity
# ↓
# Action
# ```
#
# Which is exactly how good executive reporting works.
#
# ---
#
# # What Improved the Most
#
# ## 1. The Opening Section
#
# This is now excellent.
#
# ```
# Mixed signals detected: expansion opportunities alongside declining products
# ```
#
# This line does two important things:
#
# * frames the analysis
# * communicates risk + opportunity simultaneously
#
# Then the **signal snapshot** reinforces it:
#
# ```
# Signals detected:
# 10 bundle opportunities
# 15 emerging products
# 4 declining products
# 5 fast-expanding segments
# ```
#
# Executives can understand the entire situation **in about 3 seconds**.
#
# This is exactly what you want.
#
# ---
#
# # 2. Traceability Section
#
# This is one of the strongest parts of your report.
#
# ```
# customers: 200
# transactions: 1824
# product_catalog: 20
# Snapshot timestamp
# ```
#
# This answers questions like:
#
# * How much data did we analyze?
# * Is this analysis fresh?
# * Is the dataset complete?
#
# Adding **data quality notes** makes this even better:
#
# ```
# Retention risk metric not present
# Product margin below threshold
# ```
#
# This prevents misinterpretation of the report.
#
# Most AI systems **never do this**, so this is a big differentiator.
#
# ---
#
# # 3. Numeric Formatting
#
# Huge improvement.
#
# Example:
#
# ```
# $503,600
# $21,557
# $9,200
# ```
#
# Instead of:
#
# ```
# 503600.0
# 21557.14
# 9200.0
# ```
#
# This makes the report feel **business-grade instead of technical**.
#
# Small change, big impact.
#
# ---
#
# # 4. Customer Intelligence Table
#
# This section is very readable now.
#
# ```
# Segment | Customers | Revenue | CLV
# ```
#
# and the retention risk handling is perfect:
#
# ```
# —
# Retention risk not present in dataset
# ```
#
# That avoids the misleading:
#
# ```
# 0.0
# ```
#
# which could imply zero risk.
#
# Excellent handling.
#
# ---
#
# # 5. Feature Intelligence Narrative
#
# The explanatory text you added works very well:
#
# ```
# Feature demand signals are driven by internal usage
# ```
#
# and:
#
# ```
# Strongest combined signal: Feature D
# ```
#
# This helps executives interpret the table quickly.
#
# Without it, the numbers would require interpretation.
#
# ---
#
# # 6. Trend Intelligence Tables
#
# These are much better now because of:
#
# ```
# Product ID + Product Type
# ```
#
# Example:
#
# ```
# P18 | Service | 460
# ```
#
# That gives context.
#
# If your real datasets include **actual product names**, this will become even stronger.
#
# ---
#
# # 7. Top Opportunity Section
#
# This is one of the most important improvements.
#
# ```
# Top opportunity detected
# Software + Hardware
# Enterprise segment
# $9,200 average revenue
# ```
#
# Executives love this format.
#
# It answers:
#
# > "What is the single most important thing we should act on?"
#
# The report now **has a headline insight**, which the original version lacked.
#
# ---
#
# # 8. Revenue Signal Summary
#
# This section is also very effective:
#
# ```
# 10 bundle opportunities
# 135 observed customers
# $900 – $9,200 revenue potential
# ```
#
# This converts discovery into **financial impact**, which is critical for leadership.
#
# ---
#
# # 9. Bundle Table
#
# The bundle table is now much more readable.
#
# Example:
#
# ```
# Software | Hardware | Service
# ```
#
# instead of:
#
# ```
# P03 | P10 | P18
# ```
#
# This removes the cognitive overhead of decoding IDs.
#
# Also good:
#
# ```
# Product C included when present
# ```
#
# Nice touch.
#
# ---
#
# # Minor Things I Would Improve
#
# These are **small refinements**, not problems.
#
# ---
#
# # 1. Product Names vs Product Types
#
# Right now you show:
#
# ```
# Software
# Hardware
# Service
# ```
#
# which appear to be **product categories**, not product names.
#
# Example:
#
# ```
# Software + Hardware
# ```
#
# This is informative but still slightly abstract.
#
# If your product catalog contains names like:
#
# ```
# Revenue Insights
# Customer Analytics Pro
# Automation Suite
# ```
#
# the report would become even stronger.
#
# Example:
#
# ```
# Revenue Insights + Customer Analytics Pro
# ```
#
# Much more strategic.
#
# But this depends on your dataset.
#
# ---
#
# # 2. Growth Percentage Precision
#
# You currently show mixed precision:
#
# ```
# 460
# 428.6
# 361.1
# ```
#
# You might want to standardize:
#
# ```
# 460
# 428.6
# 361.1
# ```
#
# or
#
# ```
# 460.0
# 428.6
# 361.1
# ```
#
# Personally I would keep your current rule:
#
# ```
# whole numbers → no decimal
# others → one decimal
# ```
#
# which your formatter already does.
#
# So this is fine.
#
# ---
#
# # 3. Revenue Range Interpretation
#
# This line is technically correct:
#
# ```
# Average revenue potential: $900 – $9,200 per customer
# ```
#
# But executives might interpret this as:
#
# ```
# expected revenue
# ```
#
# rather than:
#
# ```
# observed bundle revenue range
# ```
#
# If you want to be very precise you could say:
#
# ```
# Observed bundle revenue range: $900 – $9,200 per customer
# ```
#
# This is optional.
#
# ---
#
# # What This Report Demonstrates
#
# Your agent is now doing something quite sophisticated.
#
# It converts raw data into:
#
# ```
# signals
# → prioritized opportunity
# → financial framing
# → executive narrative
# → recommended actions
# ```
#
# That is exactly how **real strategy reports** are structured.
#
# This is no longer just:
#
# ```
# data analysis
# ```
#
# It is now:
#
# ```
# decision intelligence
# ```
#
# ---
#
# # Final Score
#
# For an automated executive report generator:
#
# **9.7 / 10**
#
# Strengths:
#
# * strong narrative structure
# * excellent formatting
# * robust missing-data handling
# * clear top insight
# * financial context
# * actionable next steps
#
# Very few improvements left.
#
# ---
#
# # One Strategic Observation
#
# Your system now follows a pattern used by high-level consulting reports:
#
# ```
# Executive summary
# ↓
# Evidence tables
# ↓
# Key opportunity
# ↓
# Financial implications
# ↓
# Recommended actions
# ```
#
# That is exactly the structure used by firms like **McKinsey, Bain, and BCG**.
#
# You have effectively automated that format.

# %% [markdown]
# ## What’s working well
#
# **One view** — The opening is strong. “**Mixed signals** detected: expansion opportunities alongside declining products and segments to monitor” plus the signal snapshot (10 bundles, 15 emerging, 4 declining, 5 fast-expanding) gives the right framing and scale in a few seconds.
#
# **Traceability and data quality** — Record counts, snapshot time, and the two data quality notes (retention risk absent, margin below threshold) make the run auditable and avoid misreading “no data” as “all clear.”
#
# **Customer table** — Revenue and CLV as `$503,600`, `$21,557`, and “—” for retention risk with the line “Retention risk not present in dataset” is clear and consistent.
#
# **Product intelligence** — The “no high-margin” message with the 25% threshold and the suggestion to review pricing/margin is exactly what you wanted: absence of signal is explained, not left vague.
#
# **Feature section** — The one-line explanation plus “Strongest combined signal: Feature D” before the table makes the feature story obvious.
#
# **Trend tables** — Product column (Service / Hardware / Software) gives context without losing IDs. Growth % is readable (e.g. 460, 428.6, -35).
#
# **Top opportunity** — “**Software** + **Hardware**”, segment Enterprise, 8 customers, $9,200, score 96 works as a single headline takeaway.
#
# **Revenue summary** — “135 observed customers … $900 – $9,200 per customer” turns the bundle list into a clear financial summary.
#
# **Bundle table** — Product A/B/C as names, $ in the revenue column, score-sorted order (96 down to 40), and Product C shown (with blank when missing, e.g. B08) look consistent and executive-ready.
#
# **Next steps** — Three concrete actions in the right order.
#
# ---
#
# ## Small polish (optional)
#
# - **Product C empty cell** — B08, B02, B06, B04, B09 show an empty cell for Product C. You could use “—” there so “no third product” is explicit; it’s a style choice, not a bug.
# - **Segment table revenue** — Revenue % is “30.9” and “27” (one decimal vs integer). You could standardize to one decimal (e.g. “27.0”) for consistency; again optional.
#
# ---
#
# ## Bottom line
#
# The report is in good shape for an executive audience: verdict and snapshot up front, traceability and data quality spelled out, revenue and currency consistent, top opportunity and revenue summary as the strategic hook, and tables that tell the story (product names, $ formatting, clear handling of missing data). The Phase 1 and Enhancement_Ideas_v2 changes are doing what they were meant to do.
