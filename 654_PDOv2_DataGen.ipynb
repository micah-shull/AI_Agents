# %% [markdown]
# <a href="https://colab.research.google.com/github/micah-shull/AI_Agents/blob/main/654_PDOv2_DataGen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📘 Proposal & Document Orchestrator — Version 2 Data Proposal (MVP Expansion)
#
# ## Objective of V2
#
# Version 2 of the Proposal & Document Orchestrator expands the dataset **selectively** to unlock:
#
# * portfolio-level governance views
# * cost-to-outcome attribution
# * bottleneck detection
# * reviewer effectiveness modeling
# * compliance risk scoring
#
# The guiding principle remains:
#
# > **Increase architectural leverage, not raw data volume.**
#
# V2 focuses on adding **cross-cutting analytical dimensions** that enable new orchestration nodes and executive-grade reporting—while keeping the total data footprint small enough to preserve rapid iteration and learning.
#
# ---
#
# ## Design Principles for V2 Data
#
# V2 data additions follow four strict rules:
#
# ### ✅ 1. Architecture First
#
# Each dataset must power at least one new orchestration node or decision system.
#
# ### ✅ 2. Executive Signal Density
#
# Every field should map to:
#
# * risk
# * cost
# * speed
# * quality
# * revenue impact
#
# ### ✅ 3. Joinable, Not Massive
#
# Datasets are small but relational:
#
# * document_id
# * version_id
# * reviewer_id
# * stage_name
#
# drive most analytics.
#
# ### ✅ 4. Audit-Ready
#
# All data supports:
#
# * traceability
# * historical reconstruction
# * escalation logic
# * ROI modeling
#
# ---
#
# # 📊 V1 Datasets Retained in V2
#
# The following V1 datasets are retained unchanged and reused across new V2 nodes:
#
# * `documents.json` — document registry and business intent
# * `document_versions.json` — version lineage and authorship
# * `workflow_stages.json` — lifecycle events and failures
# * `review_events.json` — human approvals and overrides
# * `compliance_checks.json` — policy and legal rule enforcement
# * `cost_tracking.json` — LLM, tooling, and human spend
# * `outcomes.json` — cycle-time deltas and outcome proxies
#
# These continue to represent the **core document production ledger**.
#
# ---
#
# # ➕ New V2 Dataset Additions (Minimal, High-Leverage)
#
# V2 introduces **one to three small new datasets** to unlock significantly richer orchestration behavior.
#
# ---
#
# ## 🆕 1. Reviewer Registry
#
# **File:** `reviewer_registry.json`
#
# **Purpose:**
# Adds economic and governance context to human reviewers.
#
# **Unlocks:**
#
# * cost of review loops
# * escalation valuation
# * legal bottleneck modeling
# * risk authority thresholds
# * reviewer effectiveness scoring
#
# **Fields:**
#
# * reviewer_id
# * role
# * hourly_cost
# * risk_authority_level
# * escalation_threshold
#
# ---
#
# ## 🆕 2. Document Risk Profile
#
# **File:** `document_risk_profile.json`
#
# **Purpose:**
# Pre-classifies documents by regulatory, revenue, and reputational exposure.
#
# **Unlocks:**
#
# * adaptive workflow depth
# * escalation rules
# * compliance strictness tiers
# * CEO alerting thresholds
#
# **Fields:**
#
# * document_id
# * regulatory_risk_level
# * revenue_impact_estimate
# * reputational_risk
# * compliance_intensity
# * executive_visibility
#
# ---
#
# ## 🆕 3. Stage Cost Baselines (Optional)
#
# **File:** `stage_cost_baselines.json`
#
# **Purpose:**
# Defines expected cost/time envelopes for each workflow stage.
#
# **Unlocks:**
#
# * anomaly detection
# * runaway-review alerts
# * cost overruns
# * early escalation triggers
#
# **Fields:**
#
# * stage_name
# * expected_minutes
# * expected_cost_usd
# * variance_threshold_pct
#
# ---
#
# # 🧠 New Analytical Dimensions Enabled in V2
#
# With the retained V1 datasets plus the V2 additions, the orchestrator can now compute:
#
# ### 📈 Portfolio Intelligence
#
# * total hours saved
# * high-risk documents in flight
# * cost by document type
# * priority backlog
# * regulatory exposure map
#
# ---
#
# ### 🚦 Workflow Bottlenecks
#
# * stage failure rates
# * rework frequency
# * override-heavy stages
# * average latency per stage
# * stalled documents
#
# ---
#
# ### ⚖️ Governance & Risk Scoring
#
# * severity-weighted compliance scores
# * open legal blockers
# * override concentration
# * industry risk clusters
# * preventable failure ratios
#
# ---
#
# ### 👥 Reviewer Effectiveness Modeling
#
# * approval rate by role
# * time-to-decision
# * escalation frequency
# * marginal cost of review
# * downstream rework caused/prevented
#
# ---
#
# ### 💰 Cost-to-Outcome Attribution
#
# * cost per approved document
# * wasted spend on rejections
# * ROI proxy ratios
# * marginal value of revisions
# * efficiency rankings
#
# ---
#
# # 🧩 How V2 Data Maps to New Orchestration Nodes
#
# | Node                      | Powered By                       |
# | ------------------------- | -------------------------------- |
# | Portfolio Analysis Node   | documents, outcomes, costs       |
# | Bottleneck Detection Node | workflow_stages, reviews         |
# | Governance Risk Node      | compliance_checks, risk_profiles |
# | Reviewer Analytics Node   | reviews, reviewer_registry       |
# | Cost Attribution Node     | costs, outcomes                  |
# | Escalation Engine         | risk_profiles, baselines         |
#
# ---
#
# # 🎯 Why This Matters in a Portfolio Setting
#
# This V2 data design demonstrates:
#
# * restraint in synthetic data growth
# * thoughtful system evolution
# * executive-driven metrics
# * causal joins across systems
# * governance-first design
# * economic modeling discipline
# * real-world enterprise framing
#
# It positions the agent as:
#
# > **a financial-and-risk control plane for document production—
# > not a writing assistant.**
#
# Which is extremely aligned with the story you’re telling across your orchestrator ecosystem.

# %% [markdown]
# # reviewer_registry.json

# %%
[
  {
    "reviewer_id": "REVIEWER_LEGAL_001",
    "role": "legal",
    "hourly_cost_usd": 180,
    "risk_authority_level": "high",
    "escalation_threshold_severity": "medium",
    "can_block_release": true
  },
  {
    "reviewer_id": "REVIEWER_LEGAL_002",
    "role": "legal",
    "hourly_cost_usd": 175,
    "risk_authority_level": "high",
    "escalation_threshold_severity": "medium",
    "can_block_release": true
  },
  {
    "reviewer_id": "REVIEWER_COMPLIANCE_001",
    "role": "compliance",
    "hourly_cost_usd": 160,
    "risk_authority_level": "high",
    "escalation_threshold_severity": "medium",
    "can_block_release": true
  },
  {
    "reviewer_id": "REVIEWER_SALES_001",
    "role": "sales_manager",
    "hourly_cost_usd": 140,
    "risk_authority_level": "medium",
    "escalation_threshold_severity": "high",
    "can_block_release": false
  },
  {
    "reviewer_id": "REVIEWER_SALES_002",
    "role": "sales_manager",
    "hourly_cost_usd": 135,
    "risk_authority_level": "medium",
    "escalation_threshold_severity": "high",
    "can_block_release": false
  },
  {
    "reviewer_id": "REVIEWER_SALES_003",
    "role": "sales_manager",
    "hourly_cost_usd": 145,
    "risk_authority_level": "medium",
    "escalation_threshold_severity": "high",
    "can_block_release": false
  },
  {
    "reviewer_id": "REVIEWER_ACCOUNT_001",
    "role": "account_manager",
    "hourly_cost_usd": 125,
    "risk_authority_level": "low",
    "escalation_threshold_severity": "critical",
    "can_block_release": false
  },
  {
    "reviewer_id": "REVIEWER_STRATEGY_001",
    "role": "strategy",
    "hourly_cost_usd": 155,
    "risk_authority_level": "medium",
    "escalation_threshold_severity": "high",
    "can_block_release": false
  }
]

# %% [markdown]
# # document_risk_profile.json

# %%
[
  {
    "document_id": "DOC_001",
    "regulatory_risk_level": "medium",
    "revenue_impact_estimate_usd": 450000,
    "reputational_risk": "medium",
    "compliance_intensity": "high",
    "executive_visibility": true,
    "risk_tier": "tier_2"
  },
  {
    "document_id": "DOC_002",
    "regulatory_risk_level": "low",
    "revenue_impact_estimate_usd": 320000,
    "reputational_risk": "medium",
    "compliance_intensity": "medium",
    "executive_visibility": true,
    "risk_tier": "tier_2"
  },
  {
    "document_id": "DOC_003",
    "regulatory_risk_level": "high",
    "revenue_impact_estimate_usd": 0,
    "reputational_risk": "low",
    "compliance_intensity": "high",
    "executive_visibility": false,
    "risk_tier": "tier_3"
  },
  {
    "document_id": "DOC_004",
    "regulatory_risk_level": "high",
    "revenue_impact_estimate_usd": 500000,
    "reputational_risk": "high",
    "compliance_intensity": "high",
    "executive_visibility": true,
    "risk_tier": "tier_3"
  },
  {
    "document_id": "DOC_005",
    "regulatory_risk_level": "low",
    "revenue_impact_estimate_usd": 120000,
    "reputational_risk": "low",
    "compliance_intensity": "low",
    "executive_visibility": false,
    "risk_tier": "tier_1"
  },
  {
    "document_id": "DOC_006",
    "regulatory_risk_level": "high",
    "revenue_impact_estimate_usd": 0,
    "reputational_risk": "medium",
    "compliance_intensity": "high",
    "executive_visibility": true,
    "risk_tier": "tier_3"
  },
  {
    "document_id": "DOC_007",
    "regulatory_risk_level": "medium",
    "revenue_impact_estimate_usd": 275000,
    "reputational_risk": "medium",
    "compliance_intensity": "medium",
    "executive_visibility": false,
    "risk_tier": "tier_2"
  },
  {
    "document_id": "DOC_008",
    "regulatory_risk_level": "low",
    "revenue_impact_estimate_usd": 0,
    "reputational_risk": "low",
    "compliance_intensity": "low",
    "executive_visibility": false,
    "risk_tier": "tier_1"
  },
  {
    "document_id": "DOC_009",
    "regulatory_risk_level": "medium",
    "revenue_impact_estimate_usd": 600000,
    "reputational_risk": "high",
    "compliance_intensity": "high",
    "executive_visibility": true,
    "risk_tier": "tier_3"
  },
  {
    "document_id": "DOC_010",
    "regulatory_risk_level": "medium",
    "revenue_impact_estimate_usd": 180000,
    "reputational_risk": "low",
    "compliance_intensity": "medium",
    "executive_visibility": false,
    "risk_tier": "tier_2"
  }
]

# %% [markdown]
# # stage_cost_baselines.json

# %%
[
  {
    "stage_name": "structure_planning",
    "expected_minutes": 20,
    "expected_cost_usd": 0.40,
    "variance_threshold_pct": 75
  },
  {
    "stage_name": "content_generation",
    "expected_minutes": 45,
    "expected_cost_usd": 2.00,
    "variance_threshold_pct": 60
  },
  {
    "stage_name": "content_revision",
    "expected_minutes": 35,
    "expected_cost_usd": 0.75,
    "variance_threshold_pct": 60
  },
  {
    "stage_name": "human_review",
    "expected_minutes": 15,
    "expected_cost_usd": 30.00,
    "variance_threshold_pct": 50
  },
  {
    "stage_name": "legal_review",
    "expected_minutes": 20,
    "expected_cost_usd": 40.00,
    "variance_threshold_pct": 40
  },
  {
    "stage_name": "policy_validation",
    "expected_minutes": 15,
    "expected_cost_usd": 1.00,
    "variance_threshold_pct": 60
  },
  {
    "stage_name": "compliance_check",
    "expected_minutes": 12,
    "expected_cost_usd": 1.25,
    "variance_threshold_pct": 50
  },
  {
    "stage_name": "quality_check",
    "expected_minutes": 10,
    "expected_cost_usd": 0.50,
    "variance_threshold_pct": 70
  },
  {
    "stage_name": "approval_check",
    "expected_minutes": 8,
    "expected_cost_usd": 0.30,
    "variance_threshold_pct": 75
  },
  {
    "stage_name": "final_review",
    "expected_minutes": 12,
    "expected_cost_usd": 25.00,
    "variance_threshold_pct": 50
  },
  {
    "stage_name": "regulatory_validation",
    "expected_minutes": 18,
    "expected_cost_usd": 35.00,
    "variance_threshold_pct": 40
  }
]
