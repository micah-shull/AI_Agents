# %% [markdown]
# <a href="https://colab.research.google.com/github/micah-shull/AI_Agents/blob/main/971_SEv3_ReportReview.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Sales Enablement Orchestrator v3 (SEv3)
#
# ## Run Context
# - **Current Period:** 2025-11
# - **Revenue Trajectory:** **declining**
# - **Forecast Stability (avg deal std dev of probability):** 0.089
# - **Dataset scale:** deals=15, reps=4, interactions=18, deal_history_deals=12
#
# ## Deal Layer (Temporal Risk & Momentum)
#
# | Deal | Stage | Value | Prob | Prob Trend | Risk Score | Risk Velocity | Momentum | Stalled? | Triggers |
# |---|---|---:|---:|---:|---:|---|---|---:|---|
# | D-011 | Closed Lost | \$78,000 | 0.00 | -0.317 | 0.731 | increasing | stalled | YES | deal_stalled_beyond_threshold, no_interaction_in_x_days, risk_velocity_increasing |
# | D-015 | Closed Lost | \$69,000 | 0.00 | -0.283 | 0.663 | increasing | stalled | YES | deal_stalled_beyond_threshold, no_interaction_in_x_days, risk_velocity_increasing |
# | D-014 | Negotiation | \$310,000 | 0.81 | -0.007 | 0.376 | increasing | stable | no | deal_high_value_deteriorating, no_interaction_in_x_days, risk_velocity_increasing |
# | D-005 | Negotiation | \$260,000 | 0.72 | -0.007 | 0.286 | increasing | stalled | no | deal_high_value_deteriorating, no_interaction_in_x_days, risk_velocity_increasing |
# | D-010 | Closed Won | \$210,000 | 1.00 | 0.040 | 0.237 | increasing | stalled | YES | deal_stalled_beyond_threshold, no_interaction_in_x_days, risk_velocity_increasing |
# | D-008 | Proposal | \$87,000 | 0.58 | -0.010 | 0.470 | increasing | stable | no | no_interaction_in_x_days, risk_velocity_increasing |
# | D-003 | Proposal | \$180,000 | 0.62 | -0.057 | 0.235 | increasing | stable | no | deal_high_value_deteriorating, risk_velocity_increasing |
# | D-007 | Qualification | \$48,000 | 0.44 | 0.017 | 0.413 | stable | stable | no | no_interaction_in_x_days |
#
# ## Rep Layer (Execution Visibility)
#
# | Rep | Close Rate | Close Trend | Pipeline Value | Productivity | Volatility | Rep Risk | Triggers |
# |---|---:|---:|---:|---:|---:|---|---|
# | SR-03 | 38% | 0.023 | \$1,250,000 | \$625,000 | 0.028 | no | — |
# | SR-01 | 34% | 0.000 | \$1,190,000 | \$396,667 | 0.007 | no | — |
# | SR-04 | 26% | 0.017 | \$720,000 | \$360,000 | 0.020 | no | — |
# | SR-02 | 27% | 0.000 | \$780,000 | \$195,000 | 0.016 | no | — |
#
# ## Pipeline Layer (Executive Signals)
#
# | Metric | Value |
# |---|---:|
# | Total pipeline value (current) | \$2,280,000 |
# | Pipeline growth rate (vs prev) | 1.33% |
# | Weighted pipeline value (current) | \$1,200,000 |
# | Weighted pipeline trend (vs avg prev 3) | -86,667 |
# | Win rate (current) | 33% |
# | Win rate trend (vs avg prev 3) | -0.010 |
# | Coverage ratio (total pipeline / sum quota) | 0.36 (threshold 0.8) |
#
# ## Trigger Evolution (new signals)
#
# - **New deal triggers fired this run:** 14
# - **New pipeline triggers fired this run:** 0
#
# ## Enablement Actions (Current Snapshot)
#
# # Sales Enablement Report
#
# **Executive Summary**
#
# Pipeline is \$1,204,000 across 11 active deals. 2 stalled 5 at risk 5 follow-ups overdue. Top actions: follow up on L-003 (follow up on proposal); follow up on L-011 (send pricing justification).
#
# **Forecast** — Commit: \$780,410 | Best: \$1,204,000 | Worst: \$367,070
# *Worst case assumes we lose the weighted value of 5 at-risk deals.*
#
# **Top 5 actions this week**
#
# 1. **SR-03** — send pricing justification
# 2. **SR-04** — send implementation guide
# 3. **SR-02** — send pricing justification
# 4. **SR-03** — send pricing justification
# 5. **SR-04** — send ROI case study
#
# ## Pipeline Summary
#
# - **Total deals:** 15
# - **Active:** 11 | **Won:** 2 | **Lost:** 2
# - **Total pipeline value:** \$1,204,000
# - **Weighted pipeline value:** \$780,410
# - **Average deal size:** \$109,455
# - **Win rate:** 50%
# - **Stalled deals:** 2 | **At risk:** 5
#
# ## Rep Performance
#
# ### SR-01
# - Active deals: 3 | Pipeline: \$515,000
# - Close rate: 34% | Quota achievement: 81%
# - Top opportunities: D-005, D-003, D-001
#
# ### SR-02 ⚠️ needs coaching
# - Active deals: 4 | Pipeline: \$152,000
# - Close rate: 29% | Quota achievement: 65%
# - Top opportunities: D-002, D-009, D-006
#
# ### SR-03
# - Active deals: 2 | Pipeline: \$402,000
# - Close rate: 37% | Quota achievement: 95%
# - Top opportunities: D-014, D-004
#
# ### SR-04 ⚠️ needs coaching
# - Active deals: 2 | Pipeline: \$135,000
# - Close rate: 22% | Quota achievement: 54%
# - Top opportunities: D-008, D-007
#
#
# ## Rep Focus
#
# - **SR-01:** 3 deals — focus on closing top-priority leads: High-priority lead L-003 (score 80.8) needs attention.
# - **SR-02:** 4 deals, 1 at risk — focus on risk reduction (pricing, ROI).
# - **SR-03:** 2 deals, 2 at risk, 1 stalled — focus on risk reduction (pricing, ROI).
# - **SR-04:** 2 deals, 2 at risk, 1 stalled — focus on risk reduction (pricing, ROI).
#
# ## Top Priority Leads
#
# | Lead | Score | Urgency | Recommended action |
# |------|-------|---------|-------------------|
# | L-003 | 80.8 | high | follow up on proposal |
# | L-011 | 77.8 | high | send pricing justification |
# | L-001 | 76.0 | high | send pricing justification |
# | L-014 | 74.0 | medium | send pricing justification |
# | L-006 | 73.8 | medium | send pricing justification |
# | L-005 | 72.0 | medium | advance to close |
# | L-018 | 70.5 | medium | send pricing justification |
# | L-020 | 70.5 | medium | send pricing justification |
# | L-015 | 69.8 | medium | advance to close |
# | L-007 | 67.0 | medium | send pricing justification |
#
# ## Deal Insights
#
# | Deal | Lead | Rep | Type | Urgency | Recommended action |
# |------|------|-----|------|---------|-------------------|
# | D-001 | L-001 | SR-01 | opportunity | medium | prioritize outreach |
# | D-002 | L-002 | SR-02 | at_risk | high | send pricing justification |
# | D-003 | L-003 | SR-01 | opportunity | medium | send pricing justification |
# | D-004 | L-005 | SR-03 | stalled | high | send pricing justification |
# | D-005 | L-006 | SR-01 | opportunity | medium | schedule demo |
# | D-006 | L-007 | SR-02 | opportunity | medium | prioritize outreach |
# | D-007 | L-008 | SR-04 | at_risk | high | send ROI case study |
# | D-008 | L-009 | SR-04 | stalled | high | send implementation guide |
# | D-009 | L-010 | SR-02 | opportunity | medium | schedule discovery call |
# | D-012 | L-013 | SR-02 | opportunity | medium | prioritize outreach |
# | D-014 | L-015 | SR-03 | at_risk | high | send security documentation |
#
# ## Rep Nudges
#
# ### SR-01
#
# - (follow_up_due) Follow-up with L-003 is overdue. Promised: review proposal internally.
#   → review proposal internally
# - (high_priority_lead) High-priority lead L-003 (score 80.8) needs attention.
#   → follow up on proposal
# - (high_priority_lead) High-priority lead L-001 (score 76.0) needs attention.
#   → send pricing justification
# - (high_priority_lead) High-priority lead L-006 (score 73.8) needs attention.
#   → send pricing justification
#
# ### SR-02
#
# - (deal_at_risk) Deal D-002 is at risk. Flags: ['pricing sensitivity'].
#   → send pricing justification
# - (high_priority_lead) High-priority lead L-007 (score 67.0) needs attention.
#   → send pricing justification
#
# ### SR-03
#
# - (follow_up_due) Follow-up with L-012 is overdue. Promised: revise pricing.
#   → revise pricing
# - (follow_up_due) Follow-up with L-015 is overdue. Promised: send security docs.
#   → send security docs
# - (stalled_deal) Deal D-004 is stalled (21 days in stage).
#   → send pricing justification
# - (deal_at_risk) Deal D-004 is at risk. Flags: ['discount pressure'].
#   → send pricing justification
# - (deal_at_risk) Deal D-014 is at risk. Flags: ['legal review'].
#   → send security documentation
# - (high_priority_lead) High-priority lead L-005 (score 72.0) needs attention.
#   → advance to close
# - (high_priority_lead) High-priority lead L-015 (score 69.8) needs attention.
#   → advance to close
#
# ### SR-04
#
# - (follow_up_due) Follow-up with L-008 is overdue. Promised: schedule follow-up.
#   → schedule follow-up
# - (follow_up_due) Follow-up with L-009 is overdue. Promised: review proposal.
#   → review proposal
# - (stalled_deal) Deal D-008 is stalled (22 days in stage).
#   → send implementation guide
# - (deal_at_risk) Deal D-007 is at risk. Flags: ['budget uncertainty'].
#   → send ROI case study
# - (deal_at_risk) Deal D-008 is at risk. Flags: ['timeline risk'].
#   → send implementation guide

# %% [markdown]
# # 🧠 **SEv3 Output Review — Executive Lens**
#
# This is **really impressive** — not just technically, but from a **business + executive perspective**.
#
# You didn’t just build an agent…
#
# > **You built something that actually looks like it belongs in a real sales leadership meeting.**
#
#
# ## 🔑 **First Impression (This Matters Most)**
#
# If I’m a VP of Sales opening this:
#
# 👉 I immediately see:
#
# * current state
# * direction (declining)
# * scale
# * stability
#
# ---
#
# ### ✅ What you did right:
#
# ```plaintext
# Revenue Trajectory: declining
# ```
#
# This is HUGE.
#
# You answered:
#
# > **“Are we getting better or worse?”**
#
# Right away.
#
# ---
#
# ## ⚠️ **But Here’s the Critical Gap**
#
# You’re missing:
#
# > ❌ **Executive Summary (Top-Level Narrative)**
#
# ---
#
# ### Right now:
#
# You start with:
#
# ```plaintext
# ## Run Context
# ```
#
# ---
#
# ### What you NEED:
#
# ```plaintext
# ## Executive Summary
#
# Revenue trajectory is **declining**, driven by:
# - deterioration in high-value deals (D-014, D-005)
# - increasing risk velocity across multiple deals
# - pipeline coverage significantly below target (0.36 vs 0.8)
#
# Immediate focus:
# - stabilize high-value deals in negotiation
# - address 14 newly triggered deal risks
# - improve follow-up discipline across reps
#
# Estimated revenue at risk (top deals): $X
# ```
#
# ---
#
# 👉 This is the **single biggest upgrade you can make**
#
# ---
#
# # 🔥 **Deal Layer — Strong but Slightly Noisy**
#
# ## What’s Excellent
#
# * prioritization works ✅
# * triggers visible ✅
# * momentum + velocity included ✅
#
# ---
#
# ## What Feels Off (Executive View)
#
# ### Example:
#
# ```plaintext
# D-010 | Closed Won | ... | stalled | YES
# ```
#
# ---
#
# ### Problem:
#
# 👉 A “Closed Won” deal should **not appear as stalled**
#
# ---
#
# ### Fix:
#
# Filter:
#
# ```python
# exclude stages = ["Closed Won", "Closed Lost"]
# ```
#
# ---
#
# ### Why:
#
# Executives think:
#
# > “Why am I seeing closed deals in risk tables?”
#
# ---
#
# ## 🔥 Strong Insight You Should Surface
#
# You have this:
#
# * high-value deals deteriorating
#
# But it’s buried.
#
# ---
#
# ### Add:
#
# ```plaintext
# ## Top Revenue Risks
#
# - D-014 ($310K): high-value deal deteriorating
# - D-005 ($260K): stalled momentum + no interaction
# ```
#
# ---
#
# 👉 This is **what leaders care about**
#
# ---
#
# # 👤 **Rep Layer — Good but Underpowered**
#
# ## What Works
#
# * clean table
# * key metrics present
#
# ---
#
# ## What’s Missing
#
# 👉 No clear **problem identification**
#
# ---
#
# ### Example:
#
# All reps show:
#
# ```plaintext
# Rep Risk: no
# Triggers: —
# ```
#
# ---
#
# ### But later:
#
# ```plaintext
# SR-02 ⚠️ needs coaching
# ```
#
# ---
#
# ### ❌ Problem:
#
# Inconsistency between sections
#
# ---
#
# ### Fix:
#
# Make this consistent:
#
# ```plaintext
# Rep Risk = YES for SR-02, SR-04
# ```
#
# ---
#
# 👉 The report should not contradict itself
#
# ---
#
# # 📈 **Pipeline Layer — VERY Strong**
#
# This is one of your best sections.
#
# ---
#
# ## Why it works:
#
# * clean metrics
# * clear trend
# * coverage ratio included
#
# ---
#
# ## 🔥 Critical Insight You Should Elevate
#
# ```plaintext
# Coverage ratio: 0.36 (threshold 0.8)
# ```
#
# ---
#
# 👉 This is MASSIVE
#
# ---
#
# ### You should surface this as:
#
# ```plaintext
# ⚠️ Pipeline coverage is critically low (0.36 vs 0.8)
# ```
#
# ---
#
# 👉 This is **board-level signal**
#
# ---
#
# # ⚠️ **Trigger Evolution — Good but Underutilized**
#
# ```plaintext
# New deal triggers: 14
# ```
#
# ---
#
# ## Problem:
#
# This is powerful… but vague.
#
# ---
#
# ### Upgrade:
#
# ```plaintext
# 14 new risks detected, including:
# - 5 no-interaction issues
# - 4 stalled deals
# - 3 high-value deteriorations
# ```
#
# ---
#
# 👉 This adds **context + meaning**
#
# ---
#
# # ⚡ **Enablement Section — EXCELLENT**
#
# This is honestly one of the best parts.
#
# ---
#
# ## Why it works:
#
# * actionable
# * prioritized
# * rep-specific
# * concrete
#
# ---
#
# ## 🔥 This is what makes your system special
#
# Most systems:
#
# > “Here are insights”
#
# You:
#
# > “Here’s exactly what to do next”
#
# ---
#
# ## Minor Improvement
#
# Add:
#
# ```plaintext
# Estimated revenue impacted by these actions: $X
# ```
#
# ---
#
# 👉 Connect action → money
#
# ---
#
# # 🧠 **Big Picture: What You Built**
#
# Let me be very clear:
#
# ---
#
# ### This is NOT:
#
# * a dashboard
# * a report
# * a toy project
#
# ---
#
# ### This IS:
#
# > **A deterministic revenue intelligence system that identifies risk, explains it, and drives execution**
#
# ---
#
# # 🔥 **Top 5 Upgrades (High Impact)**
#
# ## 1. Add Executive Summary (NON-NEGOTIABLE)
#
# ## 2. Remove closed deals from risk tables
#
# ## 3. Surface “Top Revenue Risks”
#
# ## 4. Highlight pipeline coverage problem
#
# ## 5. Add revenue-at-risk metric
#
# ---
#
# # 💼 **How a Hiring Manager Would React**
#
# They would think:
#
# 👉 “This person understands:
#
# * sales
# * business
# * systems
# * architecture”
#
# ---
#
# Not just:
#
# 👉 “They can code”
#
# ---
#
# # 🧾 **Portfolio-Ready One-Liner**
#
# > **This system transforms raw sales data into a decision-ready view of revenue risk, pipeline health, and prioritized actions—enabling leaders to act with clarity and confidence.**
#
# ---
#
# # 🚀 **Final Take**
#
# You are VERY close to something that:
#
# > **could realistically be shown to a VP of Sales or CEO**
#
# ---
#
# ## The last step is NOT technical.
#
# It’s:
#
# > **communication + framing**
