# %% [markdown]
# <a href="https://colab.research.google.com/github/micah-shull/AI_Agents/blob/main/369_Results.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![sentiment_by_department.png](data:image/png;base64,...)

# %% [markdown]
# ![ideas_by_department.png](data:image/png;base64,...)

# %% [markdown]
# ![issues_by_department.png](data:image/png;base64,...)

# %% [markdown]
# # Employee Feedback Intelligence Report
#
# ## Executive Summary
#
# The recent employee feedback analysis reveals a concerning overall sentiment, with 60% of the 70 responses highlighting negative experiences primarily related to operational inefficiencies. The top critical issues include the inability of pick time goals to adjust during order volume spikes, overwhelming Drive-Up order backlogs, and the Guest Service desk being inundated with simultaneous demands. Key opportunities for improvement include automating self-checkout issue logging, enhancing backroom labeling, and separating Drive-Up prep from regular fulfillment. To address these challenges, we recommend prioritizing resource allocation during peak hours and implementing suggested process improvements to enhance operational efficiency and employee satisfaction.
#
# ---
#
# ## Overall Statistics
#
# - **Total Feedback:** 70
# - **Total Issues:** 42
# - **Total Ideas:** 28
# - **Departments:** Fulfillment Expert, General Merchandise Expert, Guest Advocate
#
# ## Sentiment Analysis
#
# - **Overall Sentiment:** negative
# - **Positive:** 9
# - **Neutral:** 44
# - **Negative:** 17
# - **Average Intensity:** 0.49
#
# ## Top Priority Issues
#
# ### 1. Priority Score: 79.5
#
# **Department:** Fulfillment Expert
#
# **Feedback:** Pick time goals don’t adjust when order volume spikes. It feels impossible to keep up during peak hours.
#
# **Rationale:** High frequency theme (32 occurrences) | operational issue requiring attention
#
# ### 2. Priority Score: 79.5
#
# **Department:** Guest Advocate
#
# **Feedback:** Drive-Up orders pile up during peak hours and we don’t always have enough people scheduled to keep wait times reasonable. Guests get frustrated and we take the blame.
#
# **Rationale:** High frequency theme (32 occurrences) | operational issue requiring attention
#
# ### 3. Priority Score: 79.5
#
# **Department:** Guest Advocate
#
# **Feedback:** Guest Service desk gets overwhelmed when returns, pickups, and questions all hit at once. It feels understaffed for the workload.
#
# **Rationale:** High frequency theme (14 occurrences) | operational issue requiring attention
#
# ### 4. Priority Score: 78.0
#
# **Department:** Fulfillment Expert
#
# **Feedback:** INF pressure feels high even when issues are caused by inventory errors outside our control.
#
# **Rationale:** High frequency theme (14 occurrences) | operational issue requiring attention
#
# ### 5. Priority Score: 78.0
#
# **Department:** Guest Advocate
#
# **Feedback:** Training for new Guest Advocates feels rushed. New team members aren’t confident handling issues and it slows the whole front end.
#
# **Rationale:** High frequency theme (32 occurrences) | operational issue requiring attention
#
# ### 6. Priority Score: 73.5
#
# **Department:** Fulfillment Expert
#
# **Feedback:** Zebra devices freeze or lose connection frequently, which slows picking and causes missed goals.
#
# **Rationale:** High frequency theme (32 occurrences) | operational issue requiring attention
#
# ### 7. Priority Score: 73.5
#
# **Department:** Fulfillment Expert
#
# **Feedback:** Items are often not located where the system says they are, leading to wasted time and INF issues.
#
# **Rationale:** High frequency theme (32 occurrences) | operational issue requiring attention
#
# ### 8. Priority Score: 73.5
#
# **Department:** Fulfillment Expert
#
# **Feedback:** During heavy SFS days, packing stations back up and slow everything downstream.
#
# **Rationale:** High frequency theme (32 occurrences) | operational issue requiring attention
#
# ### 9. Priority Score: 73.5
#
# **Department:** Fulfillment Expert
#
# **Feedback:** We often run out of packing supplies during busy days, which slows down shipping.
#
# **Rationale:** High frequency theme (32 occurrences) | operational issue requiring attention
#
# ### 10. Priority Score: 73.5
#
# **Department:** Fulfillment Expert
#
# **Feedback:** Backroom locations change without clear communication, making items hard to find.
#
# **Rationale:** High frequency theme (12 occurrences) | operational issue requiring attention
#
# ## Top Priority Ideas
#
# ### 1. Priority Score: 63.5
#
# **Department:** Guest Advocate
#
# **Feedback:** If self-checkout issues were logged automatically when machines go down, fixes might happen faster.
#
# **Rationale:** High frequency theme (32 occurrences) | improvement idea with potential impact
#
# ### 2. Priority Score: 56.8
#
# **Department:** Fulfillment Expert
#
# **Feedback:** Better labeling in the backroom would reduce time spent searching for items.
#
# **Rationale:** High frequency theme (32 occurrences) | improvement idea with potential impact
#
# ### 3. Priority Score: 56.8
#
# **Department:** Fulfillment Expert
#
# **Feedback:** Separating Drive-Up prep from regular fulfillment could improve speed for both.
#
# **Rationale:** High frequency theme (32 occurrences) | improvement idea with potential impact
#
# ### 4. Priority Score: 56.8
#
# **Department:** Fulfillment Expert
#
# **Feedback:** A daily fulfillment volume forecast posted at the start of the shift would help us plan better.
#
# **Rationale:** High frequency theme (28 occurrences) | improvement idea with potential impact
#
# ### 5. Priority Score: 56.8
#
# **Department:** Fulfillment Expert
#
# **Feedback:** Reducing task switching within a single shift would improve accuracy and speed.
#
# **Rationale:** High frequency theme (32 occurrences) | improvement idea with potential impact
#
# ### 6. Priority Score: 56.8
#
# **Department:** General Merchandise Expert
#
# **Feedback:** Improved backstock labeling would save time when pulling items for the floor.
#
# **Rationale:** High frequency theme (32 occurrences) | improvement idea with potential impact
#
# ### 7. Priority Score: 56.8
#
# **Department:** General Merchandise Expert
#
# **Feedback:** Posting upcoming layout changes ahead of time would help us prepare better.
#
# **Rationale:** High frequency theme (32 occurrences) | improvement idea with potential impact
#
# ### 8. Priority Score: 56.8
#
# **Department:** General Merchandise Expert
#
# **Feedback:** Setting realistic staffing levels based on workload would improve presentation.
#
# **Rationale:** High frequency theme (28 occurrences) | improvement idea with potential impact
#
# ### 9. Priority Score: 56.8
#
# **Department:** General Merchandise Expert
#
# **Feedback:** Sharing feedback after transitions would help us understand what went well and what to improve.
#
# **Rationale:** High frequency theme (11 occurrences) | improvement idea with potential impact
#
# ### 10. Priority Score: 50.0
#
# **Department:** Fulfillment Expert
#
# **Feedback:** Smarter pick path grouping by department could reduce walking time significantly.
#
# **Rationale:** High frequency theme (32 occurrences) | improvement idea with potential impact
#
# ## Visualizations
#
# - **Issues By Department:** `output/employee_feedback/charts/issues_by_department.png`
# - **Ideas By Department:** `output/employee_feedback/charts/ideas_by_department.png`
# - **Sentiment By Department:** `output/employee_feedback/charts/sentiment_by_department.png`
# - **Top Issues:** `output/employee_feedback/charts/top_issues.png`
# - **Top Ideas:** `output/employee_feedback/charts/top_ideas.png`
#
# ## Department Summaries
#
# ### Fulfillment Expert
#
# Employee feedback from the Fulfillment Expert department reveals significant challenges related to operational efficiency, particularly during peak hours, with concerns over system reliability, training adequacy, and order prioritization. The overall sentiment is predominantly neutral, with a notable number of negative comments highlighting issues such as device malfunctions, congestion in backroom aisles, and inefficient order batching. Key areas requiring immediate attention include improving technology reliability, enhancing training for new team members, and streamlining communication and processes to better manage order fulfillment during high-demand periods.
#
# ### General Merchandise Expert
#
# Employee feedback from the General Merchandise Expert department reveals significant challenges related to resource allocation and communication, particularly regarding priority shifts, inventory accuracy, and layout changes. The overall sentiment is neutral, with a notable portion of negative feedback highlighting difficulties in maintaining zoning standards and product presentation due to staffing constraints and frequent interruptions. Key areas for attention include improving inventory management, enhancing communication about layout changes, and ensuring adequate staffing during peak hours to support core tasks and guest service.
#
# ### Guest Advocate
#
# Employee feedback from the Guest Advocate department reveals significant challenges related to staffing during peak hours, particularly for Drive-Up and Guest Service operations, leading to increased guest frustration and longer wait times. The overall sentiment is predominantly neutral, with notable concerns regarding inadequate training for new team members and communication breakdowns between departments. Key areas requiring immediate attention include optimizing staffing schedules, enhancing training programs, and improving the functionality and clarity of self-checkout systems to better serve guests during high-volume periods.

# %% [markdown]
# ![top_issues.png](data:image/png;base64,...)

# %% [markdown]
# ![top_ideas.png](data:image/png;base64,...)
