# %% [markdown]
# <a href="https://colab.research.google.com/github/micah-shull/AI_Agents/blob/main/375_EFIA_Employee_Feedback_Intelligence_Agent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![sentiment_by_department.png](data:image/png;base64,...)

# %% [markdown]
# # Employee Feedback Intelligence Agent
#
# ### Turning Frontline Insight into Better Decisions — Faster
#
# ### 🗣️ **Employee Message**
#
# > We’re launching a new way for employees to share feedback and ideas directly with leadership.
# >
# > This isn’t a survey. It’s not tied to performance reviews. And it’s not about finding fault with individuals.
# >
# > **Issues** help us understand where systems, staffing, or processes are getting in the way of good work. These are reviewed in aggregate.
# >
# > **Ideas** help us improve how things run. If you choose to include your name, we can recognize great ideas and follow up when appropriate.
# >
# > The goal is simple:
# > **Fix problems sooner. Learn faster. And recognize good thinking when we see it.**
#
# ## The Problem This Solves (In One Sentence)
#
# Leaders make decisions every day without a clear, unbiased view of what frontline employees actually experience — and valuable insights are lost before they ever reach management.
#
# This agent fixes that.
#
# ---
#
# ## The Big Idea
#
# Every employee sees things leadership can’t.
#
# They see:
#
# * Where systems slow work down
# * Where guests get frustrated
# * Which processes don’t work in real life
# * What small changes would make their jobs easier and the store run better
#
# The problem isn’t a lack of insight.
#
# The problem is **signal loss**.
#
# Employee feedback:
#
# * Gets buried in conversations
# * Gets filtered as it moves up
# * Gets remembered only when something breaks
#
# By the time patterns become visible, the cost is already paid — in frustration, turnover, guest experience, or lost efficiency.
#
# This agent creates a **direct, structured line from frontline reality to leadership decisions** — without noise, blame, or overwhelm.
#
# ---
#
# ## What This Agent Actually Does
#
# In simple terms, it turns unstructured employee feedback into **clear priorities, trends, and actions** leadership can use immediately.
#
# Think of it as:
#
# > *A weekly “health report” for how work is really happening on the floor.*
#
# ---
#
# ## How It Works (Without the Tech Jargon)
#
# ### 1️⃣ Makes it easy and safe for employees to speak up
#
# Employees submit feedback through a simple Google Form:
#
# * Choose their department
# * Select whether they’re sharing:
#
#   * an **issue**, or
#   * an **idea**
# * Describe it in their own words
#
# No long surveys.
# No tracking individuals.
# No pressure.
#
# This encourages honesty — and better input.
#
# ---
#
# ### 2️⃣ Turns raw feedback into patterns (not noise)
#
# Instead of leaders reading dozens of comments, the agent:
#
# * Groups similar feedback together
# * Identifies recurring themes
# * Separates one-off complaints from real patterns
#
# What rises to the top isn’t volume — it’s **consistency**.
#
# ---
#
# ### 3️⃣ Prioritizes what actually matters
#
# Not all feedback deserves equal attention.
#
# The agent helps answer:
#
# * “What’s affecting the most people right now?”
# * “Which issues are creating the most friction?”
# * “Where would a small fix have a big impact?”
#
# This turns feedback into **decision-ready priorities**, not opinions.
#
# ---
#
# ### 4️⃣ Translates insight into clear, actionable recommendations
#
# For top issues and ideas, the agent generates:
#
# * Concrete actions to take
# * Who should own them
# * The expected impact
#
# This removes the common gap between:
#
# > “This is interesting”
# > and
# > “Here’s what we’re going to do.”
#
# ---
#
# ### 5️⃣ Shows trends before problems escalate
#
# Because feedback is tracked over time, leaders can see:
#
# * Issues increasing or declining
# * Whether changes are actually helping
# * New problems emerging early
#
# This allows leadership to act **before issues become crises**.
#
# ---
#
# ## What Leaders Get (At a Glance)
#
# Each report provides:
#
# * A clear executive summary
# * Top issues and ideas, ranked by impact
# * Department-level insights
# * Actionable recommendations
# * Simple charts that make patterns obvious
#
# A manager can understand the full picture in **minutes**, not hours.
#
# ---
#
# ## Why This Is Valuable to *Your Manager*
#
# This tool directly supports what good managers already want to do — but makes it easier.
#
# It helps your manager:
#
# * Spot problems earlier
# * Prioritize fairly and confidently
# * Back decisions with real employee input
# * Reduce surprises
# * Have better conversations with leadership and teams
#
# Instead of reacting to individual complaints, she can respond to **validated patterns**.
#
# ---
#
# ## Why This Is Valuable to the Organization
#
# At the organizational level, this agent:
#
# * Reduces friction and inefficiency
# * Improves employee engagement and trust
# * Surfaces ideas that improve operations
# * Shortens the learning loop between decision and impact
#
# Most importantly, it helps the organization **learn faster than its problems grow**.
#
# ---
#
# ## What This Is *Not*
#
# This is not:
#
# * A complaint box
# * A performance evaluation tool
# * A disciplinary system
# * A replacement for leadership judgment
#
# It is a **decision-support tool** — designed to inform, not dictate.
#
# ---
#
# ## How We Start (Low Risk, High Learning)
#
# This doesn’t require a big rollout.
#
# We start small:
#
# * One Google Form
# * One weekly report
# * One pilot group
#
# Within weeks, we’ll be able to answer:
#
# * What employees care about most
# * Where systems are breaking down
# * Which ideas are worth testing
#
# If it delivers value, it scales naturally.
# If it doesn’t, we’ve learned cheaply.
#
# ---
#
# ## The Core Value Proposition (One Line)
#
# > *This agent gives leadership a clear, honest view of frontline reality — and turns it into action — without adding noise, risk, or overhead.*

# %% [markdown]
# ![issues_by_department.png](data:image/png;base64,...)

# %% [markdown]
# ![issues_trends.png](data:image/png;base64,...)

# %% [markdown]
# # Why Google Forms Is the Right Starting Point
#
# ### Simple, Secure, and Designed for Trust *and* Recognition
#
# For this system to work, employee feedback must be:
#
# * Easy to submit
# * Safe to share
# * Fairly attributed when appropriate
# * Low effort to maintain
#
# Google Forms allows us to balance **privacy, accountability, and recognition** — without introducing new tools or risk.
#
# ---
#
# ## The Real Design Goal: Privacy *and* Incentives
#
# There are **two types of feedback**, and they deserve different treatment:
#
# * **Issues** → protect anonymity to encourage honesty
# * **Ideas** → allow ownership so great ideas can be recognized and rewarded
#
# Google Forms lets us do exactly that — intentionally.
#
# ---
#
# ## A Graduated Feedback Model (By Design)
#
# Instead of a one-size-fits-all approach, the system uses **graduated identity capture**, depending on feedback type.
#
# ### 🔹 Issue Submissions: Protected by Default
#
# For operational issues:
#
# * No required name field
# * Focus stays on the problem, not the person
# * Encourages candid feedback without fear
#
# This ensures we surface real friction points early — before they escalate.
#
# ---
#
# ### 🔹 Idea Submissions: Ownership Enabled
#
# For improvement ideas:
#
# * Name is **optional but encouraged**
# * Employees can choose to attach their name
# * Makes recognition, follow-up, and rewards possible
#
# This allows leadership to:
#
# * Credit the right people
# * Highlight great thinking
# * Reinforce a culture of innovation
#
# > This is not about accountability for mistakes —
# > it’s accountability for *great ideas*.
#
# ---
#
# ## Why This Balance Matters
#
# Most systems fail because they choose **one extreme**:
#
# * Fully anonymous → no recognition
# * Fully attributed → lower honesty
#
# This design gives us **the best of both worlds**:
#
# * Safety where it matters
# * Ownership where it adds value
#
# And because it’s implemented at the form level, it’s:
#
# * Transparent
# * Intentional
# * Easy to explain to employees
#
# ---
#
# ## Addressing the Big Question Up Front: “Will This Be Used Against People?”
#
# No — and this is critical.
#
# This system is explicitly **not** designed for:
#
# * Performance management
# * Discipline
# * Individual evaluation
#
# Instead:
#
# * Issues are aggregated and anonymized
# * Ideas are credited and celebrated
# * Leadership looks for patterns, not people
#
# This distinction should be clearly communicated in the form introduction.
#
# ---
#
# ## Google Forms Privacy & Security (Why This Is Still Safe)
#
# Using Google Forms means:
#
# * Data stays inside the company’s Google environment
# * Access is controlled by existing permissions
# * No third-party vendors
# * No new compliance risk
#
# Even with name capture for ideas:
#
# * Only authorized managers can view responses
# * Data is not shared outside leadership
# * Visibility is intentional and limited
#
# This is the same infrastructure already trusted for internal workflows.
#
# ---
#
# ## Why Google Forms Works Operationally
#
# ### 🟢 Easy for employees
#
# * Familiar interface
# * Works on phones and store devices
# * Takes under 2 minutes
#
# ### 🟢 Easy for managers
#
# * No new software
# * No setup overhead
# * No training required
#
# ### 🟢 Easy to evolve
#
# * Fields can be adjusted
# * Name capture can be tightened or relaxed
# * Categories can change as the organization learns
#
# ---
#
# ## Framing This for Your Manager (One Sentence)
#
# > “Issues stay anonymous so people are honest; ideas can be attributed so great thinking gets recognized — Google Forms lets us do both safely.”
#
# ---
#
# ## What Leadership Gains From This Approach
#
# * Honest operational insight
# * Actionable improvement ideas
# * Clear recognition for innovation
# * Higher engagement from employees
# * Lower risk than traditional surveys
#
# And most importantly:
#
# > **Better decisions, grounded in reality.**
#
# ---
#
# ## The Bigger Picture
#
# Google Forms isn’t the product — it’s the **on-ramp**.
#
# If the pilot proves valuable:
#
# * Recognition programs can be layered in
# * Dashboards can be added
# * Automation can grow naturally
#
# But today, this lets us start learning immediately — with trust intact.

# %% [markdown]
# ![top_issues.png](data:image/png;base64,...)

# %% [markdown]
# # Employee Feedback Intelligence
#
# ## Practical Rollout Package
#
# ---
#
# ## 1️⃣ Google Form Layout (Exact Structure)
#
# This is the **actual form design**, not a concept sketch. Simple, fast, and intentional.
#
# ---
#
# ### 📝 **Form Title**
#
# **Employee Feedback & Ideas**
#
# **Subtitle (optional):**
# Help us improve how work gets done — your input matters.
#
# ---
#
# ### 📌 **Form Introduction (Short)**
#
# > This form is a safe space to share what’s working, what isn’t, and ideas that could make our work better.
# >
# > Issues are reviewed in aggregate. Ideas can be recognized and followed up on if you choose to include your name.
# >
# > Thank you for helping us improve together.
#
# ---
#
# ### 🔹 **Question 1: Department**
#
# **What area do you work in?**
# *(Required — dropdown)*
#
# Absolutely — this is a great instinct. Making this **concrete and recognizable** is exactly what will help your manager picture this working in the real world.
#
# Below is a **clean, professional version** you can drop straight into the notebook under the Google Form section. I’ve kept it simple, realistic, and non-technical, while still signaling thoughtfulness and scale.
#
# ---
#
# ### 🔹 **Question 1: Department**
#
# **What area do you work in?**
# *(Required — dropdown)*
#
# * Guest Advocate
# * Front of Store Attendant
# * General Merchandise Expert
# * Inbound Expert
# * Presentation Expert
# * Style Consultant
# * Beauty Consultant
# * Tech Consultant
# * Food & Beverage Expert
# * Food Service Expert
# * Starbucks Barista
# * Fulfillment Expert
# * Human Resources Expert
# * Target Security Specialist
# * Closing Expert
# * Other / Support
#
# ---
#
# ### 🔹 **Question 2: Type of Feedback**
#
# **What kind of feedback are you sharing?**
# *(Required — multiple choice)*
#
# * 🚨 Issue that needs attention
# * 💡 Idea to improve something
#
# 👉 This question controls what appears next.
#
# ---
#
# ### 🔹 **Question 3: Feedback Description**
#
# **Please describe your issue or idea in your own words.**
# *(Required — paragraph)*
#
# > There’s no right or wrong answer. Just explain it as clearly as you can.
#
# ---
#
# ### 🔹 **Question 4 (Conditional): Name for Idea Recognition**
#
# **(Only shown if “Idea” is selected)**
#
# **Would you like to include your name so we can recognize or follow up on this idea?**
# *(Optional — short answer)*
#
# > Leaving this blank is okay.
# > Including your name allows us to credit great ideas and follow up if needed.
#
# ---
#
# ### 🔹 **Question 5 (Optional): Anything Else**
#
# **Any additional context you’d like to share?**
# *(Optional — paragraph)*
#
# ---
#
# ### ✅ **Submit Button**
#
# “Submit Feedback”
#
# ---
#
# ## 2️⃣ Employee-Facing Intro Message (This Is Huge)
#
# This is what builds trust. This should appear **at the top of the form** and be shared verbally by managers.
#
# ---
#
# ### 🗣️ **Employee Message**
#
# > We’re launching a new way for employees to share feedback and ideas directly with leadership.
# >
# > This isn’t a survey. It’s not tied to performance reviews. And it’s not about finding fault with individuals.
# >
# > **Issues** help us understand where systems, staffing, or processes are getting in the way of good work. These are reviewed in aggregate.
# >
# > **Ideas** help us improve how things run. If you choose to include your name, we can recognize great ideas and follow up when appropriate.
# >
# > The goal is simple:
# > **Fix problems sooner. Learn faster. And recognize good thinking when we see it.**
#
# ---
#
# ## 3️⃣ “How Ideas Get Recognized” Flow
#
# This is critical for adoption. People need to believe ideas don’t disappear.
#
# ---
#
# ### 💡 **Idea Recognition Workflow**
#
# 1. **Idea Submitted**
#
#    * Employee submits an idea through the form
#    * Name included (optional)
#
# 2. **Idea Reviewed**
#
#    * Ideas are reviewed weekly as part of the feedback report
#    * High-impact ideas are flagged automatically
#
# 3. **Idea Evaluated**
#
#    * Leadership evaluates feasibility and impact
#    * No idea is judged on polish — only substance
#
# 4. **Recognition & Follow-Up**
#
#    * If a named idea is selected:
#
#      * Employee is acknowledged
#      * Follow-up conversation happens if needed
#      * Recognition can be:
#
#        * Verbal acknowledgment
#        * Team mention
#        * Manager recognition
#        * Pilot ownership (where appropriate)
#
# > The goal is not rewards for everything —
# > it’s **visibility and appreciation for good thinking**.
#
# ---
#
# ## 4️⃣ Manager One-Pager: Guardrails & Intent
#
# This is what protects the system long-term.
#
# ---
#
# ### 📄 **For Managers: How This Tool Is Meant to Be Used**
#
# **Purpose**
#
# * Identify operational friction early
# * Surface improvement ideas
# * Support better decisions with real input
#
# **This Tool Is NOT**
#
# * A performance evaluation system
# * A disciplinary tool
# * A way to track individuals for complaints
#
# **How to Read the Reports**
#
# * Look for patterns, not single comments
# * Focus on themes across teams
# * Use insights to prioritize fixes, not assign blame
#
# **Handling Identity**
#
# * Issues are anonymous by design
# * Names on ideas are voluntary
# * Recognition is encouraged; attribution is respectful
#
# **What Builds Trust**
#
# * Acting on repeated issues
# * Closing the loop when ideas are implemented
# * Communicating changes clearly
#
# > If employees see action, participation will grow.
# > If they don’t, participation will fade.
