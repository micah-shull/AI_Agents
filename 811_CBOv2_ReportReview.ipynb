# %% [markdown]
# <a href="https://colab.research.google.com/github/micah-shull/AI_Agents/blob/main/811_CBOv2_ReportReview.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Cross-Business Customer Intelligence Orchestrator (CBOv2)
#
# **Verdict: 1 expansion opportunity.**
#
# ## Executive Summary
#
# - **Purpose**: Detect deterministic, explainable cross-business risk and expansion signals across Finance, Retail, and Healthcare before they appear in financial statements.
# - **Run: 2026-03-02 21:06:21 UTC | improve_001 | Data: 3 customers, 3 finance, 3 retail, 3 healthcare signals.**
#
# - **Recommendation: Review C003 for targeted expansion or cross-sell.**
#
# - **Method**: All signals derived from configurable, rule-based thresholds. No probabilistic scoring used.
#
# ## Portfolio Rollup (90d view)
#
# - **Total customers analyzed**: 3
# - **Customers with coordinated deterioration (≥2 domains)**: 0 (0.0%)
# - **Customers with coordinated expansion (≥2 domains)**: 1 (33.3%)
# - **Traceability**: Run: 2026-03-02 21:06:21 UTC | improve_001 | Data: 3 customers, 3 finance, 3 retail, 3 healthcare signals.
#
# ## Executive Triggers Fired
#
# - **expansion_momentum**: opportunity — 33.3% of customers show coordinated expansion across ≥2 domains (threshold 10%).
#
# ## Top Accelerating Risk Trajectories
#
# - No customers in accelerating risk in this run.
#
# ## Top Accelerating Growth Trajectories
#
# - **Customer C003** — positive in 2 domains
#
# ## Run Metadata
#
# - **Run ID**: improve_001
# - **Timestamp**: 2026-03-02 21:06:21 UTC
# - **Config version**: 2.0
# - **Finance window**: 90 / 180 d
# - **Retail window**: 30 / 90 d
# - **Healthcare window**: 90 / 180 d
#
# ## Thresholds & Parameters (for auditability)
#
# - **Deterioration slope threshold**: -0.15
# - **Improvement slope threshold**: 0.1
# - **Min negative domains for risk alignment**: 2
# - **Min positive domains for expansion alignment**: 2
# - **Portfolio negative alignment trigger (pct ≥)**: 10%
# - **Portfolio positive alignment trigger (pct ≥)**: 10%

# %% [markdown]
# This report is *working* — and more importantly, it’s already **executive-legible + auditable**.
#
# You’ve successfully implemented the “trust is engineered” pattern:
#
# * deterministic method statement ✅
# * run metadata ✅
# * thresholds visible ✅
# * trigger references its threshold ✅
# * recommendation is clear ✅
#
# If you shipped this as v2, you’d be ahead of most “agent” demos.
#
# Here are the **highest-leverage improvements** (tightening, not rewrites).
#
# ---
#
# ## What’s strong (keep as-is)
#
# ### 1) The opening verdict + recommendation
#
# This is exactly how executives read:
#
# * Verdict (what happened)
# * Recommendation (what to do)
#
# ### 2) “Method” line
#
# That one sentence is a differentiator. Keep it.
#
# ### 3) Traceability + run metadata + thresholds
#
# This is your moat. It’s not “extra”; it’s the product.
#
# ---
#
# ## Tighten the executive narrative (small edits)
#
# ### A) Remove repeated “Run / Data” line (it appears twice)
#
# Right now this appears in:
#
# * Executive Summary (Run line)
# * Portfolio Rollup (Traceability line)
#
# Pick one place.
#
# **Recommendation:** Keep it in **Run Metadata** and make Executive Summary lighter.
#
# What execs want at the top is:
#
# * verdict
# * recommendation
# * why it matters
#
# Traceability belongs in metadata.
#
# ---
#
# ### B) Fix the “Top Accelerating…” language (you’re not calculating acceleration yet)
#
# Your report says:
#
# * “Top Accelerating Growth Trajectories”
# * “Top Accelerating Risk Trajectories”
#
# But your current ranking is based on **domain counts**, not acceleration.
#
# Two options:
#
# **Option 1 (best for now): rename**
#
# * “Top Cross-Business Risk Trajectories”
# * “Top Cross-Business Growth Trajectories”
#
# **Option 2 (v2.5+): implement true acceleration**
# Only use “accelerating” once you store prior run or compute slope-of-slope.
#
# ---
#
# ### C) Make the trigger line consistent with config language
#
# You wrote:
#
# > threshold 10%
#
# Nice. If you want it airtight, say:
#
# * “(portfolio trigger: pct ≥ 10%)”
#
# This matches your parameter naming and reduces ambiguity.
#
# ---
#
# ## Improve clarity with one extra line (high value)
#
# ### Add a “Coverage” statement (optional, but executive-friendly)
#
# Since you now track validation warnings and counts, add:
#
# * **Coverage**: Finance ✓ Retail ✓ Healthcare ✓ (3/3 customers with signals)
#
# This becomes important when real data is messy.
#
# ---
#
# ## Micro-formatting improvements (polish)
#
# ### 1) Executive Summary bullets
#
# Right now you have blank lines between bullets, which can read “floaty.”
#
# A tighter block reads more “board memo.”
#
# ### 2) Percent formatting
#
# You did this well. Keep it.
#
# ### 3) Consistent casing
#
# * “Data: 3 customers…” is fine, but keep it consistent across sections or move it to metadata only.
#
# ---
#
# ## Suggested “v2 report layout” (minimal changes)
#
# If you want the cleanest executive scan, structure it like this:
#
# 1. **Verdict**
# 2. **Recommendation**
# 3. **What changed / What it means** (1–2 bullets)
# 4. **Portfolio Rollup**
# 5. **Triggers**
# 6. **Top lists**
# 7. **Run Metadata**
# 8. **Thresholds**
# 9. **Validation Warnings** (only if present)
#
# That keeps the “CEO narrative” separate from audit appendices.
#
# ---
#
# ## One final thought: the report is already doing the most important job
#
# It answers, in order:
#
# * What is happening? ✅
# * So what? ✅
# * What should we do? ✅
# * Can we trust it? ✅
# * Under what rules? ✅
#
# That is the whole executive intelligence ladder in one page.
