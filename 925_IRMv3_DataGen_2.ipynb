# %% [markdown]
# <a href="https://colab.research.google.com/github/micah-shull/AI_Agents/blob/main/925_IRMv3_DataGen_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
[
  {
    "integration_id": "crm_salesforce",
    "system_name": "Salesforce CRM",
    "integration_type": "crm",
    "owning_team": "Revenue Operations",
    "schema_version": "v4.2",
    "sla_uptime": 99.9,
    "auth_expiry": "2026-05-15",
    "latency_p95_ms": 240,
    "fallback_available": false
  },
  {
    "integration_id": "email_sendgrid",
    "system_name": "SendGrid Email API",
    "integration_type": "messaging",
    "owning_team": "Platform Engineering",
    "schema_version": "v3.1",
    "sla_uptime": 99.5,
    "auth_expiry": "2026-04-02",
    "latency_p95_ms": 410,
    "fallback_available": true
  },
  {
    "integration_id": "llm_provider_openai",
    "system_name": "OpenAI API",
    "integration_type": "ai_model_provider",
    "owning_team": "AI Platform",
    "schema_version": "v2.7",
    "sla_uptime": 99.7,
    "auth_expiry": "2026-06-20",
    "latency_p95_ms": 520,
    "fallback_available": true
  },
  {
    "integration_id": "erp_netsuite",
    "system_name": "NetSuite ERP",
    "integration_type": "erp",
    "owning_team": "Finance Systems",
    "schema_version": "v5.0",
    "sla_uptime": 99.3,
    "auth_expiry": "2026-03-25",
    "latency_p95_ms": 310,
    "fallback_available": false
  },
  {
    "integration_id": "document_ai",
    "system_name": "Document AI Processing",
    "integration_type": "document_processing",
    "owning_team": "AI Platform",
    "schema_version": "v1.9",
    "sla_uptime": 98.9,
    "auth_expiry": "2026-04-18",
    "latency_p95_ms": 460,
    "fallback_available": false
  },
  {
    "integration_id": "zendesk",
    "system_name": "Zendesk Support Platform",
    "integration_type": "customer_support",
    "owning_team": "Customer Experience",
    "schema_version": "v3.4",
    "sla_uptime": 99.6,
    "auth_expiry": "2026-06-01",
    "latency_p95_ms": 280,
    "fallback_available": false
  },
  {
    "integration_id": "marketing_hubspot",
    "system_name": "HubSpot Marketing Platform",
    "integration_type": "marketing_platform",
    "owning_team": "Marketing Ops",
    "schema_version": "v4.1",
    "sla_uptime": 99.4,
    "auth_expiry": "2026-05-05",
    "latency_p95_ms": 350,
    "fallback_available": false
  },
  {
    "integration_id": "data_warehouse_snowflake",
    "system_name": "Snowflake Data Warehouse",
    "integration_type": "data_platform",
    "owning_team": "Data Engineering",
    "schema_version": "v7.2",
    "sla_uptime": 99.8,
    "auth_expiry": "2026-07-10",
    "latency_p95_ms": 180,
    "fallback_available": false
  },
  {
    "integration_id": "ats_greenhouse",
    "system_name": "Greenhouse ATS",
    "integration_type": "hr_platform",
    "owning_team": "HR Systems",
    "schema_version": "v2.6",
    "sla_uptime": 99.2,
    "auth_expiry": "2026-05-28",
    "latency_p95_ms": 330,
    "fallback_available": false
  },
  {
    "integration_id": "payments_stripe",
    "system_name": "Stripe Payments API",
    "integration_type": "payments",
    "owning_team": "Payments Infrastructure",
    "schema_version": "v6.3",
    "sla_uptime": 99.7,
    "auth_expiry": "2026-06-14",
    "latency_p95_ms": 210,
    "fallback_available": true
  }
]

# %% [markdown]
# # dependency_graph.json

# %%
[
  {
    "source_component": "agent_sales_outreach",
    "target_component": "crm_salesforce",
    "dependency_type": "data_sync",
    "criticality": "high",
    "failover_available": false,
    "shared_dependency_group": "crm_systems"
  },
  {
    "source_component": "agent_sales_outreach",
    "target_component": "email_sendgrid",
    "dependency_type": "communication_api",
    "criticality": "high",
    "failover_available": true,
    "shared_dependency_group": "email_delivery"
  },
  {
    "source_component": "agent_sales_outreach",
    "target_component": "llm_provider_openai",
    "dependency_type": "ai_generation",
    "criticality": "medium",
    "failover_available": true,
    "shared_dependency_group": "llm_services"
  },
  {
    "source_component": "agent_invoice_processing",
    "target_component": "erp_netsuite",
    "dependency_type": "financial_system",
    "criticality": "high",
    "failover_available": false,
    "shared_dependency_group": "erp_systems"
  },
  {
    "source_component": "agent_invoice_processing",
    "target_component": "document_ai",
    "dependency_type": "document_processing",
    "criticality": "high",
    "failover_available": false,
    "shared_dependency_group": "document_services"
  },
  {
    "source_component": "agent_invoice_processing",
    "target_component": "llm_provider_openai",
    "dependency_type": "ai_generation",
    "criticality": "medium",
    "failover_available": true,
    "shared_dependency_group": "llm_services"
  },
  {
    "source_component": "agent_customer_support",
    "target_component": "zendesk",
    "dependency_type": "ticket_platform",
    "criticality": "high",
    "failover_available": false,
    "shared_dependency_group": "support_platforms"
  },
  {
    "source_component": "agent_customer_support",
    "target_component": "llm_provider_openai",
    "dependency_type": "ai_generation",
    "criticality": "medium",
    "failover_available": true,
    "shared_dependency_group": "llm_services"
  },
  {
    "source_component": "agent_marketing_analytics",
    "target_component": "data_warehouse_snowflake",
    "dependency_type": "data_query",
    "criticality": "high",
    "failover_available": false,
    "shared_dependency_group": "data_platform"
  },
  {
    "source_component": "agent_marketing_analytics",
    "target_component": "marketing_hubspot",
    "dependency_type": "campaign_data",
    "criticality": "medium",
    "failover_available": false,
    "shared_dependency_group": "marketing_platforms"
  },
  {
    "source_component": "agent_inventory_forecasting",
    "target_component": "data_warehouse_snowflake",
    "dependency_type": "data_query",
    "criticality": "high",
    "failover_available": false,
    "shared_dependency_group": "data_platform"
  },
  {
    "source_component": "agent_inventory_forecasting",
    "target_component": "erp_netsuite",
    "dependency_type": "inventory_sync",
    "criticality": "high",
    "failover_available": false,
    "shared_dependency_group": "erp_systems"
  },
  {
    "source_component": "agent_hr_screening",
    "target_component": "ats_greenhouse",
    "dependency_type": "candidate_data",
    "criticality": "medium",
    "failover_available": false,
    "shared_dependency_group": "hr_platforms"
  },
  {
    "source_component": "agent_hr_screening",
    "target_component": "llm_provider_openai",
    "dependency_type": "ai_analysis",
    "criticality": "low",
    "failover_available": true,
    "shared_dependency_group": "llm_services"
  },
  {
    "source_component": "agent_financial_reporting",
    "target_component": "erp_netsuite",
    "dependency_type": "financial_data",
    "criticality": "high",
    "failover_available": false,
    "shared_dependency_group": "erp_systems"
  },
  {
    "source_component": "agent_financial_reporting",
    "target_component": "data_warehouse_snowflake",
    "dependency_type": "data_query",
    "criticality": "high",
    "failover_available": false,
    "shared_dependency_group": "data_platform"
  },
  {
    "source_component": "agent_contract_review",
    "target_component": "document_ai",
    "dependency_type": "document_processing",
    "criticality": "high",
    "failover_available": false,
    "shared_dependency_group": "document_services"
  },
  {
    "source_component": "agent_contract_review",
    "target_component": "llm_provider_openai",
    "dependency_type": "ai_analysis",
    "criticality": "medium",
    "failover_available": true,
    "shared_dependency_group": "llm_services"
  },
  {
    "source_component": "agent_product_feedback",
    "target_component": "data_warehouse_snowflake",
    "dependency_type": "data_query",
    "criticality": "medium",
    "failover_available": false,
    "shared_dependency_group": "data_platform"
  },
  {
    "source_component": "agent_product_feedback",
    "target_component": "llm_provider_openai",
    "dependency_type": "ai_analysis",
    "criticality": "medium",
    "failover_available": true,
    "shared_dependency_group": "llm_services"
  },
  {
    "source_component": "agent_fraud_detection",
    "target_component": "payments_stripe",
    "dependency_type": "transaction_data",
    "criticality": "high",
    "failover_available": false,
    "shared_dependency_group": "payment_systems"
  },
  {
    "source_component": "agent_fraud_detection",
    "target_component": "data_warehouse_snowflake",
    "dependency_type": "data_query",
    "criticality": "high",
    "failover_available": false,
    "shared_dependency_group": "data_platform"
  }
]

# %% [markdown]
# # integration_health_logs.json

# %%
[
  {
    "integration_id": "crm_salesforce",
    "timestamp": "2026-03-01T08:00:00Z",
    "uptime_percent": 99.92,
    "latency_ms": 230,
    "error_rate_percent": 0.4,
    "schema_mismatch_events": 0,
    "auth_failures": 0
  },
  {
    "integration_id": "email_sendgrid",
    "timestamp": "2026-03-01T08:00:00Z",
    "uptime_percent": 99.6,
    "latency_ms": 420,
    "error_rate_percent": 1.2,
    "schema_mismatch_events": 1,
    "auth_failures": 0
  },
  {
    "integration_id": "llm_provider_openai",
    "timestamp": "2026-03-01T08:00:00Z",
    "uptime_percent": 99.7,
    "latency_ms": 520,
    "error_rate_percent": 0.9,
    "schema_mismatch_events": 0,
    "auth_failures": 0
  },
  {
    "integration_id": "erp_netsuite",
    "timestamp": "2026-03-01T08:00:00Z",
    "uptime_percent": 99.2,
    "latency_ms": 340,
    "error_rate_percent": 1.7,
    "schema_mismatch_events": 0,
    "auth_failures": 0
  },
  {
    "integration_id": "document_ai",
    "timestamp": "2026-03-01T08:00:00Z",
    "uptime_percent": 98.7,
    "latency_ms": 470,
    "error_rate_percent": 3.2,
    "schema_mismatch_events": 2,
    "auth_failures": 0
  },
  {
    "integration_id": "zendesk",
    "timestamp": "2026-03-01T08:00:00Z",
    "uptime_percent": 99.5,
    "latency_ms": 290,
    "error_rate_percent": 0.8,
    "schema_mismatch_events": 0,
    "auth_failures": 0
  },
  {
    "integration_id": "marketing_hubspot",
    "timestamp": "2026-03-01T08:00:00Z",
    "uptime_percent": 99.4,
    "latency_ms": 360,
    "error_rate_percent": 1.1,
    "schema_mismatch_events": 0,
    "auth_failures": 0
  },
  {
    "integration_id": "data_warehouse_snowflake",
    "timestamp": "2026-03-01T08:00:00Z",
    "uptime_percent": 99.85,
    "latency_ms": 190,
    "error_rate_percent": 0.2,
    "schema_mismatch_events": 0,
    "auth_failures": 0
  },
  {
    "integration_id": "ats_greenhouse",
    "timestamp": "2026-03-01T08:00:00Z",
    "uptime_percent": 99.1,
    "latency_ms": 330,
    "error_rate_percent": 1.9,
    "schema_mismatch_events": 0,
    "auth_failures": 0
  },
  {
    "integration_id": "payments_stripe",
    "timestamp": "2026-03-01T08:00:00Z",
    "uptime_percent": 99.75,
    "latency_ms": 210,
    "error_rate_percent": 0.6,
    "schema_mismatch_events": 0,
    "auth_failures": 0
  },

  {
    "integration_id": "crm_salesforce",
    "timestamp": "2026-03-08T08:00:00Z",
    "uptime_percent": 99.88,
    "latency_ms": 250,
    "error_rate_percent": 0.6,
    "schema_mismatch_events": 0,
    "auth_failures": 0
  },
  {
    "integration_id": "email_sendgrid",
    "timestamp": "2026-03-08T08:00:00Z",
    "uptime_percent": 99.3,
    "latency_ms": 510,
    "error_rate_percent": 2.3,
    "schema_mismatch_events": 1,
    "auth_failures": 0
  },
  {
    "integration_id": "llm_provider_openai",
    "timestamp": "2026-03-08T08:00:00Z",
    "uptime_percent": 99.65,
    "latency_ms": 610,
    "error_rate_percent": 1.4,
    "schema_mismatch_events": 0,
    "auth_failures": 0
  },
  {
    "integration_id": "erp_netsuite",
    "timestamp": "2026-03-08T08:00:00Z",
    "uptime_percent": 99.0,
    "latency_ms": 380,
    "error_rate_percent": 2.5,
    "schema_mismatch_events": 1,
    "auth_failures": 0
  },
  {
    "integration_id": "document_ai",
    "timestamp": "2026-03-08T08:00:00Z",
    "uptime_percent": 98.2,
    "latency_ms": 520,
    "error_rate_percent": 4.6,
    "schema_mismatch_events": 3,
    "auth_failures": 1
  },
  {
    "integration_id": "zendesk",
    "timestamp": "2026-03-08T08:00:00Z",
    "uptime_percent": 99.4,
    "latency_ms": 310,
    "error_rate_percent": 1.0,
    "schema_mismatch_events": 0,
    "auth_failures": 0
  },
  {
    "integration_id": "marketing_hubspot",
    "timestamp": "2026-03-08T08:00:00Z",
    "uptime_percent": 99.2,
    "latency_ms": 390,
    "error_rate_percent": 1.5,
    "schema_mismatch_events": 0,
    "auth_failures": 0
  },
  {
    "integration_id": "data_warehouse_snowflake",
    "timestamp": "2026-03-08T08:00:00Z",
    "uptime_percent": 99.8,
    "latency_ms": 200,
    "error_rate_percent": 0.3,
    "schema_mismatch_events": 0,
    "auth_failures": 0
  },
  {
    "integration_id": "ats_greenhouse",
    "timestamp": "2026-03-08T08:00:00Z",
    "uptime_percent": 98.9,
    "latency_ms": 360,
    "error_rate_percent": 2.4,
    "schema_mismatch_events": 0,
    "auth_failures": 0
  },
  {
    "integration_id": "payments_stripe",
    "timestamp": "2026-03-08T08:00:00Z",
    "uptime_percent": 99.7,
    "latency_ms": 220,
    "error_rate_percent": 0.8,
    "schema_mismatch_events": 0,
    "auth_failures": 0
  }
]

# %% [markdown]
# # dependency_incidents.json

# %%
[
  {
    "incident_id": "inc_001",
    "timestamp": "2026-02-20T10:12:00Z",
    "dependency_component": "email_sendgrid",
    "affected_agents": [
      "agent_sales_outreach"
    ],
    "affected_workflows": [
      "wf_sales_prospecting",
      "wf_sales_followup_sequences"
    ],
    "incident_type": "api_outage",
    "severity": "medium",
    "resolution_time_minutes": 48
  },
  {
    "incident_id": "inc_002",
    "timestamp": "2026-02-24T16:35:00Z",
    "dependency_component": "erp_netsuite",
    "affected_agents": [
      "agent_invoice_processing",
      "agent_financial_reporting"
    ],
    "affected_workflows": [
      "wf_invoice_erp_entry",
      "wf_financial_summary_generation"
    ],
    "incident_type": "system_unavailable",
    "severity": "high",
    "resolution_time_minutes": 95
  },
  {
    "incident_id": "inc_003",
    "timestamp": "2026-02-27T08:22:00Z",
    "dependency_component": "document_ai",
    "affected_agents": [
      "agent_invoice_processing",
      "agent_contract_review"
    ],
    "affected_workflows": [
      "wf_invoice_extraction",
      "wf_contract_clause_analysis"
    ],
    "incident_type": "processing_errors",
    "severity": "high",
    "resolution_time_minutes": 140
  },
  {
    "incident_id": "inc_004",
    "timestamp": "2026-03-02T13:18:00Z",
    "dependency_component": "llm_provider_openai",
    "affected_agents": [
      "agent_sales_outreach",
      "agent_customer_support",
      "agent_contract_review",
      "agent_product_feedback"
    ],
    "affected_workflows": [
      "wf_sales_prospecting",
      "wf_response_drafting",
      "wf_contract_clause_analysis",
      "wf_feedback_sentiment_analysis"
    ],
    "incident_type": "latency_spike",
    "severity": "medium",
    "resolution_time_minutes": 36
  },
  {
    "incident_id": "inc_005",
    "timestamp": "2026-03-04T09:41:00Z",
    "dependency_component": "data_warehouse_snowflake",
    "affected_agents": [
      "agent_marketing_analytics",
      "agent_inventory_forecasting",
      "agent_product_feedback",
      "agent_financial_reporting"
    ],
    "affected_workflows": [
      "wf_campaign_performance_analysis",
      "wf_demand_forecasting",
      "wf_feedback_topic_clustering",
      "wf_financial_summary_generation"
    ],
    "incident_type": "query_timeout",
    "severity": "high",
    "resolution_time_minutes": 82
  },
  {
    "incident_id": "inc_006",
    "timestamp": "2026-03-06T11:07:00Z",
    "dependency_component": "crm_salesforce",
    "affected_agents": [
      "agent_sales_outreach"
    ],
    "affected_workflows": [
      "wf_sales_prospecting"
    ],
    "incident_type": "authentication_failure",
    "severity": "medium",
    "resolution_time_minutes": 27
  },
  {
    "incident_id": "inc_007",
    "timestamp": "2026-03-07T15:54:00Z",
    "dependency_component": "payments_stripe",
    "affected_agents": [
      "agent_fraud_detection"
    ],
    "affected_workflows": [
      "wf_transaction_monitoring"
    ],
    "incident_type": "api_degradation",
    "severity": "medium",
    "resolution_time_minutes": 44
  },
  {
    "incident_id": "inc_008",
    "timestamp": "2026-03-08T18:11:00Z",
    "dependency_component": "document_ai",
    "affected_agents": [
      "agent_invoice_processing"
    ],
    "affected_workflows": [
      "wf_invoice_extraction"
    ],
    "incident_type": "schema_mismatch",
    "severity": "high",
    "resolution_time_minutes": 63
  }
]

# %% [markdown]
# # risk_signals.json

# %%
[
  {
    "risk_id": "risk_001",
    "risk_type": "integration_instability",
    "source_system": "document_ai",
    "severity": "high",
    "detected_timestamp": "2026-03-08T18:30:00Z",
    "affected_agents": [
      "agent_invoice_processing",
      "agent_contract_review"
    ],
    "affected_workflows": [
      "wf_invoice_extraction",
      "wf_contract_clause_analysis"
    ],
    "status": "open"
  },
  {
    "risk_id": "risk_002",
    "risk_type": "dependency_concentration",
    "source_system": "data_warehouse_snowflake",
    "severity": "medium",
    "detected_timestamp": "2026-03-05T12:00:00Z",
    "affected_agents": [
      "agent_marketing_analytics",
      "agent_inventory_forecasting",
      "agent_product_feedback",
      "agent_financial_reporting"
    ],
    "affected_workflows": [
      "wf_campaign_performance_analysis",
      "wf_demand_forecasting",
      "wf_feedback_topic_clustering",
      "wf_financial_summary_generation"
    ],
    "status": "open"
  },
  {
    "risk_id": "risk_003",
    "risk_type": "authentication_expiry",
    "source_system": "erp_netsuite",
    "severity": "medium",
    "detected_timestamp": "2026-03-10T09:10:00Z",
    "affected_agents": [
      "agent_invoice_processing",
      "agent_financial_reporting"
    ],
    "affected_workflows": [
      "wf_invoice_erp_entry",
      "wf_financial_summary_generation"
    ],
    "status": "open"
  },
  {
    "risk_id": "risk_004",
    "risk_type": "latency_degradation",
    "source_system": "llm_provider_openai",
    "severity": "medium",
    "detected_timestamp": "2026-03-08T08:20:00Z",
    "affected_agents": [
      "agent_sales_outreach",
      "agent_customer_support",
      "agent_contract_review",
      "agent_product_feedback"
    ],
    "affected_workflows": [
      "wf_sales_prospecting",
      "wf_response_drafting",
      "wf_contract_clause_analysis",
      "wf_feedback_sentiment_analysis"
    ],
    "status": "open"
  },
  {
    "risk_id": "risk_005",
    "risk_type": "automation_value_leakage",
    "source_system": "agent_invoice_processing",
    "severity": "high",
    "detected_timestamp": "2026-03-09T14:00:00Z",
    "affected_agents": [
      "agent_invoice_processing"
    ],
    "affected_workflows": [
      "wf_invoice_extraction",
      "wf_invoice_erp_entry"
    ],
    "status": "open"
  },
  {
    "risk_id": "risk_006",
    "risk_type": "workflow_failure_rate",
    "source_system": "agent_customer_support",
    "severity": "medium",
    "detected_timestamp": "2026-03-07T16:45:00Z",
    "affected_agents": [
      "agent_customer_support"
    ],
    "affected_workflows": [
      "wf_response_drafting"
    ],
    "status": "open"
  },
  {
    "risk_id": "risk_007",
    "risk_type": "data_pipeline_dependency",
    "source_system": "data_warehouse_snowflake",
    "severity": "medium",
    "detected_timestamp": "2026-03-06T11:30:00Z",
    "affected_agents": [
      "agent_inventory_forecasting",
      "agent_product_feedback"
    ],
    "affected_workflows": [
      "wf_demand_forecasting",
      "wf_feedback_topic_clustering"
    ],
    "status": "open"
  },
  {
    "risk_id": "risk_008",
    "risk_type": "financial_system_dependency",
    "source_system": "erp_netsuite",
    "severity": "high",
    "detected_timestamp": "2026-03-06T12:00:00Z",
    "affected_agents": [
      "agent_invoice_processing",
      "agent_financial_reporting"
    ],
    "affected_workflows": [
      "wf_invoice_erp_entry",
      "wf_financial_summary_generation"
    ],
    "status": "open"
  }
]

# %% [markdown]
# # remediation_actions.json

# %%
[
  {
    "remediation_id": "rem_001",
    "risk_id": "risk_001",
    "assigned_owner": "AI Platform Team",
    "assigned_date": "2026-03-08",
    "due_date": "2026-03-15",
    "status": "in_progress",
    "resolution_date": null,
    "days_open": 6,
    "missed_deadline_flag": false
  },
  {
    "remediation_id": "rem_002",
    "risk_id": "risk_002",
    "assigned_owner": "Data Engineering",
    "assigned_date": "2026-03-05",
    "due_date": "2026-03-20",
    "status": "in_progress",
    "resolution_date": null,
    "days_open": 9,
    "missed_deadline_flag": false
  },
  {
    "remediation_id": "rem_003",
    "risk_id": "risk_003",
    "assigned_owner": "Finance Systems",
    "assigned_date": "2026-03-10",
    "due_date": "2026-03-18",
    "status": "open",
    "resolution_date": null,
    "days_open": 4,
    "missed_deadline_flag": false
  },
  {
    "remediation_id": "rem_004",
    "risk_id": "risk_004",
    "assigned_owner": "AI Platform Team",
    "assigned_date": "2026-03-08",
    "due_date": "2026-03-14",
    "status": "in_progress",
    "resolution_date": null,
    "days_open": 6,
    "missed_deadline_flag": false
  },
  {
    "remediation_id": "rem_005",
    "risk_id": "risk_005",
    "assigned_owner": "Finance Automation",
    "assigned_date": "2026-03-09",
    "due_date": "2026-03-12",
    "status": "open",
    "resolution_date": null,
    "days_open": 7,
    "missed_deadline_flag": true
  },
  {
    "remediation_id": "rem_006",
    "risk_id": "risk_006",
    "assigned_owner": "Customer Experience Engineering",
    "assigned_date": "2026-03-07",
    "due_date": "2026-03-14",
    "status": "resolved",
    "resolution_date": "2026-03-12",
    "days_open": 5,
    "missed_deadline_flag": false
  },
  {
    "remediation_id": "rem_007",
    "risk_id": "risk_007",
    "assigned_owner": "Data Engineering",
    "assigned_date": "2026-03-06",
    "due_date": "2026-03-16",
    "status": "in_progress",
    "resolution_date": null,
    "days_open": 8,
    "missed_deadline_flag": false
  },
  {
    "remediation_id": "rem_008",
    "risk_id": "risk_008",
    "assigned_owner": "Finance Systems",
    "assigned_date": "2026-03-06",
    "due_date": "2026-03-13",
    "status": "open",
    "resolution_date": null,
    "days_open": 9,
    "missed_deadline_flag": true
  }
]

# %% [markdown]
# # task_execution_logs.json

# %%
[
  {
    "run_id": "run_2026_03_01",
    "workflow_id": "wf_sales_prospecting",
    "agent_id": "agent_sales_outreach",
    "execution_duration_minutes": 12,
    "human_intervention": false,
    "failure_flag": false,
    "latency_ms": 520,
    "throughput": 780
  },
  {
    "run_id": "run_2026_03_01",
    "workflow_id": "wf_sales_followup_sequences",
    "agent_id": "agent_sales_outreach",
    "execution_duration_minutes": 15,
    "human_intervention": false,
    "failure_flag": false,
    "latency_ms": 500,
    "throughput": 1180
  },
  {
    "run_id": "run_2026_03_01",
    "workflow_id": "wf_invoice_extraction",
    "agent_id": "agent_invoice_processing",
    "execution_duration_minutes": 22,
    "human_intervention": true,
    "failure_flag": false,
    "latency_ms": 470,
    "throughput": 410
  },
  {
    "run_id": "run_2026_03_01",
    "workflow_id": "wf_invoice_erp_entry",
    "agent_id": "agent_invoice_processing",
    "execution_duration_minutes": 18,
    "human_intervention": true,
    "failure_flag": false,
    "latency_ms": 340,
    "throughput": 395
  },
  {
    "run_id": "run_2026_03_01",
    "workflow_id": "wf_ticket_classification",
    "agent_id": "agent_customer_support",
    "execution_duration_minutes": 9,
    "human_intervention": false,
    "failure_flag": false,
    "latency_ms": 300,
    "throughput": 880
  },
  {
    "run_id": "run_2026_03_01",
    "workflow_id": "wf_response_drafting",
    "agent_id": "agent_customer_support",
    "execution_duration_minutes": 14,
    "human_intervention": true,
    "failure_flag": false,
    "latency_ms": 310,
    "throughput": 560
  },
  {
    "run_id": "run_2026_03_01",
    "workflow_id": "wf_campaign_performance_analysis",
    "agent_id": "agent_marketing_analytics",
    "execution_duration_minutes": 30,
    "human_intervention": false,
    "failure_flag": false,
    "latency_ms": 210,
    "throughput": 48
  },
  {
    "run_id": "run_2026_03_01",
    "workflow_id": "wf_demand_forecasting",
    "agent_id": "agent_inventory_forecasting",
    "execution_duration_minutes": 25,
    "human_intervention": false,
    "failure_flag": false,
    "latency_ms": 200,
    "throughput": 118
  },
  {
    "run_id": "run_2026_03_01",
    "workflow_id": "wf_reorder_recommendations",
    "agent_id": "agent_inventory_forecasting",
    "execution_duration_minutes": 20,
    "human_intervention": true,
    "failure_flag": false,
    "latency_ms": 210,
    "throughput": 82
  },
  {
    "run_id": "run_2026_03_01",
    "workflow_id": "wf_resume_screening",
    "agent_id": "agent_hr_screening",
    "execution_duration_minutes": 11,
    "human_intervention": true,
    "failure_flag": false,
    "latency_ms": 330,
    "throughput": 270
  },
  {
    "run_id": "run_2026_03_01",
    "workflow_id": "wf_financial_summary_generation",
    "agent_id": "agent_financial_reporting",
    "execution_duration_minutes": 45,
    "human_intervention": true,
    "failure_flag": false,
    "latency_ms": 320,
    "throughput": 18
  },
  {
    "run_id": "run_2026_03_01",
    "workflow_id": "wf_contract_clause_analysis",
    "agent_id": "agent_contract_review",
    "execution_duration_minutes": 17,
    "human_intervention": true,
    "failure_flag": false,
    "latency_ms": 460,
    "throughput": 64
  },
  {
    "run_id": "run_2026_03_01",
    "workflow_id": "wf_feedback_sentiment_analysis",
    "agent_id": "agent_product_feedback",
    "execution_duration_minutes": 13,
    "human_intervention": false,
    "failure_flag": false,
    "latency_ms": 480,
    "throughput": 470
  },
  {
    "run_id": "run_2026_03_01",
    "workflow_id": "wf_feedback_topic_clustering",
    "agent_id": "agent_product_feedback",
    "execution_duration_minutes": 14,
    "human_intervention": false,
    "failure_flag": false,
    "latency_ms": 470,
    "throughput": 280
  },
  {
    "run_id": "run_2026_03_01",
    "workflow_id": "wf_transaction_monitoring",
    "agent_id": "agent_fraud_detection",
    "execution_duration_minutes": 6,
    "human_intervention": true,
    "failure_flag": false,
    "latency_ms": 210,
    "throughput": 4850
  }
]

# %% [markdown]
# # mission_runs.json

# %%
[
  {
    "run_id": "run_2026_02_24",
    "mission_id": "ai_ecosystem_health_monitor",
    "start_time": "2026-02-24T08:00:00Z",
    "end_time": "2026-02-24T08:02:10Z",
    "total_duration_minutes": 2,
    "portfolio_health_score": 82,
    "active_agents": 10,
    "agents_at_risk": 2,
    "human_interventions": 4,
    "escalation_count": 1,
    "risk_flags": [
      "dependency_concentration",
      "integration_latency_warning"
    ]
  },
  {
    "run_id": "run_2026_03_01",
    "mission_id": "ai_ecosystem_health_monitor",
    "start_time": "2026-03-01T08:00:00Z",
    "end_time": "2026-03-01T08:02:30Z",
    "total_duration_minutes": 2,
    "portfolio_health_score": 79,
    "active_agents": 10,
    "agents_at_risk": 3,
    "human_interventions": 5,
    "escalation_count": 1,
    "risk_flags": [
      "integration_instability",
      "automation_value_leakage"
    ]
  },
  {
    "run_id": "run_2026_03_05",
    "mission_id": "ai_ecosystem_health_monitor",
    "start_time": "2026-03-05T08:00:00Z",
    "end_time": "2026-03-05T08:02:25Z",
    "total_duration_minutes": 2,
    "portfolio_health_score": 76,
    "active_agents": 10,
    "agents_at_risk": 4,
    "human_interventions": 6,
    "escalation_count": 2,
    "risk_flags": [
      "dependency_concentration",
      "integration_instability",
      "latency_degradation"
    ]
  },
  {
    "run_id": "run_2026_03_08",
    "mission_id": "ai_ecosystem_health_monitor",
    "start_time": "2026-03-08T08:00:00Z",
    "end_time": "2026-03-08T08:02:35Z",
    "total_duration_minutes": 2,
    "portfolio_health_score": 74,
    "active_agents": 10,
    "agents_at_risk": 5,
    "human_interventions": 7,
    "escalation_count": 2,
    "risk_flags": [
      "integration_instability",
      "automation_value_leakage",
      "workflow_failure_rate"
    ]
  },
  {
    "run_id": "run_2026_03_10",
    "mission_id": "ai_ecosystem_health_monitor",
    "start_time": "2026-03-10T08:00:00Z",
    "end_time": "2026-03-10T08:02:45Z",
    "total_duration_minutes": 2,
    "portfolio_health_score": 72,
    "active_agents": 10,
    "agents_at_risk": 5,
    "human_interventions": 8,
    "escalation_count": 3,
    "risk_flags": [
      "integration_instability",
      "automation_value_leakage",
      "authentication_expiry",
      "dependency_concentration"
    ]
  }
]

# %% [markdown]
# # historical_snapshots.json

# %%
[
  {
    "snapshot_date": "2026-02-20",
    "agent_id": "agent_sales_outreach",
    "integration_score": 88,
    "risk_score": 82,
    "value_score": 91,
    "overall_health_score": 87
  },
  {
    "snapshot_date": "2026-02-20",
    "agent_id": "agent_invoice_processing",
    "integration_score": 84,
    "risk_score": 78,
    "value_score": 86,
    "overall_health_score": 82
  },
  {
    "snapshot_date": "2026-02-20",
    "agent_id": "agent_customer_support",
    "integration_score": 90,
    "risk_score": 85,
    "value_score": 88,
    "overall_health_score": 88
  },
  {
    "snapshot_date": "2026-02-20",
    "agent_id": "agent_marketing_analytics",
    "integration_score": 92,
    "risk_score": 86,
    "value_score": 89,
    "overall_health_score": 89
  },
  {
    "snapshot_date": "2026-02-20",
    "agent_id": "agent_inventory_forecasting",
    "integration_score": 91,
    "risk_score": 87,
    "value_score": 90,
    "overall_health_score": 89
  },

  {
    "snapshot_date": "2026-03-01",
    "agent_id": "agent_sales_outreach",
    "integration_score": 84,
    "risk_score": 78,
    "value_score": 89,
    "overall_health_score": 83
  },
  {
    "snapshot_date": "2026-03-01",
    "agent_id": "agent_invoice_processing",
    "integration_score": 80,
    "risk_score": 72,
    "value_score": 79,
    "overall_health_score": 77
  },
  {
    "snapshot_date": "2026-03-01",
    "agent_id": "agent_customer_support",
    "integration_score": 88,
    "risk_score": 82,
    "value_score": 85,
    "overall_health_score": 85
  },
  {
    "snapshot_date": "2026-03-01",
    "agent_id": "agent_marketing_analytics",
    "integration_score": 90,
    "risk_score": 85,
    "value_score": 87,
    "overall_health_score": 87
  },
  {
    "snapshot_date": "2026-03-01",
    "agent_id": "agent_inventory_forecasting",
    "integration_score": 89,
    "risk_score": 84,
    "value_score": 88,
    "overall_health_score": 87
  },

  {
    "snapshot_date": "2026-03-10",
    "agent_id": "agent_sales_outreach",
    "integration_score": 79,
    "risk_score": 70,
    "value_score": 85,
    "overall_health_score": 78
  },
  {
    "snapshot_date": "2026-03-10",
    "agent_id": "agent_invoice_processing",
    "integration_score": 74,
    "risk_score": 64,
    "value_score": 70,
    "overall_health_score": 69
  },
  {
    "snapshot_date": "2026-03-10",
    "agent_id": "agent_customer_support",
    "integration_score": 84,
    "risk_score": 76,
    "value_score": 82,
    "overall_health_score": 81
  },
  {
    "snapshot_date": "2026-03-10",
    "agent_id": "agent_marketing_analytics",
    "integration_score": 88,
    "risk_score": 83,
    "value_score": 86,
    "overall_health_score": 86
  },
  {
    "snapshot_date": "2026-03-10",
    "agent_id": "agent_inventory_forecasting",
    "integration_score": 86,
    "risk_score": 81,
    "value_score": 85,
    "overall_health_score": 84
  }
]
