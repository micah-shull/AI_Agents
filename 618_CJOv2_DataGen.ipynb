# %% [markdown]
# <a href="https://colab.research.google.com/github/micah-shull/AI_Agents/blob/main/618_CJOv2_DataGen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # journey_playbooks.json

# %%
[
  {
    "playbook_id": "PB_ONB_001",
    "name": "SMB Onboarding Rescue",
    "journey_stage": "onboarding",
    "eligible_segments": ["SMB"],
    "risk_threshold": 0.6,
    "default_actions": [
      "proactive_outreach",
      "onboarding_specialist_call"
    ],
    "approval_required": true,
    "avg_cost_estimate": 60,
    "expected_value_range": [500, 2500],
    "created_at": "2025-01-20",
    "status": "active"
  },
  {
    "playbook_id": "PB_ONB_002",
    "name": "Mid-Market Onboarding Acceleration",
    "journey_stage": "onboarding",
    "eligible_segments": ["Mid-Market"],
    "risk_threshold": 0.55,
    "default_actions": [
      "guided_setup_session",
      "success_manager_intro"
    ],
    "approval_required": false,
    "avg_cost_estimate": 45,
    "expected_value_range": [800, 4000],
    "created_at": "2025-01-22",
    "status": "active"
  },
  {
    "playbook_id": "PB_ENG_001",
    "name": "Usage Drop Recovery",
    "journey_stage": "engagement",
    "eligible_segments": ["SMB", "Mid-Market"],
    "risk_threshold": 0.5,
    "default_actions": [
      "reengagement_campaign",
      "usage_review_checkin"
    ],
    "approval_required": false,
    "avg_cost_estimate": 30,
    "expected_value_range": [300, 1800],
    "created_at": "2025-01-18",
    "status": "active"
  },
  {
    "playbook_id": "PB_SUP_001",
    "name": "Support Escalation Mitigation",
    "journey_stage": "support",
    "eligible_segments": ["SMB", "Mid-Market", "Enterprise"],
    "risk_threshold": 0.65,
    "default_actions": [
      "support_manager_followup",
      "priority_ticket_queue"
    ],
    "approval_required": true,
    "avg_cost_estimate": 75,
    "expected_value_range": [1000, 6000],
    "created_at": "2025-01-25",
    "status": "active"
  },
  {
    "playbook_id": "PB_RET_001",
    "name": "Enterprise Renewal Health Check",
    "journey_stage": "retention",
    "eligible_segments": ["Enterprise"],
    "risk_threshold": 0.4,
    "default_actions": [
      "executive_sponsor_outreach",
      "renewal_strategy_review"
    ],
    "approval_required": true,
    "avg_cost_estimate": 120,
    "expected_value_range": [5000, 25000],
    "created_at": "2025-01-28",
    "status": "active"
  },
  {
    "playbook_id": "PB_RET_002",
    "name": "SMB Renewal Nurture",
    "journey_stage": "retention",
    "eligible_segments": ["SMB"],
    "risk_threshold": 0.45,
    "default_actions": [
      "renewal_health_check",
      "discount_offer_review"
    ],
    "approval_required": false,
    "avg_cost_estimate": 25,
    "expected_value_range": [400, 2000],
    "created_at": "2025-01-29",
    "status": "active"
  },
  {
    "playbook_id": "PB_EXP_001",
    "name": "Passive Monitoring Only",
    "journey_stage": "engagement",
    "eligible_segments": ["SMB", "Mid-Market", "Enterprise"],
    "risk_threshold": 0.2,
    "default_actions": [
      "monitor_only"
    ],
    "approval_required": false,
    "avg_cost_estimate": 5,
    "expected_value_range": [0, 200],
    "created_at": "2025-01-30",
    "status": "active"
  }
]

# %% [markdown]
# # journey_forecasts.json

# %%
[
  {
    "forecast_id": "F001",
    "customer_id": "C001",
    "current_stage": "onboarding",
    "predicted_path": ["support", "churn_risk"],
    "churn_probability": 0.48,
    "recovery_probability": 0.32,
    "stagnation_probability": 0.20,
    "revenue_at_risk": 5760,
    "generated_at": "2025-02-02",
    "model_type": "rules_v2"
  },
  {
    "forecast_id": "F002",
    "customer_id": "C002",
    "current_stage": "onboarding",
    "predicted_path": ["engagement"],
    "churn_probability": 0.22,
    "recovery_probability": 0.51,
    "stagnation_probability": 0.27,
    "revenue_at_risk": 1760,
    "generated_at": "2025-02-02",
    "model_type": "rules_v2"
  },
  {
    "forecast_id": "F003",
    "customer_id": "C003",
    "current_stage": "engagement",
    "predicted_path": ["retention"],
    "churn_probability": 0.10,
    "recovery_probability": 0.63,
    "stagnation_probability": 0.27,
    "revenue_at_risk": 500,
    "generated_at": "2025-02-02",
    "model_type": "rules_v2"
  },
  {
    "forecast_id": "F004",
    "customer_id": "C004",
    "current_stage": "engagement",
    "predicted_path": ["support", "churn_risk"],
    "churn_probability": 0.38,
    "recovery_probability": 0.41,
    "stagnation_probability": 0.21,
    "revenue_at_risk": 15960,
    "generated_at": "2025-02-02",
    "model_type": "rules_v2"
  },
  {
    "forecast_id": "F005",
    "customer_id": "C005",
    "current_stage": "support",
    "predicted_path": ["retention"],
    "churn_probability": 0.19,
    "recovery_probability": 0.56,
    "stagnation_probability": 0.25,
    "revenue_at_risk": 7220,
    "generated_at": "2025-02-02",
    "model_type": "rules_v2"
  },
  {
    "forecast_id": "F006",
    "customer_id": "C006",
    "current_stage": "onboarding",
    "predicted_path": ["support"],
    "churn_probability": 0.52,
    "recovery_probability": 0.26,
    "stagnation_probability": 0.22,
    "revenue_at_risk": 23920,
    "generated_at": "2025-02-02",
    "model_type": "rules_v2"
  },
  {
    "forecast_id": "F007",
    "customer_id": "C007",
    "current_stage": "retention",
    "predicted_path": ["renewal_success"],
    "churn_probability": 0.06,
    "recovery_probability": 0.71,
    "stagnation_probability": 0.23,
    "revenue_at_risk": 7500,
    "generated_at": "2025-02-02",
    "model_type": "rules_v2"
  },
  {
    "forecast_id": "F008",
    "customer_id": "C008",
    "current_stage": "support",
    "predicted_path": ["engagement"],
    "churn_probability": 0.27,
    "recovery_probability": 0.46,
    "stagnation_probability": 0.27,
    "revenue_at_risk": 9800,
    "generated_at": "2025-02-02",
    "model_type": "rules_v2"
  },
  {
    "forecast_id": "F009",
    "customer_id": "C009",
    "current_stage": "engagement",
    "predicted_path": ["support", "churn_risk"],
    "churn_probability": 0.57,
    "recovery_probability": 0.19,
    "stagnation_probability": 0.24,
    "revenue_at_risk": 62700,
    "generated_at": "2025-02-02",
    "model_type": "rules_v2"
  },
  {
    "forecast_id": "F010",
    "customer_id": "C010",
    "current_stage": "engagement",
    "predicted_path": ["retention"],
    "churn_probability": 0.14,
    "recovery_probability": 0.58,
    "stagnation_probability": 0.28,
    "revenue_at_risk": 2100,
    "generated_at": "2025-02-02",
    "model_type": "rules_v2"
  }
]

# %% [markdown]
# # portfolio_snapshots.json

# %%
[
  {
    "snapshot_id": "PS_2025_01_20",
    "total_customers": 500,
    "customers_at_high_risk": 58,
    "revenue_at_risk": 3150000,
    "top_leaking_stage": "onboarding",
    "top_playbooks": ["PB_ONB_001", "PB_ENG_001"],
    "generated_at": "2025-01-20"
  },
  {
    "snapshot_id": "PS_2025_01_27",
    "total_customers": 505,
    "customers_at_high_risk": 52,
    "revenue_at_risk": 2920000,
    "top_leaking_stage": "support",
    "top_playbooks": ["PB_SUP_001", "PB_ONB_001"],
    "generated_at": "2025-01-27"
  },
  {
    "snapshot_id": "PS_2025_02_01",
    "total_customers": 520,
    "customers_at_high_risk": 47,
    "revenue_at_risk": 2680000,
    "top_leaking_stage": "engagement",
    "top_playbooks": ["PB_RET_001", "PB_ENG_001"],
    "generated_at": "2025-02-01"
  },
  {
    "snapshot_id": "PS_2025_02_08",
    "total_customers": 530,
    "customers_at_high_risk": 41,
    "revenue_at_risk": 2410000,
    "top_leaking_stage": "onboarding",
    "top_playbooks": ["PB_ONB_002", "PB_EXP_001"],
    "generated_at": "2025-02-08"
  }
]

# %% [markdown]
# # playbook_performance_log.json

# %%
[
  {
    "playbook_id": "PB_ONB_001",
    "segment": "SMB",
    "runs": 42,
    "success_rate": 0.71,
    "avg_cost": 58,
    "avg_value": 1340,
    "roi_ratio": 23.1,
    "override_rate": 0.18,
    "last_updated": "2025-02-01"
  },
  {
    "playbook_id": "PB_ONB_002",
    "segment": "Mid-Market",
    "runs": 35,
    "success_rate": 0.68,
    "avg_cost": 46,
    "avg_value": 2210,
    "roi_ratio": 48.0,
    "override_rate": 0.09,
    "last_updated": "2025-02-01"
  },
  {
    "playbook_id": "PB_ENG_001",
    "segment": "SMB",
    "runs": 51,
    "success_rate": 0.64,
    "avg_cost": 29,
    "avg_value": 890,
    "roi_ratio": 30.7,
    "override_rate": 0.05,
    "last_updated": "2025-02-01"
  },
  {
    "playbook_id": "PB_SUP_001",
    "segment": "Enterprise",
    "runs": 18,
    "success_rate": 0.83,
    "avg_cost": 112,
    "avg_value": 7420,
    "roi_ratio": 66.2,
    "override_rate": 0.22,
    "last_updated": "2025-02-01"
  },
  {
    "playbook_id": "PB_RET_001",
    "segment": "Enterprise",
    "runs": 12,
    "success_rate": 0.92,
    "avg_cost": 135,
    "avg_value": 18200,
    "roi_ratio": 134.8,
    "override_rate": 0.17,
    "last_updated": "2025-02-01"
  },
  {
    "playbook_id": "PB_RET_002",
    "segment": "SMB",
    "runs": 27,
    "success_rate": 0.59,
    "avg_cost": 24,
    "avg_value": 640,
    "roi_ratio": 26.7,
    "override_rate": 0.04,
    "last_updated": "2025-02-01"
  },
  {
    "playbook_id": "PB_EXP_001",
    "segment": "All",
    "runs": 64,
    "success_rate": 0.22,
    "avg_cost": 6,
    "avg_value": 80,
    "roi_ratio": 13.3,
    "override_rate": 0.01,
    "last_updated": "2025-02-01"
  }
]

# %% [markdown]
# # journey_state_log.json

# %%
[
  {
    "customer_id": "C001",
    "journey_stage": "onboarding",
    "state_entered_at": "2025-01-01",
    "days_in_state": 14,
    "previous_stage": null,
    "portfolio_risk_bucket": "high",
    "predicted_next_stage": "support",
    "forecast_confidence": 0.64
  },
  {
    "customer_id": "C002",
    "journey_stage": "onboarding",
    "state_entered_at": "2025-01-05",
    "days_in_state": 10,
    "previous_stage": null,
    "portfolio_risk_bucket": "medium",
    "predicted_next_stage": "engagement",
    "forecast_confidence": 0.58
  },
  {
    "customer_id": "C003",
    "journey_stage": "engagement",
    "state_entered_at": "2024-12-01",
    "days_in_state": 45,
    "previous_stage": "onboarding",
    "portfolio_risk_bucket": "low",
    "predicted_next_stage": "retention",
    "forecast_confidence": 0.61
  },
  {
    "customer_id": "C004",
    "journey_stage": "engagement",
    "state_entered_at": "2024-10-12",
    "days_in_state": 90,
    "previous_stage": "onboarding",
    "portfolio_risk_bucket": "high",
    "predicted_next_stage": "support",
    "forecast_confidence": 0.66
  },
  {
    "customer_id": "C005",
    "journey_stage": "support",
    "state_entered_at": "2025-01-08",
    "days_in_state": 7,
    "previous_stage": "engagement",
    "portfolio_risk_bucket": "medium",
    "predicted_next_stage": "retention",
    "forecast_confidence": 0.54
  },
  {
    "customer_id": "C006",
    "journey_stage": "onboarding",
    "state_entered_at": "2025-01-03",
    "days_in_state": 12,
    "previous_stage": null,
    "portfolio_risk_bucket": "high",
    "predicted_next_stage": "support",
    "forecast_confidence": 0.69
  },
  {
    "customer_id": "C007",
    "journey_stage": "retention",
    "state_entered_at": "2024-08-01",
    "days_in_state": 160,
    "previous_stage": "engagement",
    "portfolio_risk_bucket": "low",
    "predicted_next_stage": "renewal_success",
    "forecast_confidence": 0.72
  },
  {
    "customer_id": "C008",
    "journey_stage": "support",
    "state_entered_at": "2025-01-10",
    "days_in_state": 5,
    "previous_stage": "retention",
    "portfolio_risk_bucket": "medium",
    "predicted_next_stage": "engagement",
    "forecast_confidence": 0.51
  },
  {
    "customer_id": "C009",
    "journey_stage": "engagement",
    "state_entered_at": "2025-01-09",
    "days_in_state": 2,
    "previous_stage": "support",
    "portfolio_risk_bucket": "high",
    "predicted_next_stage": "support",
    "forecast_confidence": 0.63
  },
  {
    "customer_id": "C010",
    "journey_stage": "engagement",
    "state_entered_at": "2024-11-15",
    "days_in_state": 60,
    "previous_stage": "onboarding",
    "portfolio_risk_bucket": "low",
    "predicted_next_stage": "retention",
    "forecast_confidence": 0.59
  }
]

# %% [markdown]
# # signals.json

# %%
[
  {
    "signal_id": "S001",
    "customer_id": "C001",
    "signal_type": "support_ticket_spike",
    "signal_strength": 0.82,
    "detected_at": "2025-01-14",
    "journey_stage": "onboarding",
    "source": "automated",
    "normalized_strength": 0.78,
    "risk_weight": 1.4,
    "segment_adjustment": 1.2
  },
  {
    "signal_id": "S002",
    "customer_id": "C001",
    "signal_type": "negative_sentiment",
    "signal_strength": 0.67,
    "detected_at": "2025-01-15",
    "journey_stage": "onboarding",
    "source": "automated",
    "normalized_strength": 0.65,
    "risk_weight": 1.3,
    "segment_adjustment": 1.2
  },
  {
    "signal_id": "S003",
    "customer_id": "C002",
    "signal_type": "low_product_usage",
    "signal_strength": 0.45,
    "detected_at": "2025-01-13",
    "journey_stage": "onboarding",
    "source": "automated",
    "normalized_strength": 0.42,
    "risk_weight": 1.1,
    "segment_adjustment": 1.0
  },
  {
    "signal_id": "S004",
    "customer_id": "C004",
    "signal_type": "usage_drop",
    "signal_strength": 0.60,
    "detected_at": "2025-01-12",
    "journey_stage": "engagement",
    "source": "automated",
    "normalized_strength": 0.58,
    "risk_weight": 1.3,
    "segment_adjustment": 1.1
  },
  {
    "signal_id": "S005",
    "customer_id": "C005",
    "signal_type": "repeat_support_tickets",
    "signal_strength": 0.75,
    "detected_at": "2025-01-14",
    "journey_stage": "support",
    "source": "manual",
    "normalized_strength": 0.72,
    "risk_weight": 1.5,
    "segment_adjustment": 1.1
  },
  {
    "signal_id": "S006",
    "customer_id": "C006",
    "signal_type": "failed_onboarding_step",
    "signal_strength": 0.88,
    "detected_at": "2025-01-15",
    "journey_stage": "onboarding",
    "source": "automated",
    "normalized_strength": 0.85,
    "risk_weight": 1.6,
    "segment_adjustment": 1.2
  },
  {
    "signal_id": "S007",
    "customer_id": "C006",
    "signal_type": "positive_sentiment",
    "signal_strength": 0.40,
    "detected_at": "2025-01-16",
    "journey_stage": "onboarding",
    "source": "automated",
    "normalized_strength": 0.38,
    "risk_weight": 0.6,
    "segment_adjustment": 1.2
  },
  {
    "signal_id": "S008",
    "customer_id": "C007",
    "signal_type": "renewal_intent",
    "signal_strength": 0.30,
    "detected_at": "2025-01-10",
    "journey_stage": "retention",
    "source": "manual",
    "normalized_strength": 0.28,
    "risk_weight": 0.5,
    "segment_adjustment": 1.4
  },
  {
    "signal_id": "S009",
    "customer_id": "C009",
    "signal_type": "negative_sentiment",
    "signal_strength": 0.90,
    "detected_at": "2025-01-14",
    "journey_stage": "support",
    "source": "automated",
    "normalized_strength": 0.88,
    "risk_weight": 1.7,
    "segment_adjustment": 1.3
  },
  {
    "signal_id": "S010",
    "customer_id": "C004",
    "signal_type": "usage_recovery",
    "signal_strength": 0.55,
    "detected_at": "2025-01-16",
    "journey_stage": "engagement",
    "source": "automated",
    "normalized_strength": 0.53,
    "risk_weight": 0.7,
    "segment_adjustment": 1.1
  },
  {
    "signal_id": "S011",
    "customer_id": "C010",
    "signal_type": "inactivity_warning",
    "signal_strength": 0.50,
    "detected_at": "2025-01-11",
    "journey_stage": "engagement",
    "source": "automated",
    "normalized_strength": 0.48,
    "risk_weight": 1.2,
    "segment_adjustment": 1.0
  },
  {
    "signal_id": "S012",
    "customer_id": "C005",
    "signal_type": "support_satisfaction_low",
    "signal_strength": 0.65,
    "detected_at": "2025-01-15",
    "journey_stage": "support",
    "source": "manual",
    "normalized_strength": 0.63,
    "risk_weight": 1.4,
    "segment_adjustment": 1.1
  }
]

# %% [markdown]
# # interventions.json

# %%
[
  {
    "intervention_id": "I001",
    "customer_id": "C001",
    "journey_stage": "onboarding",
    "playbook_id": "PB_ONB_001",
    "recommended_action": "proactive_outreach",
    "confidence": 0.78,
    "expected_cost": 60,
    "expected_value": 1800,
    "requires_human_approval": true,
    "triggered_by_signals": ["S001", "S002"],
    "evaluation_latency_ms": 240,
    "generated_at": "2025-02-02"
  },
  {
    "intervention_id": "I002",
    "customer_id": "C002",
    "journey_stage": "onboarding",
    "playbook_id": "PB_ONB_002",
    "recommended_action": "guided_setup_session",
    "confidence": 0.52,
    "expected_cost": 45,
    "expected_value": 1400,
    "requires_human_approval": false,
    "triggered_by_signals": ["S003"],
    "evaluation_latency_ms": 180,
    "generated_at": "2025-02-02"
  },
  {
    "intervention_id": "I003",
    "customer_id": "C004",
    "journey_stage": "engagement",
    "playbook_id": "PB_ENG_001",
    "recommended_action": "usage_review_checkin",
    "confidence": 0.60,
    "expected_cost": 30,
    "expected_value": 900,
    "requires_human_approval": false,
    "triggered_by_signals": ["S004"],
    "evaluation_latency_ms": 210,
    "generated_at": "2025-02-02"
  },
  {
    "intervention_id": "I004",
    "customer_id": "C005",
    "journey_stage": "support",
    "playbook_id": "PB_SUP_001",
    "recommended_action": "support_manager_followup",
    "confidence": 0.81,
    "expected_cost": 75,
    "expected_value": 3200,
    "requires_human_approval": true,
    "triggered_by_signals": ["S005", "S012"],
    "evaluation_latency_ms": 320,
    "generated_at": "2025-02-02"
  },
  {
    "intervention_id": "I005",
    "customer_id": "C006",
    "journey_stage": "onboarding",
    "playbook_id": "PB_ONB_001",
    "recommended_action": "onboarding_specialist_call",
    "confidence": 0.69,
    "expected_cost": 65,
    "expected_value": 2400,
    "requires_human_approval": true,
    "triggered_by_signals": ["S006", "S007"],
    "evaluation_latency_ms": 290,
    "generated_at": "2025-02-02"
  },
  {
    "intervention_id": "I006",
    "customer_id": "C007",
    "journey_stage": "retention",
    "playbook_id": "PB_RET_001",
    "recommended_action": "executive_sponsor_outreach",
    "confidence": 0.40,
    "expected_cost": 120,
    "expected_value": 15000,
    "requires_human_approval": true,
    "triggered_by_signals": ["S008"],
    "evaluation_latency_ms": 150,
    "generated_at": "2025-02-02"
  },
  {
    "intervention_id": "I007",
    "customer_id": "C010",
    "journey_stage": "engagement",
    "playbook_id": "PB_ENG_001",
    "recommended_action": "reengagement_campaign",
    "confidence": 0.55,
    "expected_cost": 28,
    "expected_value": 800,
    "requires_human_approval": false,
    "triggered_by_signals": ["S011"],
    "evaluation_latency_ms": 200,
    "generated_at": "2025-02-02"
  },
  {
    "intervention_id": "I008",
    "customer_id": "C004",
    "journey_stage": "engagement",
    "playbook_id": "PB_EXP_001",
    "recommended_action": "monitor_only",
    "confidence": 0.35,
    "expected_cost": 5,
    "expected_value": 120,
    "requires_human_approval": false,
    "triggered_by_signals": ["S010"],
    "evaluation_latency_ms": 120,
    "generated_at": "2025-02-02"
  }
]

# %% [markdown]
# #outcomes.json

# %%
[
  {
    "outcome_id": "O001",
    "intervention_id": "I001",
    "customer_id": "C001",
    "playbook_id": "PB_ONB_001",
    "outcome": "resolved",
    "resolution_time_days": 3,
    "csat_delta": 1,
    "churn_risk_delta": -0.25,
    "estimated_revenue_saved": 2000,
    "human_override": false,
    "playbook_success": true,
    "measured_at": "2025-02-05"
  },
  {
    "outcome_id": "O002",
    "intervention_id": "I002",
    "customer_id": "C002",
    "playbook_id": "PB_ONB_002",
    "outcome": "no_response",
    "resolution_time_days": null,
    "csat_delta": 0,
    "churn_risk_delta": 0.00,
    "estimated_revenue_saved": 0,
    "human_override": false,
    "playbook_success": false,
    "measured_at": "2025-02-06"
  },
  {
    "outcome_id": "O003",
    "intervention_id": "I003",
    "customer_id": "C004",
    "playbook_id": "PB_ENG_001",
    "outcome": "partial_improvement",
    "resolution_time_days": 6,
    "csat_delta": 0,
    "churn_risk_delta": -0.12,
    "estimated_revenue_saved": 600,
    "human_override": false,
    "playbook_success": true,
    "measured_at": "2025-02-07"
  },
  {
    "outcome_id": "O004",
    "intervention_id": "I004",
    "customer_id": "C005",
    "playbook_id": "PB_SUP_001",
    "outcome": "resolved",
    "resolution_time_days": 2,
    "csat_delta": 2,
    "churn_risk_delta": -0.30,
    "estimated_revenue_saved": 1500,
    "human_override": true,
    "playbook_success": true,
    "measured_at": "2025-02-05"
  },
  {
    "outcome_id": "O005",
    "intervention_id": "I006",
    "customer_id": "C007",
    "playbook_id": "PB_RET_001",
    "outcome": "no_action_needed",
    "resolution_time_days": null,
    "csat_delta": 0,
    "churn_risk_delta": 0.00,
    "estimated_revenue_saved": 0,
    "human_override": false,
    "playbook_success": true,
    "measured_at": "2025-02-08"
  },
  {
    "outcome_id": "O006",
    "intervention_id": "I007",
    "customer_id": "C010",
    "playbook_id": "PB_ENG_001",
    "outcome": "improved_engagement",
    "resolution_time_days": 5,
    "csat_delta": 1,
    "churn_risk_delta": -0.15,
    "estimated_revenue_saved": 800,
    "human_override": false,
    "playbook_success": true,
    "measured_at": "2025-02-07"
  },
  {
    "outcome_id": "O007",
    "intervention_id": "I008",
    "customer_id": "C004",
    "playbook_id": "PB_EXP_001",
    "outcome": "monitor_only",
    "resolution_time_days": null,
    "csat_delta": 0,
    "churn_risk_delta": 0.00,
    "estimated_revenue_saved": 0,
    "human_override": false,
    "playbook_success": false,
    "measured_at": "2025-02-08"
  },
  {
    "outcome_id": "O008",
    "intervention_id": "I005",
    "customer_id": "C006",
    "playbook_id": "PB_ONB_001",
    "outcome": "resolved",
    "resolution_time_days": 4,
    "csat_delta": 2,
    "churn_risk_delta": -0.28,
    "estimated_revenue_saved": 2200,
    "human_override": false,
    "playbook_success": true,
    "measured_at": "2025-02-07"
  }
]

# %% [markdown]
# # customers.json

# %%
[
  {
    "customer_id": "C001",
    "segment": "SMB",
    "account_value": 12000,
    "tenure_months": 3,
    "risk_tier": "high"
  },
  {
    "customer_id": "C002",
    "segment": "SMB",
    "account_value": 8000,
    "tenure_months": 2,
    "risk_tier": "medium"
  },
  {
    "customer_id": "C003",
    "segment": "SMB",
    "account_value": 5000,
    "tenure_months": 14,
    "risk_tier": "low"
  },
  {
    "customer_id": "C004",
    "segment": "Mid-Market",
    "account_value": 42000,
    "tenure_months": 18,
    "risk_tier": "low"
  },
  {
    "customer_id": "C005",
    "segment": "Mid-Market",
    "account_value": 38000,
    "tenure_months": 6,
    "risk_tier": "medium"
  },
  {
    "customer_id": "C006",
    "segment": "Mid-Market",
    "account_value": 46000,
    "tenure_months": 4,
    "risk_tier": "high"
  },
  {
    "customer_id": "C007",
    "segment": "Enterprise",
    "account_value": 125000,
    "tenure_months": 36,
    "risk_tier": "low"
  },
  {
    "customer_id": "C008",
    "segment": "Enterprise",
    "account_value": 98000,
    "tenure_months": 10,
    "risk_tier": "medium"
  },
  {
    "customer_id": "C009",
    "segment": "Enterprise",
    "account_value": 110000,
    "tenure_months": 1,
    "risk_tier": "high"
  },
  {
    "customer_id": "C010",
    "segment": "SMB",
    "account_value": 15000,
    "tenure_months": 24,
    "risk_tier": "low"
  }
]
