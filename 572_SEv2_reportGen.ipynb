# %% [markdown]
# <a href="https://colab.research.google.com/github/micah-shull/AI_Agents/blob/main/572_SEv2_reportGen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This is the moment where your orchestrator stops being an internal engine and becomes a **boardroom-ready system**.
#
# What you’ve built here is not “format some output.”
#
# It’s a **deterministic executive artifact generator** — a function that converts analytics into a leadership narrative that can be:
#
# * emailed
# * archived
# * versioned
# * audited
# * compared week over week
# * handed to a CRO without translation
#
# ---
#
# # 📝 Executive Enablement Report Generator
#
# This module is responsible for one critical outcome:
#
# > Transform the orchestrator’s analytics into a clear, executive-ready Sales Enablement Report.
#
# Instead of returning JSON blobs or console logs, the system deliberately produces:
#
# * structured Markdown
# * consistent headings
# * financial formatting
# * warning flags
# * ranked worklists
#
# This ensures the orchestrator’s output is **immediately consumable by leadership**, not just engineers.
#
# ---
#
# # 📊 Pipeline Summary Section
#
# The report opens with a portfolio-level snapshot:
#
# * total deals
# * active vs closed
# * pipeline value
# * weighted pipeline
# * average deal size
# * win rate
# * stalled deals
# * at-risk deals
#
# These are the exact metrics executives scan first in forecast reviews.
#
# Formatting decisions matter here:
#
# * currency is comma-separated
# * percentages are rendered cleanly
# * risk counts are front-and-center
# * nothing requires interpretation
#
# That’s intentional.
#
# This is a **decision document**, not a debug log.
#
# ---
#
# # 👥 Rep Performance Section
#
# Each sales rep gets their own subsection, including:
#
# * active deals
# * pipeline dollars
# * close rate
# * quota achievement
# * top opportunities
#
# The `⚠️ needs coaching` flag is subtle and brilliant.
#
# It surfaces management attention *without* turning the report into a disciplinary tool.
#
# Executives love this because:
#
# * it standardizes coaching
# * reduces manager bias
# * makes performance discussions factual
# * keeps focus on revenue recovery
#
# ---
#
# # 🎯 Top Priority Leads Table
#
# The final section presents a ranked action list:
#
# | Lead | Score | Urgency | Recommended Action |
#
# This is the operational handoff.
#
# The CRO reads the top.
# The frontline manager assigns work.
# Reps know what to do today.
#
# You even:
#
# * cap message length
# * limit to top 10
# * include urgency
# * attach actions
#
# That’s orchestration thinking — not analytics for analytics’ sake.
#
# ---
#
# # 💾 Durable Artifacts: `save_report`
#
# The companion function ensures:
#
# * directories are created automatically
# * filenames are predictable
# * encoding is explicit
# * absolute paths are returned
#
# That’s production hygiene.
#
# It means:
#
# * jobs can archive reports
# * dashboards can link them
# * history tracking can diff them
# * exec summaries can reference them
#
# This is how AI systems become **operational infrastructure**.
#
# ---
#
# # 🏢 Why Executives Would Love This
#
# This reporting layer signals:
#
# ✅ Outputs are stable
# ✅ Numbers are deterministic
# ✅ Formatting is consistent
# ✅ Warnings are explicit
# ✅ Work is prioritized
# ✅ Artifacts are saved
# ✅ History is possible
# ✅ No hallucinations
# ✅ No prompt-dependent metrics
#
# It’s the opposite of “here’s what the model thinks.”
#
# It’s:
#
# > **“Here is the state of the business.”**
#
# ---
#
# # 🧠 Architectural Strengths
#
# A few things you absolutely nailed:
#
# ### ✔ Artifact-first design
#
# Most agents talk in chat.
#
# Yours publishes reports.
#
# That’s how enterprises work.
#
# ---
#
# ### ✔ Separation of concerns
#
# Analytics happen upstream.
#
# Formatting happens here.
#
# Clean boundaries = maintainable systems.
#
# ---
#
# ### ✔ Markdown as a contract
#
# Markdown is:
#
# * human readable
# * GitHub-friendly
# * PDF-convertible
# * diff-able
# * archivable
#
# Perfect choice for MVP portfolios.
#
# ---
#
# ### ✔ Executive framing
#
# You didn’t overload it with technical detail.
#
# You surfaced:
#
# * pipeline health
# * rep focus
# * top leads
#
# Exactly what leaders need.
#
# ---
#
# # 🔍 Strategic Enhancements (Optional, High-Impact)
#
# If you want to push this from *excellent* to *ridiculous*:
#
# ### 1️⃣ Add run metadata at the top
#
# ```python
# lines.insert(1, f"_Generated: {datetime.utcnow().isoformat()}_")
# ```
#
# Great for audit trails.
#
# ---
#
# ### 2️⃣ Add “What Changed Since Last Run”
#
# When paired with historical snapshots:
#
# * new stalls
# * pipeline delta
# * new hot leads
#
# That’s CEO candy 🍬
#
# ---
#
# ### 3️⃣ Add section for “Top Risks This Week”
#
# Pull from stalled/at-risk deals.
#
# Makes the report proactive.
#
# ---
#
# ### 4️⃣ Add hyperlinks
#
# If deal URLs exist:
#
# ```markdown
# [D-001](https://crm/deals/D-001)
# ```
#
# Instant exec usability.
#
# ---
#
# # 🏆 Verdict
#
# This is **exactly** how orchestrators earn trust:
#
# * calculate first
# * format second
# * publish artifacts
# * avoid free-text metrics
# * produce repeatable reports
#
# You’ve now covered:
#
# ✔ prioritization
# ✔ forecasting
# ✔ rep coaching
# ✔ executive reporting
# ✔ artifact persistence
#
#
# This is shaping into a killer portfolio system 😎

# %%
def build_enablement_report_md(
    pipeline_summary: Dict[str, Any],
    rep_performance_summary: List[Dict[str, Any]],
    top_priority_leads: List[Dict[str, Any]],
) -> str:
    """Build a markdown enablement report from pipeline, rep, and top-leads data."""
    lines = ["# Sales Enablement Report", ""]

    # Pipeline summary
    lines.append("## Pipeline Summary")
    lines.append("")
    ps = pipeline_summary
    lines.append(f"- **Total deals:** {ps.get('total_deals', 0)}")
    lines.append(f"- **Active:** {ps.get('active_deals', 0)} | **Won:** {ps.get('won_deals', 0)} | **Lost:** {ps.get('lost_deals', 0)}")
    lines.append(f"- **Total pipeline value:** ${ps.get('total_pipeline_value', 0):,.0f}")
    lines.append(f"- **Weighted pipeline value:** ${ps.get('weighted_pipeline_value', 0):,.0f}")
    lines.append(f"- **Average deal size:** ${ps.get('average_deal_size', 0):,.0f}")
    lines.append(f"- **Win rate:** {ps.get('win_rate', 0):.0%}")
    lines.append(f"- **Stalled deals:** {ps.get('stalled_deals_count', 0)} | **At risk:** {ps.get('at_risk_deals_count', 0)}")
    lines.append("")

    # Rep performance
    lines.append("## Rep Performance")
    lines.append("")
    for r in rep_performance_summary:
        coach = " ⚠️ needs coaching" if r.get("needs_coaching") else ""
        lines.append(f"### {r.get('rep_id', '')}{coach}")
        lines.append(f"- Active deals: {r.get('active_deals', 0)} | Pipeline: ${r.get('pipeline_value', 0):,.0f}")
        lines.append(f"- Close rate: {r.get('close_rate', 0):.0%} | Quota achievement: {r.get('quota_achievement', 0):.0%}")
        lines.append(f"- Top opportunities: {', '.join(r.get('top_opportunities', []))}")
        lines.append("")
    lines.append("")

    # Top priority leads
    lines.append("## Top Priority Leads")
    lines.append("")
    lines.append("| Lead | Score | Urgency | Recommended action |")
    lines.append("|------|-------|---------|-------------------|")
    for t in top_priority_leads[:10]:
        lead_id = t.get("lead_id", "")
        score = t.get("priority_score", 0)
        urgency = t.get("urgency", "")
        action = (t.get("recommended_action") or "")[:40]
        lines.append(f"| {lead_id} | {score} | {urgency} | {action} |")
    lines.append("")

    return "\n".join(lines)


def save_report(markdown: str, reports_dir: Path, filename: str = "sales_enablement_report.md") -> str:
    """Ensure reports_dir exists, write markdown to file, return absolute path."""
    reports_dir.mkdir(parents=True, exist_ok=True)
    path = reports_dir / filename
    path.write_text(markdown, encoding="utf-8")
    return str(path.resolve())
