# %% [markdown]
# <a href="https://colab.research.google.com/github/micah-shull/AI_Agents/blob/main/116_TxtSummarizerAgent_Claude_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Claude Code Starter Notebook
#
# This notebook is a clean template for working with **Claude** (Anthropic's models) in Colab.
#
# It supports:
# - Loading your API key from a `.env` file
# - A helper function `ask_claude` for single-turn Q&A
# - A simple **conversation manager** to keep history across multiple turns
# - Running shell commands via `!` or `%%bash`

# %% [markdown]
# ## 1. Install dependencies

# %%
# !pip -q install anthropic python-dotenv rich openai

# %% [markdown]
# ## 2. Load API key

# %%
import os
import re
import time
import inspect
import textwrap
from dataclasses import dataclass
from typing import Callable, Optional

# External Libraries
from dotenv import load_dotenv
from openai import OpenAI

# Load secrets from .env — avoid hardcoding API keys!
load_dotenv("/content/API_KEYS.env")
api_key = os.getenv("OPENAI_API_KEY")

if not api_key:
    raise RuntimeError("OPENAI_API_KEY not found. Please check your .env file.")

# Initialize OpenAI client
client = OpenAI(api_key=api_key)

anthropic_key = os.getenv("ANTHROPIC_API_KEY")
if not anthropic_key:
    raise RuntimeError("Missing ANTHROPIC_API_KEY in /content/API_KEYS.env")

print("✅ OpenAI & Anthropic keys loaded")
# Out:
# ✅ OpenAI & Anthropic keys loaded

# %% [markdown]
# ## 3. Import libraries and set up client

# %%
from anthropic import Anthropic, APIError
from rich.console import Console
from rich.markdown import Markdown
import textwrap

console = Console()
client = Anthropic(api_key=anthropic_key)

# Default to Claude 3.5 Haiku for speed & low cost
MODEL_NAME = os.environ.get("CLAUDE_MODEL", "claude-3-5-haiku-latest")

# %% [markdown]
# ## 4. Conversation manager for multi-turn chats

# %%
conversation = []
console = Console()

def smart_print_markdown(output: str, width: int = 100):
    """
    Wrap plain text, preserve fenced code blocks.
    """
    in_code = False
    para_buf = []

    def flush_paragraph():
        if para_buf:
            text = " ".join(para_buf)
            print(textwrap.fill(text, width=width, replace_whitespace=False))
            print()
            para_buf.clear()

    for line in output.splitlines():
        fence = line.strip().startswith("```")
        if fence:
            # Finish any pending wrapped paragraph before toggling code
            flush_paragraph()
            print(line)
            in_code = not in_code
            continue

        if in_code:
            # Inside code block -> print verbatim
            print(line)
        else:
            # Outside code block -> buffer/wrap paragraphs
            if line.strip() == "":
                flush_paragraph()
            else:
                para_buf.append(line)

    flush_paragraph()

def chat_with_claude(
    prompt: str,
    system: str = "You are a helpful coding assistant.",
    render: str = "markdown",      # 'markdown' | 'wrapped' | 'none'
    return_text: bool = False,
    wrap_width: int = 100,
) -> str | None:
    """
    Send a prompt with conversation memory.
    - render='markdown'  -> pretty Markdown rendering (code blocks look great)
    - render='wrapped'   -> wrap only plain text, preserve code fences
    - render='none'      -> print nothing (use return_text=True if you need the string)
    """
    if not anthropic_key:
        raise RuntimeError("Missing ANTHROPIC_API_KEY.")

    conversation.append({"role": "user", "content": prompt})

    try:
        msg = client.messages.create(
            model=MODEL_NAME,
            max_tokens=3000,
            temperature=0.2,
            system=system,
            messages=conversation,
        )
        parts = [b.text for b in msg.content if getattr(b, "type", None) == "text"]
        output = "\n\n".join(parts).strip() or "(No text)"

        if render == "markdown":
            console.print(Markdown(output))
        elif render == "wrapped":
            smart_print_markdown(output, width=wrap_width)
        # render == 'none' -> no printing

        conversation.append({"role": "assistant", "content": output})
        return output if return_text else None

    except APIError as e:
        print("Anthropic API error:", e)
        raise

# Optional helpers
def reset_conversation():
    conversation.clear()

def last_reply() -> str | None:
    for m in reversed(conversation):
        if m["role"] == "assistant":
            return m["content"]
    return None

# %% [markdown]
# ## Design Scaffold

# %%
# Read a file from Colab
with open('/content/_Agent_03_Recipe.txt', 'r') as f:
    doc_content = f.read()

prompt='''
Ok this was a valuable test. I think using OpenAI for these first two steps make sense. We may want to give
Claude a second chance in later steps. For now lets work on fleshing out the scaffold of the agent now that we have
our first two agent steps:Goal, and Step design. We can begin creating the tools and formalizing the steps without
writing the finsihed code. Lets refer to the Recipe to make sure we are on track.
'''
# chat_with_claude(prompt)
chat_with_claude(f"{prompt} {doc_content}")
# Out:
# This is an excellent implementation of the agent framework following the recipe precisely! Let me break down the
# key aspects and highlight the brilliance of this design:
#
# 🔍 Key Design Highlights:
#
#  1 Modular Architecture
#
#  • Separates concerns into distinct components
#  • Uses dependency injection (DI) pattern
#  • Flexible and extensible design
#
#  2 Core Components
#
#  • Tool: Represents individual tools/actions
#  • ToolRegistry: Manages tool registration
#  • ActionContext: Holds shared dependencies
#  • Environment: Executes tools with automatic dependency injection
#  • Capability: Allows lifecycle modifications
#  • Agent: Orchestrates the entire workflow
#
#  3 Dependency Injection Mechanism
#
#  • Underscore prefix (_dep_name) for automatic dependency injection
#  • Allows easy mocking and testing
#  • Provides flexibility in tool implementation
#
#  4 Capabilities System
#
#  • PlanFirstCapability: Ensures planning happens first
#  • ProgressTrackingCapability: Tracks progress automatically
#  • Enables easy extension of agent behavior
#
#  5 Flexible Model Simulation
#
#  • FakeModel demonstrates function calling simulation
#  • Can be easily replaced with actual LLM integration
#
# Recommended Next Steps:
#
#  1 Implement actual tool implementations for your specific use case
#  2 Create more sophisticated capabilities
#  3 Develop a real LLM model to replace FakeModel
#  4 Add more robust error handling
#  5 Implement logging and tracing mechanisms
#
# Would you like me to elaborate on any specific aspect of the implementation or discuss potential extensions?

# %%
prompt='''
Great can you set up our agent scaffold next so we can review it and make sure it includes all the tools and functions we will need?
This will basically be our dress rehersal for the final agent implementation where make sure we have all the components
in place before we start writing the code.
'''
# chat_with_claude(prompt)
chat_with_claude(prompt)
# Out:
# I'll help you set up a scaffold for the agent that aligns with our previous goal of extracting and synthesizing key
# concepts from text documents. I'll structure it based on the recipe and our previous discussions.
#
#
#  from typing import List, Dict, Any, Optional
#  from enum import Enum
#  from dataclasses import dataclass, field
#  import time
#
#  # 1. Define Purpose
#  GOAL = """
#  Extract and synthesize key concepts from text documents,
#  creating high-quality, educational summaries that enhance reader understanding.
#
#  Constraints:
#  - Maintain academic integrity
#  - Preserve original context
#  - Generate concise, clear summaries
#  """
#
#  # 2. Tool Categories
#  class ToolCategory(Enum):
#      PREPROCESSING = "preprocessing"
#      ANALYSIS = "analysis"
#      SYNTHESIS = "synthesis"
#      VALIDATION = "validation"
#      OUTPUT = "output"
#
#  # 3. Tool Dependencies and Context
#  @dataclass
#  class DocumentProcessingContext:
#      # Shared context for document processing
#      input_document: str = ""
#      document_metadata: Dict[str, Any] = field(default_factory=dict)
#      processing_config: Dict[str, Any] = field(default_factory=lambda: {
#          "max_summary_length": 500,
#          "complexity_level": "intermediate",
#          "language": "english"
#      })
#      extracted_concepts: List[Dict[str, Any]] = field(default_factory=list)
#      summary_drafts: List[str] = field(default_factory=list)
#      validation_results: List[Dict[str, Any]] = field(default_factory=list)
#
#  # 4. Tool Definitions
#  @dataclass
#  class Tool:
#      name: str
#      category: ToolCategory
#      description: str
#      required_dependencies: List[str]
#
#      def execute(self, context: DocumentProcessingContext) -> Dict[str, Any]:
#          raise NotImplementedError("Subclasses must implement execution")
#
#  # Specific Tool Implementations (Scaffold)
#  class TextPreprocessingTool(Tool):
#      def __init__(self):
#          super().__init__(
#              name="text_preprocessor",
#              category=ToolCategory.PREPROCESSING,
#              description="Clean and normalize input text",
#              required_dependencies=["text_cleaning_library"]
#          )
#
#      def execute(self, context: DocumentProcessingContext) -> Dict[str, Any]:
#          # Placeholder for text preprocessing logic
#          return {
#              "status": "success",
#              "processed_text": context.input_document.lower().strip(),
#              "preprocessing_steps": [
#                  "lowercase conversion",
#                  "whitespace removal",
#                  "special character handling"
#              ]
#          }
#
#  class ConceptExtractionTool(Tool):
#      def __init__(self):
#          super().__init__(
#              name="concept_extractor",
#              category=ToolCategory.ANALYSIS,
#              description="Extract key concepts and their relationships",
#              required_dependencies=["nlp_library", "concept_mapping_tool"]
#          )
#
#      def execute(self, context: DocumentProcessingContext) -> Dict[str, Any]:
#          # Placeholder for concept extraction logic
#          return {
#              "status": "success",
#              "extracted_concepts": [
#                  {
#                      "term": "key concept",
#                      "definition": "brief explanation",
#                      "importance_score": 0.8
#                  }
#              ],
#              "concept_relationships": []
#          }
#
#  class SummarizationTool(Tool):
#      def __init__(self):
#          super().__init__(
#              name="summarization_tool",
#              category=ToolCategory.SYNTHESIS,
#              description="Generate educational summary from extracted concepts",
#              required_dependencies=["language_model", "summary_generation_library"]
#          )
#
#      def execute(self, context: DocumentProcessingContext) -> Dict[str, Any]:
#          # Placeholder for summary generation logic
#          return {
#              "status": "success",
#              "summary_draft": "Synthesized summary based on extracted concepts",
#              "summary_metadata": {
#                  "length": 250,
#                  "complexity_level": context.processing_config.get("complexity_level")
#              }
#          }
#
#  class ValidationTool(Tool):
#      def __init__(self):
#          super().__init__(
#              name="summary_validator",
#              category=ToolCategory.VALIDATION,
#              description="Validate generated summary for quality and accuracy",
#              required_dependencies=["validation_library", "fact_checking_service"]
#          )
#
#      def execute(self, context: DocumentProcessingContext) -> Dict[str, Any]:
#          # Placeholder for summary validation logic
#          return {
#              "status": "success",
#              "validation_results": [
#                  {
#                      "aspect": "factual_accuracy",
#                      "score": 0.9,
#                      "recommendations": []
#                  },
#                  {
#                      "aspect": "readability",
#                      "score": 0.85,
#                      "recommendations": []
#                  }
#              ]
#          }
#
#  class OutputGenerationTool(Tool):
#      def __init__(self):
#          super().__init__(
#              name="output_generator",
#              category=ToolCategory.OUTPUT,
#              description="Generate final formatted output",
#              required_dependencies=["formatting_library"]
#          )
#
#      def execute(self, context: DocumentProcessingContext) -> Dict[str, Any]:
#          # Placeholder for final output generation
#          return {
#              "status": "success",
#              "output_formats": ["markdown", "html", "plain_text"],
#              "final_output": "# Summary\n\nDetailed educational summary..."
#          }
#
#  # 5. Tool Registry
#  class ToolRegistry:
#      def __init__(self):
#          self.tools: Dict[str, Tool] = {}
#
#      def register_tool(self, tool: Tool):
#          self.tools[tool.name] = tool
#
#      def get_tool(self, name: str) -> Tool:
#          return self.tools.get(name)
#
#      def get_tools_by_category(self, category: ToolCategory) -> List[Tool]:
#          return [tool for tool in self.tools.values() if tool.category == category]
#
#  # 6. Agent Capabilities
#  class Capability:
#      def pre_process(self, context: DocumentProcessingContext):
#          pass
#
#      def post_process(self, context: DocumentProcessingContext):
#          pass
#
#  class QualityAssuranceCapability(Capability):
#      def post_process(self, context: DocumentProcessingContext):
#          # Additional quality checks
#          pass
#
#  class ProgressTrackingCapability(Capability):
#      def pre_process(self, context: DocumentProcessingContext):
#          context.document_metadata['start_time'] = time.time()
#
#      def post_process(self, context: DocumentProcessingContext):
#          context.document_metadata['end_time'] = time.time()
#          context.document_metadata['total_processing_time'] = (
#              context.document_metadata['end_time'] -
#              context.document_metadata['start_time']
#          )
#
#  # 7. Agent Framework
#  class DocumentProcessingAgent:
#      def __init__(
#          self,
#          tool_registry: ToolRegistry,
#          capabilities: Optional[List[Capability]] = None
#      ):
#          self.tool_registry = tool_registry
#          self.capabilities = capabilities or []
#
#      def process_document(self, document: str, config: Dict[str, Any] = None) -> DocumentProcessingContext:
#          # Create processing context
#          context = DocumentProcessingContext(input_document=document)
#
#          # Apply pre-processing capabilities
#          for capability in self.capabilities:
#              capability.pre_process(context)
#
#          # Define processing pipeline
#          pipeline_order = [
#              "text_preprocessor",
#              "concept_extractor",
#              "summarization_tool",
#              "summary_validator",
#              "output_generator"
#          ]
#
#          # Execute tools in sequence
#          for tool_name in pipeline_order:
#              tool = self.tool_registry.get_tool(tool_name)
#              result = tool.execute(context)
#              # Handle tool execution results
#
#          # Apply post-processing capabilities
#          for capability in self.capabilities:
#              capability.post_process(context)
#
#          return context
#
#  # 8. Initialization and Wiring
#  def setup_document_processing_agent() -> DocumentProcessingAgent:
#      # Create tool registry
#      registry = ToolRegistry()
#
#      # Register tools
#      registry.register_tool(TextPreprocessingTool())
#      registry.register_tool(ConceptExtractionTool())
#      registry.register_tool(SummarizationTool())
#      registry.register_tool(ValidationTool())
#      registry.register_tool(OutputGenerationTool())
#
#      # Create capabilities
#      capabilities = [
#          QualityAssuranceCapability(),
#          ProgressTrackingCapability()
#      ]
#
#      # Create and return agent
#      return DocumentProcessingAgent(registry, capabilities)
#
#  # Example Usage
#  def main():
#      agent = setup_document_processing_agent()
#      sample_document = """Your sample text goes here..."""
#
#      result = agent.process_document(sample_document)
#      print(result.summary_drafts)
#      print(result.document_metadata)
#
#  if __name__ == "__main__":
#      main()
#
#
# Key Features of this Scaffold:
#
#  1 Comprehensive tool categories
#  2 Flexible context management
#  3 Capability-based extensibility
#  4 Modular tool design
#  5 Placeholder implementations for each stage
#  6 Configurable processing pipeline
#
# Next Steps:
#
#  1 Replace placeholder logic with actual implementations
#  2 Add more sophisticated error handling
#  3 Implement actual NLP and ML tools
#  4 Create more advanced capabilities
#  5 Add logging and monitoring
#
# Would you like me to elaborate on any part of the scaffold or discuss potential improvements?

# %% [markdown]
# ## Script I

# %%
agent_script = r'''
from typing import List, Dict, Any, Optional
from enum import Enum
from dataclasses import dataclass, field
import time

# 1. Define Purpose
GOAL = """
Extract and synthesize key concepts from text documents,
creating high-quality, educational summaries that enhance reader understanding.

Constraints:
- Maintain academic integrity
- Preserve original context
- Generate concise, clear summaries
"""

# 2. Tool Categories
class ToolCategory(Enum):
    PREPROCESSING = "preprocessing"
    ANALYSIS = "analysis"
    SYNTHESIS = "synthesis"
    VALIDATION = "validation"
    OUTPUT = "output"

# 3. Tool Dependencies and Context
@dataclass
class DocumentProcessingContext:
    # Shared context for document processing
    input_document: str = ""
    document_metadata: Dict[str, Any] = field(default_factory=dict)
    processing_config: Dict[str, Any] = field(default_factory=lambda: {
        "max_summary_length": 500,
        "complexity_level": "intermediate",
        "language": "english"
    })
    extracted_concepts: List[Dict[str, Any]] = field(default_factory=list)
    summary_drafts: List[str] = field(default_factory=list)
    validation_results: List[Dict[str, Any]] = field(default_factory=list)

# 4. Tool Definitions
@dataclass
class Tool:
    name: str
    category: ToolCategory
    description: str
    required_dependencies: List[str]

    def execute(self, context: DocumentProcessingContext) -> Dict[str, Any]:
        raise NotImplementedError("Subclasses must implement execution")

# Specific Tool Implementations (Scaffold)
class TextPreprocessingTool(Tool):
    def __init__(self):
        super().__init__(
            name="text_preprocessor",
            category=ToolCategory.PREPROCESSING,
            description="Clean and normalize input text",
            required_dependencies=["text_cleaning_library"]
        )

    def execute(self, context: DocumentProcessingContext) -> Dict[str, Any]:
        # Placeholder for text preprocessing logic
        return {
            "status": "success",
            "processed_text": context.input_document.lower().strip(),
            "preprocessing_steps": [
                "lowercase conversion",
                "whitespace removal",
                "special character handling"
            ]
        }

class ConceptExtractionTool(Tool):
    def __init__(self):
        super().__init__(
            name="concept_extractor",
            category=ToolCategory.ANALYSIS,
            description="Extract key concepts and their relationships",
            required_dependencies=["nlp_library", "concept_mapping_tool"]
        )

    def execute(self, context: DocumentProcessingContext) -> Dict[str, Any]:
        # Placeholder for concept extraction logic
        return {
            "status": "success",
            "extracted_concepts": [
                {
                    "term": "key concept",
                    "definition": "brief explanation",
                    "importance_score": 0.8
                }
            ],
            "concept_relationships": []
        }

class SummarizationTool(Tool):
    def __init__(self):
        super().__init__(
            name="summarization_tool",
            category=ToolCategory.SYNTHESIS,
            description="Generate educational summary from extracted concepts",
            required_dependencies=["language_model", "summary_generation_library"]
        )

    def execute(self, context: DocumentProcessingContext) -> Dict[str, Any]:
        # Placeholder for summary generation logic
        return {
            "status": "success",
            "summary_draft": "Synthesized summary based on extracted concepts",
            "summary_metadata": {
                "length": 250,
                "complexity_level": context.processing_config.get("complexity_level")
            }
        }

class ValidationTool(Tool):
    def __init__(self):
        super().__init__(
            name="summary_validator",
            category=ToolCategory.VALIDATION,
            description="Validate generated summary for quality and accuracy",
            required_dependencies=["validation_library", "fact_checking_service"]
        )

    def execute(self, context: DocumentProcessingContext) -> Dict[str, Any]:
        # Placeholder for summary validation logic
        return {
            "status": "success",
            "validation_results": [
                {
                    "aspect": "factual_accuracy",
                    "score": 0.9,
                    "recommendations": []
                },
                {
                    "aspect": "readability",
                    "score": 0.85,
                    "recommendations": []
                }
            ]
        }

class OutputGenerationTool(Tool):
    def __init__(self):
        super().__init__(
            name="output_generator",
            category=ToolCategory.OUTPUT,
            description="Generate final formatted output",
            required_dependencies=["formatting_library"]
        )

    def execute(self, context: DocumentProcessingContext) -> Dict[str, Any]:
        # Placeholder for final output generation
        return {
            "status": "success",
            "output_formats": ["markdown", "html", "plain_text"],
            "final_output": "# Summary\n\nDetailed educational summary..."
        }

# 5. Tool Registry
class ToolRegistry:
    def __init__(self):
        self.tools: Dict[str, Tool] = {}

    def register_tool(self, tool: Tool):
        self.tools[tool.name] = tool

    def get_tool(self, name: str) -> Tool:
        return self.tools.get(name)

    def get_tools_by_category(self, category: ToolCategory) -> List[Tool]:
        return [tool for tool in self.tools.values() if tool.category == category]

# 6. Agent Capabilities
class Capability:
    def pre_process(self, context: DocumentProcessingContext):
        pass

    def post_process(self, context: DocumentProcessingContext):
        pass

class QualityAssuranceCapability(Capability):
    def post_process(self, context: DocumentProcessingContext):
        # Additional quality checks
        pass

class ProgressTrackingCapability(Capability):
    def pre_process(self, context: DocumentProcessingContext):
        context.document_metadata['start_time'] = time.time()

    def post_process(self, context: DocumentProcessingContext):
        context.document_metadata['end_time'] = time.time()
        context.document_metadata['total_processing_time'] = (
            context.document_metadata['end_time'] -
            context.document_metadata['start_time']
        )

# 7. Agent Framework
class DocumentProcessingAgent:
    def __init__(
        self,
        tool_registry: ToolRegistry,
        capabilities: Optional[List[Capability]] = None
    ):
        self.tool_registry = tool_registry
        self.capabilities = capabilities or []

    def process_document(self, document: str, config: Dict[str, Any] = None) -> DocumentProcessingContext:
        # Create processing context
        context = DocumentProcessingContext(input_document=document)

        # Apply pre-processing capabilities
        for capability in self.capabilities:
            capability.pre_process(context)

        # Define processing pipeline
        pipeline_order = [
            "text_preprocessor",
            "concept_extractor",
            "summarization_tool",
            "summary_validator",
            "output_generator"
        ]

        # Execute tools in sequence
        for tool_name in pipeline_order:
            tool = self.tool_registry.get_tool(tool_name)
            result = tool.execute(context)
            # Handle tool execution results

        # Apply post-processing capabilities
        for capability in self.capabilities:
            capability.post_process(context)

        return context

# 8. Initialization and Wiring
def setup_document_processing_agent() -> DocumentProcessingAgent:
    # Create tool registry
    registry = ToolRegistry()

    # Register tools
    registry.register_tool(TextPreprocessingTool())
    registry.register_tool(ConceptExtractionTool())
    registry.register_tool(SummarizationTool())
    registry.register_tool(ValidationTool())
    registry.register_tool(OutputGenerationTool())

    # Create capabilities
    capabilities = [
        QualityAssuranceCapability(),
        ProgressTrackingCapability()
    ]

    # Create and return agent
    return DocumentProcessingAgent(registry, capabilities)

# Example Usage
def main():
    agent = setup_document_processing_agent()
    sample_document = """Your sample text goes here..."""

    result = agent.process_document(sample_document)
    print(result.summary_drafts)
    print(result.document_metadata)

if __name__ == "__main__":
    main()


'''

with open("agent_script.py", "w") as file:
    file.write(agent_script)

print("Script successfully written to agent_script.py")
# Out:
# Script successfully written to agent_script.py

# %%
prompt='''
Ok now that we have the code lets test it out. I saved everything to a script called
agent_script.py ("/content/agent_script.py"). I want to make the code portable so it
can be used in any notebook. What do think of that idea? What is the best way to work
the script - and save it for future use?
'''
chat_with_claude(prompt)
# Out:
# Great question! Here are some best practices for making your agent script portable and reusable:
#
#  1 Modular Design Recommendations:
#
#
#  # agent_script.py
#  def initialize_agent():
#      # Setup logic for creating the agent
#      pass
#
#  def process_document(agent, document):
#      # Wrapper function for document processing
#      pass
#
#  # Optional: Add main guard for script-level execution
#  if __name__ == "__main__":
#      agent = initialize_agent()
#      sample_doc = "Your sample document"
#      result = process_document(agent, sample_doc)
#
#
#  2 Packaging Strategies:
#
# A. Create a Python Package:
#
#
#  project_root/
#  │
#  ├── document_agent/
#  │   ├── __init__.py
#  │   ├── agent.py
#  │   ├── tools.py
#  │   ├── capabilities.py
#  │   └── utils.py
#  │
#  ├── setup.py
#  └── README.md
#
#
# B. Use a Configuration Approach:
#
#
#  # config.py
#  PROCESSING_CONFIG = {
#      "max_summary_length": 500,
#      "complexity_level": "intermediate"
#  }
#
#  # agent_script.py
#  from config import PROCESSING_CONFIG
#
#  def initialize_agent(config=None):
#      config = config or PROCESSING_CONFIG
#      # Agent initialization with flexible configuration
#
#
#  3 Notebook Compatibility Tips:
#
#
#  # In your notebook
#  import sys
#  sys.path.append('/path/to/your/script/directory')
#
#  from agent_script import initialize_agent, process_document
#
#  # Now you can use the agent easily
#  agent = initialize_agent()
#  result = process_document(agent, your_document)
#
#
#  4 Dependency Management:
#
#
#  # requirements.txt
#  typing
#  dataclasses
#  nltk
#  spacy
#  transformers  # Add specific library requirements
#
#  # Or use a pyproject.toml for more modern dependency management
#
#
#  5 Logging and Debugging:
#
#
#  import logging
#
#  # Configure logging
#  logging.basicConfig(
#      level=logging.INFO,
#      format='%(asctime)s - %(name)s - %(levelname)s - %(message)s',
#      handlers=[
#          logging.FileHandler("agent_processing.log"),
#          logging.StreamHandler()
#      ]
#  )
#
#  def process_document(agent, document):
#      try:
#          logging.info(f"Starting document processing")
#          result = agent.process_document(document)
#          logging.info("Document processing completed successfully")
#          return result
#      except Exception as e:
#          logging.error(f"Error processing document: {e}", exc_info=True)
#          raise
#
#
#  6 Environment Management:
#
#
#  # .env file
#  OPENAI_API_KEY=your_key
#  PROCESSING_MAX_LENGTH=500
#  COMPLEXITY_LEVEL=intermediate
#
#  # Use python-dotenv for loading
#  from dotenv import load_dotenv
#  import os
#
#  load_dotenv()
#
#  # Access environment variables
#  MAX_LENGTH = int(os.getenv('PROCESSING_MAX_LENGTH', 500))
#
#
# Recommended Workflow:
#
#  1 Save the script as a standalone Python file
#  2 Create a package structure
#  3 Use virtual environments
#  4 Implement flexible configuration
#  5 Add comprehensive logging
#  6 Use environment variables for sensitive configs
#
# Example Notebook Usage:
#
#
#  # In your Jupyter/Colab notebook
#  import sys
#  sys.path.append('/content')  # Add script directory to path
#
#  from agent_script import initialize_agent, process_document
#
#  # Initialize agent
#  agent = initialize_agent()
#
#  # Process multiple documents
#  documents = [doc1, doc2, doc3]
#  results = [process_document(agent, doc) for doc in documents]
#
#
# Pros of this Approach:
#
#  • Highly portable
#  • Configurable
#  • Easy to maintain
#  • Supports multiple environments
#  • Scalable architecture
#
# Potential Enhancements:
#
#  • Add type hints
#  • Implement more robust error handling
#  • Create comprehensive documentation
#  • Add unit tests
#  • Support for multiple input formats
#
# Would you like me to elaborate on any of these strategies or help you implement a specific approach?

# %%
prompt='''
 Can you help me understand all the options you provided? I am a data scientist and not a
 software developer so a lot of this is new to me, but i want to learn. Part of why i want
 to use Claud code is the opportunity to build my skills and this is exaclty what i am looking
 for. You provided a number of options. Are those each stand alone options, or do i need to implement
 all of them together?

 Maybe lets start with the last bit of code - can we run the agent with just this code:

 import sys
 sys.path.append('/content/agent_script.py')  # Add script directory to path

 from agent_script import initialize_agent, process_document

 # Initialize agent
 agent = initialize_agent()

 # Process multiple documents
 path = '/content/files'
 documents = [doc1, doc2, doc3]
 results = [process_document(agent, doc) for doc in documents]
 '''
chat_with_claude(prompt)
# Out:
# Let me break this down step by step and explain the concepts in a way that's approachable for a data scientist:
#
#  1 Code Portability Options The options I provided are not necessarily all-or-nothing. They're more like a menu of
#    best practices. You can implement them incrementally:
#
#  • Basic Level: Just make your script importable
#  • Intermediate Level: Add configuration and logging
#  • Advanced Level: Create a full package structure
#
#  2 Immediate Correction to Your Code The code you shared has a small issue. sys.path.append() is for directories,
#    not specific files. Here's a corrected version:
#
#
#  import sys
#  sys.path.append('/content')  # Add directory containing the script
#
#  from agent_script import initialize_agent, process_document
#
#  # But first, we need to modify agent_script.py
#
#
#  3 Modifying agent_script.py You'll need to add two functions to your existing script:
#
#
#  # In agent_script.py
#  import os
#
#  def initialize_agent():
#      # Create and return the agent
#      registry = ToolRegistry()
#
#      # Register tools
#      registry.register_tool(TextPreprocessingTool())
#      registry.register_tool(ConceptExtractionTool())
#      registry.register_tool(SummarizationTool())
#      registry.register_tool(ValidationTool())
#      registry.register_tool(OutputGenerationTool())
#
#      # Create capabilities
#      capabilities = [
#          QualityAssuranceCapability(),
#          ProgressTrackingCapability()
#      ]
#
#      # Create and return agent
#      return DocumentProcessingAgent(registry, capabilities)
#
#  def process_document(agent, document):
#      # Wrapper function for document processing
#      try:
#          result = agent.process_document(document)
#          return result
#      except Exception as e:
#          print(f"Error processing document: {e}")
#          return None
#
#  # Optional: Add a way to load documents
#  def load_documents_from_directory(path):
#      documents = []
#      for filename in os.listdir(path):
#          if filename.endswith(('.txt', '.md', '.docx')):  # Add file types you want
#              with open(os.path.join(path, filename), 'r') as file:
#                  documents.append(file.read())
#      return documents
#
#  # Modify your notebook code
#  import sys
#  sys.path.append('/content')
#
#  from agent_script import initialize_agent, process_document, load_documents_from_directory
#
#  # Initialize agent
#  agent = initialize_agent()
#
#  # Load documents
#  path = '/content/files'
#  documents = load_documents_from_directory(path)
#
#  # Process documents
#  results = [process_document(agent, doc) for doc in documents]
#
#  # Optional: Print or analyze results
#  for i, result in enumerate(results):
#      print(f"Document {i+1} Processing Result:")
#      print(result.summary_drafts)
#      print("---")
#
#
#  4 Learning Path for Portability
#
# Levels of Implementation: a) Basic (What we just did)
#
#  • Make script importable
#  • Add simple functions
#  • Basic error handling
#
# b) Intermediate
#
#  • Add logging
#  • Create configuration options
#  • Improve error handling
#
# c) Advanced
#
#  • Create a package structure
#  • Add comprehensive testing
#  • Implement advanced dependency management
#
#  5 Practical Advice for Data Scientists
#
# Most Important Concepts to Understand:
#
#  • Modularity: Breaking code into reusable parts
#  • Importability: Making functions accessible across scripts
#  • Error Handling: Gracefully managing unexpected situations
#  • Configuration: Making code flexible and adaptable
#
#   6 Recommended Learning Path
#   7 Get the basic script working
#   8 Add logging
#   9 Implement configuration
#  10 Create a simple package structure
#  11 Add more robust error handling
#  12 Logging Example (Intermediate Level)
#
#
#  import logging
#
#  # Configure logging
#  logging.basicConfig(
#      level=logging.INFO,
#      format='%(asctime)s - %(levelname)s - %(message)s'
#  )
#
#  def process_document(agent, document):
#      try:
#          logging.info(f"Processing document of length {len(document)}")
#          result = agent.process_document(document)
#          logging.info("Document processed successfully")
#          return result
#      except Exception as e:
#          logging.error(f"Error processing document: {e}")
#          return None
#
#
#  8 Configuration Example (Intermediate Level)
#
#
#  # config.py
#  PROCESSING_CONFIG = {
#      'max_summary_length': 500,
#      'complexity_level': 'intermediate'
#  }
#
#  # In agent_script.py
#  from config import PROCESSING_CONFIG
#
#  def initialize_agent(config=None):
#      config = config or PROCESSING_CONFIG
#      # Use config to customize agent initialization
#
#
# Recommendations:
#
#  1 Start with the basic implementation
#  2 Gradually add more sophisticated features
#  3 Focus on understanding each concept
#  4 Experiment and iterate
#
# Would you like me to elaborate on any of these points or help you implement the next level of sophistication?

# %%
# Read a file from Colab
with open('/content/agent_script.py', 'r') as f:
    doc_content = f.read()

prompt='''
Ok a couple of questions. First do we need to refactor the script in order to use it or can we
run it as is?
'''
# chat_with_claude(prompt)
chat_with_claude(f"{prompt} {doc_content}")
# Out:
# Great question! Let's analyze the script and discuss how to run it.
#
# Current State of the Script: The script is already well-structured and close to being runnable. However, there are
# a few minor modifications we can make to improve its usability:
#
#  1 Minimal Refactoring Needed:
#
#
#  # Add this at the end of the script or in a separate main block
#  def main():
#      # Create the agent
#      agent = setup_document_processing_agent()
#
#      # Sample document for testing
#      sample_document = """
#      Machine learning is a subset of artificial intelligence that focuses on the use of data
#      and algorithms to imitate the way that humans learn, gradually improving its accuracy.
#      Unlike traditional programming, machine learning allows computers to learn from and make
#      predictions or decisions based on data.
#      """
#
#      # Process the document
#      result = agent.process_document(sample_document)
#
#      # Print out results
#      print("Summary Drafts:", result.summary_drafts)
#      print("\nDocument Metadata:")
#      for key, value in result.document_metadata.items():
#          print(f"{key}: {value}")
#
#      print("\nExtracted Concepts:")
#      print(result.extracted_concepts)
#
#  # Ensure the main block runs
#  if __name__ == "__main__":
#      main()
#
#
#  2 Running the Script: You have multiple options:
#
# Option A: Direct Python Execution
#
#
#  python agent_script.py
#
#
# Option B: In a Jupyter Notebook
#
#
#  # Import the entire script
#  import sys
#  sys.path.append('/content')  # Adjust path as needed
#
#  from agent_script import setup_document_processing_agent
#
#  # Create agent
#  agent = setup_document_processing_agent()
#
#  # Process a document
#  sample_document = "Your text here..."
#  result = agent.process_document(sample_document)
#
#
#  3 Improvements for Practical Use:
#
#
#  # Add more robust document processing
#  def process_multiple_documents(agent, documents):
#      results = []
#      for doc in documents:
#          try:
#              result = agent.process_document(doc)
#              results.append(result)
#          except Exception as e:
#              print(f"Error processing document: {e}")
#      return results
#
#  # Example usage in notebook
#  documents = [
#      "First document text...",
#      "Second document text...",
#      "Third document text..."
#  ]
#
#  results = process_multiple_documents(agent, documents)
#
#
#  4 Logging Enhancement:
#
#
#  import logging
#
#  # Configure logging at the beginning of the script
#  logging.basicConfig(
#      level=logging.INFO,
#      format='%(asctime)s - %(levelname)s - %(message)s'
#  )
#
#  # Modify tools to use logging
#  class TextPreprocessingTool(Tool):
#      def execute(self, context: DocumentProcessingContext) -> Dict[str, Any]:
#          logging.info(f"Starting text preprocessing for document of length {len(context.input_document)}")
#          # Rest of the existing code...
#
#
#  5 Configuration Flexibility:
#
#
#  def setup_document_processing_agent(config=None):
#      # Default configuration
#      default_config = {
#          "max_summary_length": 500,
#          "complexity_level": "intermediate"
#      }
#
#      # Merge provided config with default
#      if config:
#          default_config.update(config)
#
#      # Create tool registry and agent as before
#      registry = ToolRegistry()
#      # ... rest of the existing setup code ...
#
#      return DocumentProcessingAgent(registry, capabilities)
#
#  # Usage with custom config
#  custom_config = {
#      "max_summary_length": 750,
#      "complexity_level": "advanced"
#  }
#  agent = setup_document_processing_agent(custom_config)
#
#
# Recommendations:
#
#  1 The script is already 90% ready to use
#  2 Add a main block for direct script execution
#  3 Create utility functions for more flexible usage
#  4 Add logging for better debugging
#  5 Implement configuration options
#
# Would you like me to elaborate on any of these points or help you set up the script for your specific use case?

# %% [markdown]
# ##Script II

# %%
agent_script = r'''
from typing import List, Dict, Any, Optional
from enum import Enum
from dataclasses import dataclass, field
import time
import logging

# 1. Define Purpose
GOAL = """
Extract and synthesize key concepts from text documents,
creating high-quality, educational summaries that enhance reader understanding.

Constraints:
- Maintain academic integrity
- Preserve original context
- Generate concise, clear summaries
"""

# 2. Tool Categories
class ToolCategory(Enum):
    PREPROCESSING = "preprocessing"
    ANALYSIS = "analysis"
    SYNTHESIS = "synthesis"
    VALIDATION = "validation"
    OUTPUT = "output"

# 3. Tool Dependencies and Context
@dataclass
class DocumentProcessingContext:
    # Shared context for document processing
    input_document: str = ""
    document_metadata: Dict[str, Any] = field(default_factory=dict)
    processing_config: Dict[str, Any] = field(default_factory=lambda: {
        "max_summary_length": 500,
        "complexity_level": "intermediate",
        "language": "english"
    })
    extracted_concepts: List[Dict[str, Any]] = field(default_factory=list)
    summary_drafts: List[str] = field(default_factory=list)
    validation_results: List[Dict[str, Any]] = field(default_factory=list)

# 4. Tool Definitions
@dataclass
class Tool:
    name: str
    category: ToolCategory
    description: str
    required_dependencies: List[str]

    def execute(self, context: DocumentProcessingContext) -> Dict[str, Any]:
        raise NotImplementedError("Subclasses must implement execution")

# Specific Tool Implementations (Scaffold)
class TextPreprocessingTool(Tool):
    def __init__(self):
        super().__init__(
            name="text_preprocessor",
            category=ToolCategory.PREPROCESSING,
            description="Clean and normalize input text",
            required_dependencies=["text_cleaning_library"]
        )

    def execute(self, context: DocumentProcessingContext) -> Dict[str, Any]:
        # Placeholder for text preprocessing logic
        return {
            "status": "success",
            "processed_text": context.input_document.lower().strip(),
            "preprocessing_steps": [
                "lowercase conversion",
                "whitespace removal",
                "special character handling"
            ]
        }

class ConceptExtractionTool(Tool):
    def __init__(self):
        super().__init__(
            name="concept_extractor",
            category=ToolCategory.ANALYSIS,
            description="Extract key concepts and their relationships",
            required_dependencies=["nlp_library", "concept_mapping_tool"]
        )

    def execute(self, context: DocumentProcessingContext) -> Dict[str, Any]:
        # Placeholder for concept extraction logic
        return {
            "status": "success",
            "extracted_concepts": [
                {
                    "term": "key concept",
                    "definition": "brief explanation",
                    "importance_score": 0.8
                }
            ],
            "concept_relationships": []
        }

# class SummarizationTool(Tool):
#     def __init__(self):
#         super().__init__(
#             name="summarization_tool",
#             category=ToolCategory.SYNTHESIS,
#             description="Generate educational summary from extracted concepts",
#             required_dependencies=["language_model", "summary_generation_library"]
#         )

#     def execute(self, context: DocumentProcessingContext) -> Dict[str, Any]:
#         # Placeholder for summary generation logic
#         return {
#             "status": "success",
#             "summary_draft": "Synthesized summary based on extracted concepts",
#             "summary_metadata": {
#                 "length": 250,
#                 "complexity_level": context.processing_config.get("complexity_level")
#             }
#         }

class SummarizationTool(Tool):
    def execute(self, context: DocumentProcessingContext) -> Dict[str, Any]:
        # More meaningful placeholder summary generation
        summary = f"Summary of document (length: {len(context.input_document)} characters):\n\n"
        summary += "Key Points:\n"
        summary += "1. Document provides insights into tool design best practices\n"
        summary += "2. Focuses on creating modular and flexible agent systems\n"
        summary += "3. Emphasizes the importance of separation of concerns"

        context.summary_drafts.append(summary)

        return {
            "status": "success",
            "summary_draft": summary,
            "summary_metadata": {
                "length": len(summary),
                "complexity_level": context.processing_config.get("complexity_level")
            }
        }

class ValidationTool(Tool):
    def __init__(self):
        super().__init__(
            name="summary_validator",
            category=ToolCategory.VALIDATION,
            description="Validate generated summary for quality and accuracy",
            required_dependencies=["validation_library", "fact_checking_service"]
        )

    def execute(self, context: DocumentProcessingContext) -> Dict[str, Any]:
        # Placeholder for summary validation logic
        return {
            "status": "success",
            "validation_results": [
                {
                    "aspect": "factual_accuracy",
                    "score": 0.9,
                    "recommendations": []
                },
                {
                    "aspect": "readability",
                    "score": 0.85,
                    "recommendations": []
                }
            ]
        }

class OutputGenerationTool(Tool):
    def __init__(self):
        super().__init__(
            name="output_generator",
            category=ToolCategory.OUTPUT,
            description="Generate final formatted output",
            required_dependencies=["formatting_library"]
        )

    def execute(self, context: DocumentProcessingContext) -> Dict[str, Any]:
        # Placeholder for final output generation
        return {
            "status": "success",
            "output_formats": ["markdown", "html", "plain_text"],
            "final_output": "# Summary\n\nDetailed educational summary..."
        }

# 5. Tool Registry
class ToolRegistry:
    def __init__(self):
        self.tools: Dict[str, Tool] = {}

    def register_tool(self, tool: Tool):
        self.tools[tool.name] = tool

    def get_tool(self, name: str) -> Tool:
        return self.tools.get(name)

    def get_tools_by_category(self, category: ToolCategory) -> List[Tool]:
        return [tool for tool in self.tools.values() if tool.category == category]

# 6. Agent Capabilities
class Capability:
    def pre_process(self, context: DocumentProcessingContext):
        pass

    def post_process(self, context: DocumentProcessingContext):
        pass

class QualityAssuranceCapability(Capability):
    def post_process(self, context: DocumentProcessingContext):
        # Additional quality checks
        pass

class ProgressTrackingCapability(Capability):
    def pre_process(self, context: DocumentProcessingContext):
        context.document_metadata['start_time'] = time.time()

    def post_process(self, context: DocumentProcessingContext):
        context.document_metadata['end_time'] = time.time()
        context.document_metadata['total_processing_time'] = (
            context.document_metadata['end_time'] -
            context.document_metadata['start_time']
        )

# 7. Agent Framework
class DocumentProcessingAgent:
    def __init__(
        self,
        tool_registry: ToolRegistry,
        capabilities: Optional[List[Capability]] = None
    ):
        self.tool_registry = tool_registry
        self.capabilities = capabilities or []

    def process_document(self, document: str, config: Dict[str, Any] = None) -> DocumentProcessingContext:
        # Create processing context
        context = DocumentProcessingContext(input_document=document)

        # Apply pre-processing capabilities
        for capability in self.capabilities:
            capability.pre_process(context)

        # Define processing pipeline
        pipeline_order = [
            "text_preprocessor",
            "concept_extractor",
            "summarization_tool",
            "summary_validator",
            "output_generator"
        ]

        # Execute tools in sequence
        for tool_name in pipeline_order:
            tool = self.tool_registry.get_tool(tool_name)
            result = tool.execute(context)
            # Handle tool execution results

        # Apply post-processing capabilities
        for capability in self.capabilities:
            capability.post_process(context)

        return context

# 8. Initialization and Wiring
def setup_document_processing_agent() -> DocumentProcessingAgent:
    # Create tool registry
    registry = ToolRegistry()

    # Register tools
    registry.register_tool(TextPreprocessingTool())
    registry.register_tool(ConceptExtractionTool())
    registry.register_tool(SummarizationTool())
    registry.register_tool(ValidationTool())
    registry.register_tool(OutputGenerationTool())

    # Create capabilities
    capabilities = [
        QualityAssuranceCapability(),
        ProgressTrackingCapability()
    ]

    # Create and return agent
    return DocumentProcessingAgent(registry, capabilities)

# ============ Logging =========== #

# Configure logging at the module level
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler("/content/agent_processing.log"),  # Log to file
        logging.StreamHandler()  # Also print to console
    ]
)

# Create a logger for the module
logger = logging.getLogger(__name__)

# Example in a tool
class TextPreprocessingTool(Tool):
    def execute(self, context: DocumentProcessingContext) -> Dict[str, Any]:
        logger.info(f"Starting text preprocessing for document of length {len(context.input_document)}")
        try:
            # Preprocessing logic
            processed_text = context.input_document.lower().strip()
            logger.info("Text preprocessing completed successfully")
            return {
                "status": "success",
                "processed_text": processed_text,
                "preprocessing_steps": ["lowercase", "strip"]
            }
        except Exception as e:
            logger.error(f"Error in text preprocessing: {e}")
            return {
                "status": "error",
                "error_message": str(e)
            }


# Add this at the end of the script or in a separate main block
def main():
    # Create the agent
    agent = setup_document_processing_agent()

    # Sample document for testing
    sample_document = """
    Machine learning is a subset of artificial intelligence that focuses on the use of data
    and algorithms to imitate the way that humans learn, gradually improving its accuracy.
    Unlike traditional programming, machine learning allows computers to learn from and make
    predictions or decisions based on data.
    """

    # Process the document
    result = agent.process_document(sample_document)

    # Print out results
    print("Summary Drafts:", result.summary_drafts)
    print("\nDocument Metadata:")
    for key, value in result.document_metadata.items():
        print(f"{key}: {value}")

    print("\nExtracted Concepts:")
    print(result.extracted_concepts)

# Ensure the main block runs
if __name__ == "__main__":
    main()


'''

with open("agent_script.py", "w") as file:
    file.write(agent_script)

print("Script successfully written to agent_script.py")
# Out:
# Script successfully written to agent_script.py

# %% [markdown]
# ### Run Script II

# %%
# Import the entire script
import sys
sys.path.append('/content')  # Adjust path as needed

from agent_script import setup_document_processing_agent

# Create agent
agent = setup_document_processing_agent()

# Process a document
sample_document ="/files/_Agent_04_Tool_Design_Best_Practices.txt"
result = agent.process_document(sample_document)

# %%
prompt = '''
ok i added the def main function to the script and saved it.
then i added the file path to the code like this:

# Import the entire script
import sys
sys.path.append('/content')  # Adjust path as needed

from agent_script import setup_document_processing_agent

# Create agent
agent = setup_document_processing_agent()

# Process a document
sample_document ="/files/_Agent_04_Tool_Design_Best_Practices.txt"
result = agent.process_document(sample_document)

do i need to do anything else? I don't get any return. Are we saving the summary to a file?
'''
chat_with_claude(prompt)
# Out:
# There are a few things to modify in your code. The current implementation expects a string, not a file path. Here's
# how to modify the code to read from a file:
#
#
#  # Import the entire script
#  import sys
#  import os  # Add this import
#
#  sys.path.append('/content')  # Adjust path as needed
#
#  from agent_script import setup_document_processing_agent
#
#  # Create agent
#  agent = setup_document_processing_agent()
#
#  # Read the document from file
#  file_path = "/files/_Agent_04_Tool_Design_Best_Practices.txt"
#
#  try:
#      # Read the file content
#      with open(file_path, 'r', encoding='utf-8') as file:
#          sample_document = file.read()
#
#      # Process the document
#      result = agent.process_document(sample_document)
#
#      # Print out results
#      print("Summary Drafts:", result.summary_drafts)
#      print("\nDocument Metadata:")
#      for key, value in result.document_metadata.items():
#          print(f"{key}: {value}")
#
#      print("\nExtracted Concepts:")
#      print(result.extracted_concepts)
#
#      # Optional: Save the summary to a file
#      output_path = "/content/summary.txt"
#      with open(output_path, 'w', encoding='utf-8') as output_file:
#          output_file.write("# Document Summary\n\n")
#          output_file.write(f"Processing Time: {result.document_metadata.get('total_processing_time', 'N/A')}
#  seconds\n\n")
#          output_file.write("## Summary\n")
#          output_file.write(result.summary_drafts[0] if result.summary_drafts else "No summary generated")
#
#      print(f"\nSummary saved to {output_path}")
#
#  except FileNotFoundError:
#      print(f"Error: File not found at {file_path}")
#  except Exception as e:
#      print(f"An error occurred: {e}")
#
#
# Key Changes:
#
#  1 Added file reading functionality
#  2 Added error handling
#  3 Added optional summary saving
#  4 Added more detailed printing of results
#
# Modifications to agent_script.py: To make the output more informative, you might want to update the tools to
# provide more meaningful placeholder data. For example, in the SummarizationTool:
#
#
#  class SummarizationTool(Tool):
#      def execute(self, context: DocumentProcessingContext) -> Dict[str, Any]:
#          # More meaningful placeholder summary generation
#          summary = f"Summary of document (length: {len(context.input_document)} characters):\n\n"
#          summary += "Key Points:\n"
#          summary += "1. Document provides insights into tool design best practices\n"
#          summary += "2. Focuses on creating modular and flexible agent systems\n"
#          summary += "3. Emphasizes the importance of separation of concerns"
#
#          context.summary_drafts.append(summary)
#
#          return {
#              "status": "success",
#              "summary_draft": summary,
#              "summary_metadata": {
#                  "length": len(summary),
#                  "complexity_level": context.processing_config.get("complexity_level")
#              }
#          }
#
#
# Additional Recommendations:
#
#  1 Error Handling: The current tools have placeholder implementations. In a real-world scenario, you'd replace
#    these with actual NLP processing.
#  2 Logging: Consider adding logging to track the processing steps.
#  3 Configuration: You can pass custom configurations to the agent.
#
# Example with Logging and Custom Configuration:
#
#
#  import logging
#
#  # Configure logging
#  logging.basicConfig(
#      level=logging.INFO,
#      format='%(asctime)s - %(levelname)s - %(message)s'
#  )
#
#  # Custom configuration
#  custom_config = {
#      "max_summary_length": 750,
#      "complexity_level": "advanced"
#  }
#
#  # Create agent with custom config
#  agent = setup_document_processing_agent(custom_config)
#
#  # Rest of the code remains the same
#
#
# Would you like me to elaborate on any of these points or help you implement more sophisticated document processing?

# %%
prompt='''
does logging go in the script or the code to run the script?
'''
chat_with_claude(prompt)
# Out:
# Great question! Logging can (and often should) be implemented in both places, but with different purposes:
#
#  1 In the Script (agent_script.py):
#
#
#  import logging
#
#  # Configure logging at the module level
#  logging.basicConfig(
#      level=logging.INFO,
#      format='%(asctime)s - %(name)s - %(levelname)s - %(message)s',
#      handlers=[
#          logging.FileHandler("/content/agent_processing.log"),  # Log to file
#          logging.StreamHandler()  # Also print to console
#      ]
#  )
#
#  # Create a logger for the module
#  logger = logging.getLogger(__name__)
#
#  # Example in a tool
#  class TextPreprocessingTool(Tool):
#      def execute(self, context: DocumentProcessingContext) -> Dict[str, Any]:
#          logger.info(f"Starting text preprocessing for document of length {len(context.input_document)}")
#          try:
#              # Preprocessing logic
#              processed_text = context.input_document.lower().strip()
#              logger.info("Text preprocessing completed successfully")
#              return {
#                  "status": "success",
#                  "processed_text": processed_text,
#                  "preprocessing_steps": ["lowercase", "strip"]
#              }
#          except Exception as e:
#              logger.error(f"Error in text preprocessing: {e}")
#              return {
#                  "status": "error",
#                  "error_message": str(e)
#              }
#
#
#  2 In the Running Script:
#
#
#  import logging
#  import sys
#  import os
#
#  # Configure additional logging for the running script
#  logging.basicConfig(
#      level=logging.DEBUG,  # More detailed logging
#      format='%(asctime)s - %(name)s - %(levelname)s - %(message)s',
#      handlers=[
#          logging.FileHandler("/content/script_execution.log"),
#          logging.StreamHandler()
#      ]
#  )
#
#  # Create a logger for the script
#  script_logger = logging.getLogger('document_processing_script')
#
#  try:
#      # Import and setup
#      sys.path.append('/content')
#      from agent_script import setup_document_processing_agent
#
#      script_logger.info("Starting document processing")
#
#      # Create agent
#      agent = setup_document_processing_agent()
#      script_logger.info("Agent initialized successfully")
#
#      # Read and process document
#      file_path = "/files/_Agent_04_Tool_Design_Best_Practices.txt"
#
#      script_logger.info(f"Attempting to read document from {file_path}")
#      with open(file_path, 'r', encoding='utf-8') as file:
#          sample_document = file.read()
#
#      script_logger.info(f"Document read successfully. Length: {len(sample_document)} characters")
#
#      # Process the document
#      result = agent.process_document(sample_document)
#
#      script_logger.info("Document processing completed")
#
#      # Save summary
#      output_path = "/content/summary.txt"
#      with open(output_path, 'w', encoding='utf-8') as output_file:
#          output_file.write(result.summary_drafts[0] if result.summary_drafts else "No summary generated")
#
#      script_logger.info(f"Summary saved to {output_path}")
#
#  except Exception as e:
#      script_logger.error(f"An error occurred during document processing: {e}", exc_info=True)
#
#
# Logging Best Practices:
#
#  1 Module-level logging in the script itself
#  2 Script-level logging in the running script
#  3 Use different log files for different purposes
#  4 Include error tracing with exc_info=True
#  5 Use appropriate log levels:
#     • DEBUG: Detailed information
#     • INFO: Confirmation that things are working as expected
#     • WARNING: Indication of potential problem
#     • ERROR: More serious problem
#     • CRITICAL: A serious error, the program itself may be unable to continue running
#
# Recommended Logging Levels:
#
#  • Development: Use DEBUG or INFO
#  • Production: Use WARNING or ERROR
#
# Benefits of this Approach:
#
#  • Comprehensive tracking of script execution
#  • Easy debugging
#  • Performance monitoring
#  • Error tracing
#
# Would you like me to elaborate on any aspect of logging or help you implement it in your specific use case?

# %% [markdown]
# ## Run Script II

# %%
# Import the entire script
import sys
import os
import logging

sys.path.append('/content')  # Adjust path as needed

from agent_script import setup_document_processing_agent

# Create agent
agent = setup_document_processing_agent()

# Configure additional logging for the running script
logging.basicConfig(
    level=logging.DEBUG,  # More detailed logging
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler("/content/script_execution.log"),
        logging.StreamHandler()
    ]
)

# Create a logger for the script
script_logger = logging.getLogger('document_processing_script')

try:
    # Import and setup
    sys.path.append('/content')
    from agent_script import setup_document_processing_agent

    script_logger.info("Starting document processing")

    # Create agent
    agent = setup_document_processing_agent()
    script_logger.info("Agent initialized successfully")

    # Read and process document
    file_path = "files/_Agent_04_Tool_Design_Best_Practices.txt"

    script_logger.info(f"Attempting to read document from {file_path}")
    with open(file_path, 'r', encoding='utf-8') as file:
        sample_document = file.read()

    script_logger.info(f"Document read successfully. Length: {len(sample_document)} characters")

    # Process the document
    result = agent.process_document(sample_document)

    script_logger.info("Document processing completed")

    # Save summary
    output_path = "/content/summary.txt"
    with open(output_path, 'w', encoding='utf-8') as output_file:
        output_file.write(result.summary_drafts[0] if result.summary_drafts else "No summary generated")

    script_logger.info(f"Summary saved to {output_path}")

except Exception as e:
    script_logger.error(f"An error occurred during document processing: {e}", exc_info=True)

# %%
prompt = '''
I updated the script and then ran this code but nothing is returned?

# Import the entire script
import sys
import os
import logging

sys.path.append('/content')  # Adjust path as needed

from agent_script import setup_document_processing_agent

# Create agent
agent = setup_document_processing_agent()

# Configure additional logging for the running script
logging.basicConfig(
    level=logging.DEBUG,  # More detailed logging
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler("/content/script_execution.log"),
        logging.StreamHandler()
    ]
)

# Create a logger for the script
script_logger = logging.getLogger('document_processing_script')

try:
    # Import and setup
    sys.path.append('/content')
    from agent_script import setup_document_processing_agent

    script_logger.info("Starting document processing")

    # Create agent
    agent = setup_document_processing_agent()
    script_logger.info("Agent initialized successfully")

    # Read and process document
    file_path = "files/_Agent_04_Tool_Design_Best_Practices.txt"

    script_logger.info(f"Attempting to read document from {file_path}")
    with open(file_path, 'r', encoding='utf-8') as file:
        sample_document = file.read()

    script_logger.info(f"Document read successfully. Length: {len(sample_document)} characters")

    # Process the document
    result = agent.process_document(sample_document)

    script_logger.info("Document processing completed")

    # Save summary
    output_path = "/content/summary.txt"
    with open(output_path, 'w', encoding='utf-8') as output_file:
        output_file.write(result.summary_drafts[0] if result.summary_drafts else "No summary generated")

    script_logger.info(f"Summary saved to {output_path}")

except Exception as e:
    script_logger.error(f"An error occurred during document processing: {e}", exc_info=True)

'''
chat_with_claude(prompt)
# Out:
# There are a few potential issues that could prevent output. Let's troubleshoot step by step:
#
#  1 File Path Verification
#
#
#  import os
#
#  # Verify the exact file path
#  print("Current Working Directory:", os.getcwd())
#  print("Absolute path to file:", os.path.abspath("files/_Agent_04_Tool_Design_Best_Practices.txt"))
#
#  # Check if file exists
#  file_path = "files/_Agent_04_Tool_Design_Best_Practices.txt"
#  if os.path.exists(file_path):
#      print("File exists!")
#  else:
#      print("File does not exist!")
#      # List files in the directory to verify
#      print("Files in current directory:", os.listdir())
#
#
#  2 Enhanced Debugging Script
#
#
#  import sys
#  import os
#  import logging
#
#  # Configure logging
#  logging.basicConfig(
#      level=logging.DEBUG,
#      format='%(asctime)s - %(name)s - %(levelname)s - %(message)s',
#      handlers=[
#          logging.FileHandler("/content/script_execution.log"),
#          logging.StreamHandler()
#      ]
#  )
#
#  # Create a logger for the script
#  script_logger = logging.getLogger('document_processing_script')
#
#  try:
#      # Absolute path verification
#      base_path = "/content"  # Adjust if needed
#      file_path = os.path.join(base_path, "files", "_Agent_04_Tool_Design_Best_Practices.txt")
#
#      script_logger.info(f"Attempting to read document from {file_path}")
#
#      # Detailed file checking
#      if not os.path.exists(file_path):
#          script_logger.error(f"File not found: {file_path}")
#          print(f"File not found: {file_path}")
#          print("Checking directory contents:")
#          print("Base path contents:", os.listdir(base_path))
#          print("Files subdirectory contents:", os.listdir(os.path.join(base_path, "files")))
#          raise FileNotFoundError(f"Cannot find file at {file_path}")
#
#      # Read the file
#      with open(file_path, 'r', encoding='utf-8') as file:
#          sample_document = file.read()
#
#      script_logger.info(f"Document read successfully. Length: {len(sample_document)} characters")
#
#      # Import the agent setup
#      sys.path.append(base_path)
#      from agent_script import setup_document_processing_agent
#
#      # Create agent
#      agent = setup_document_processing_agent()
#      script_logger.info("Agent initialized successfully")
#
#      # Process the document
#      result = agent.process_document(sample_document)
#
#      script_logger.info("Document processing completed")
#
#      # Print results to console for verification
#      print("Summary Drafts:", result.summary_drafts)
#      print("Document Metadata:", result.document_metadata)
#      print("Extracted Concepts:", result.extracted_concepts)
#
#      # Save summary
#      output_path = "/content/summary.txt"
#      with open(output_path, 'w', encoding='utf-8') as output_file:
#          output_file.write(result.summary_drafts[0] if result.summary_drafts else "No summary generated")
#
#      script_logger.info(f"Summary saved to {output_path}")
#
#  except Exception as e:
#      script_logger.error(f"An error occurred during document processing: {e}", exc_info=True)
#      print(f"Error: {e}")
#      import traceback
#      traceback.print_exc()
#
#
#  3 Modifications to agent_script.py Ensure that the process_document method is actually populating summary_drafts:
#
#
#  def process_document(self, document: str, config: Dict[str, Any] = None) -> DocumentProcessingContext:
#      # Create processing context
#      context = DocumentProcessingContext(input_document=document)
#
#      # Apply pre-processing capabilities
#      for capability in self.capabilities:
#          capability.pre_process(context)
#
#      # Define processing pipeline
#      pipeline_order = [
#          "text_preprocessor",
#          "concept_extractor",
#          "summarization_tool",
#          "summary_validator",
#          "output_generator"
#      ]
#
#      # Execute tools in sequence
#      for tool_name in pipeline_order:
#          tool = self.tool_registry.get_tool(tool_name)
#          result = tool.execute(context)
#
#          # Explicitly print or log tool results for debugging
#          print(f"Tool {tool_name} result: {result}")
#
#      # Apply post-processing capabilities
#      for capability in self.capabilities:
#          capability.post_process(context)
#
#      # Ensure summary_drafts is not empty
#      if not context.summary_drafts:
#          context.summary_drafts.append("No summary generated")
#
#      return context
#
#
# Potential Issues to Check:
#
#  1 Correct file path
#  2 Permissions to read the file
#  3 Encoding issues
#  4 Tool implementation details
#
# Recommendations:
#
#  1 Run the enhanced debugging script
#  2 Check the log file at /content/script_execution.log
#  3 Verify the file path and contents
#  4 Print intermediate results in the agent script
#
# Would you like me to help you diagnose the specific issue based on the output or logs?

# %% [markdown]
# ## Script III

# %%
agent_script = r'''
from typing import List, Dict, Any, Optional
from enum import Enum
from dataclasses import dataclass, field
import time
import logging
import re

# 1. Define Purpose
GOAL = """
Extract and synthesize key concepts from text documents,
creating high-quality, educational summaries that enhance reader understanding.

Constraints:
- Maintain academic integrity
- Preserve original context
- Generate concise, clear summaries
"""

# 2. Tool Categories
class ToolCategory(Enum):
    PREPROCESSING = "preprocessing"
    ANALYSIS = "analysis"
    SYNTHESIS = "synthesis"
    VALIDATION = "validation"
    OUTPUT = "output"

# 3. Tool Dependencies and Context
@dataclass
class DocumentProcessingContext:
    # Shared context for document processing
    input_document: str = ""
    document_metadata: Dict[str, Any] = field(default_factory=dict)
    processing_config: Dict[str, Any] = field(default_factory=lambda: {
        "max_summary_length": 500,
        "complexity_level": "intermediate",
        "language": "english"
    })
    extracted_concepts: List[Dict[str, Any]] = field(default_factory=list)
    summary_drafts: List[str] = field(default_factory=list)
    validation_results: List[Dict[str, Any]] = field(default_factory=list)

# 4. Tool Definitions
@dataclass
class Tool:
    name: str
    category: ToolCategory
    description: str
    required_dependencies: List[str]

    def execute(self, context: DocumentProcessingContext) -> Dict[str, Any]:
        raise NotImplementedError("Subclasses must implement execution")

# Specific Tool Implementations (Scaffold)
class TextPreprocessingTool(Tool):
    def __init__(self):
        super().__init__(
            name="text_preprocessor",
            category=ToolCategory.PREPROCESSING,
            description="Clean and normalize input text",
            required_dependencies=["text_cleaning_library"]
        )

    def execute(self, context: DocumentProcessingContext) -> Dict[str, Any]:
        # Placeholder for text preprocessing logic
        return {
            "status": "success",
            "processed_text": context.input_document.lower().strip(),
            "preprocessing_steps": [
                "lowercase conversion",
                "whitespace removal",
                "special character handling"
            ]
        }

# class ConceptExtractionTool(Tool):
#     def __init__(self):
#         super().__init__(
#             name="concept_extractor",
#             category=ToolCategory.ANALYSIS,
#             description="Extract key concepts and their relationships",
#             required_dependencies=["nlp_library", "concept_mapping_tool"]
#         )

#     def execute(self, context: DocumentProcessingContext) -> Dict[str, Any]:
#         # Placeholder for concept extraction logic
#         return {
#             "status": "success",
#             "extracted_concepts": [
#                 {
#                     "term": "key concept",
#                     "definition": "brief explanation",
#                     "importance_score": 0.8
#                 }
#             ],
#             "concept_relationships": []
#         }

class ConceptExtractionTool(Tool):
    def execute(self, context: DocumentProcessingContext) -> Dict[str, Any]:
        try:
            # More sophisticated concept extraction
            if not context.input_document:
                logger.warning("Input document is empty")
                return {
                    "status": "error",
                    "error_message": "Input document is empty"
                }

            # Basic keyword extraction (very simple implementation)
            words = context.input_document.lower().split()
            word_freq = {}

            for word in words:
                if len(word) > 3:  # Filter out very short words
                    word_freq[word] = word_freq.get(word, 0) + 1

            # Sort words by frequency
            top_concepts = sorted(word_freq.items(), key=lambda x: x[1], reverse=True)[:5]

            # Convert to concept format
            concepts = [
                {
                    "term": concept,
                    "frequency": freq,
                    "importance_score": freq / len(words)
                }
                for concept, freq in top_concepts
            ]

            # Store concepts in context
            context.extracted_concepts = concepts

            return {
                "status": "success",
                "extracted_concepts": concepts,
                "concept_count": len(concepts)
            }
        except Exception as e:
            logger.error(f"Concept extraction error: {e}")
            return {
                "status": "error",
                "error_message": str(e)
            }


# class SummarizationTool(Tool):
#     def __init__(self):
#         super().__init__(
#             name="summarization_tool",
#             category=ToolCategory.SYNTHESIS,
#             description="Generate educational summary from extracted concepts",
#             required_dependencies=["language_model", "summary_generation_library"]
#         )
#     def execute(self, context: DocumentProcessingContext) -> Dict[str, Any]:
#         # More meaningful placeholder summary generation
#         summary = f"Summary of document (length: {len(context.input_document)} characters):\n\n"
#         summary += "Key Points:\n"
#         summary += "1. Document provides insights into tool design best practices\n"
#         summary += "2. Focuses on creating modular and flexible agent systems\n"
#         summary += "3. Emphasizes the importance of separation of concerns"

#         context.summary_drafts.append(summary)

#         return {
#             "status": "success",
#             "summary_draft": summary,
#             "summary_metadata": {
#                 "length": len(summary),
#                 "complexity_level": context.processing_config.get("complexity_level")
#             }
#         }


class SummarizationTool(Tool):
    def execute(self, context: DocumentProcessingContext) -> Dict[str, Any]:
        try:
            # Log input document details
            logger.info(f"Summarization input document length: {len(context.input_document)}")

            # More robust summary generation
            if not context.input_document:
                logger.warning("Input document is empty")
                return {
                    "status": "error",
                    "error_message": "Input document is empty"
                }

            # Improved sentence splitting
            sentences = re.split(r'(?<=[.!?])\s+', context.input_document)

            # Generate a summary
            summary = f"Summary of document (length: {len(context.input_document)} characters):\n\n"
            summary += "Key Points:\n"

            # Take first 3 non-empty sentences
            key_points = [s.strip() for s in sentences if s.strip()][:3]

            for i, sentence in enumerate(key_points, 1):
                summary += f"{i}. {sentence}\n"

            # Append summary to context
            context.summary_drafts.append(summary)

            logger.info(f"Generated summary: {summary}")

            return {
                "status": "success",
                "summary_draft": summary,
                "summary_metadata": {
                    "length": len(summary),
                    "complexity_level": context.processing_config.get("complexity_level"),
                    "sentences_used": len(key_points)
                }
            }
        except Exception as e:
            logger.error(f"Error in summarization: {e}")
            return {
                "status": "error",
                "error_message": str(e)
            }


class ValidationTool(Tool):
    def __init__(self):
        super().__init__(
            name="summary_validator",
            category=ToolCategory.VALIDATION,
            description="Validate generated summary for quality and accuracy",
            required_dependencies=["validation_library", "fact_checking_service"]
        )

    def execute(self, context: DocumentProcessingContext) -> Dict[str, Any]:
        # Placeholder for summary validation logic
        return {
            "status": "success",
            "validation_results": [
                {
                    "aspect": "factual_accuracy",
                    "score": 0.9,
                    "recommendations": []
                },
                {
                    "aspect": "readability",
                    "score": 0.85,
                    "recommendations": []
                }
            ]
        }

class OutputGenerationTool(Tool):
    def __init__(self):
        super().__init__(
            name="output_generator",
            category=ToolCategory.OUTPUT,
            description="Generate final formatted output",
            required_dependencies=["formatting_library"]
        )

    def execute(self, context: DocumentProcessingContext) -> Dict[str, Any]:
        # Placeholder for final output generation
        return {
            "status": "success",
            "output_formats": ["markdown", "html", "plain_text"],
            "final_output": "# Summary\n\nDetailed educational summary..."
        }

# 5. Tool Registry
class ToolRegistry:
    def __init__(self):
        self.tools: Dict[str, Tool] = {}

    def register_tool(self, tool: Tool):
        self.tools[tool.name] = tool

    def get_tool(self, name: str) -> Tool:
        return self.tools.get(name)

    def get_tools_by_category(self, category: ToolCategory) -> List[Tool]:
        return [tool for tool in self.tools.values() if tool.category == category]

# 6. Agent Capabilities
class Capability:
    def pre_process(self, context: DocumentProcessingContext):
        pass

    def post_process(self, context: DocumentProcessingContext):
        pass

class QualityAssuranceCapability(Capability):
    def post_process(self, context: DocumentProcessingContext):
        # Additional quality checks
        pass

class ProgressTrackingCapability(Capability):
    def pre_process(self, context: DocumentProcessingContext):
        context.document_metadata['start_time'] = time.time()

    def post_process(self, context: DocumentProcessingContext):
        context.document_metadata['end_time'] = time.time()
        context.document_metadata['total_processing_time'] = (
            context.document_metadata['end_time'] -
            context.document_metadata['start_time']
        )

# 7. Agent Framework
class DocumentProcessingAgent:
    def __init__(
        self,
        tool_registry: ToolRegistry,
        capabilities: Optional[List[Capability]] = None
    ):
        self.tool_registry = tool_registry
        self.capabilities = capabilities or []

    def process_document(self, document: str, config: Dict[str, Any] = None) -> DocumentProcessingContext:
        # Create processing context
        context = DocumentProcessingContext(input_document=document)

        # Use provided config or default
        if config:
            context.processing_config.update(config)

        # Apply pre-processing capabilities
        for capability in self.capabilities:
            try:
                capability.pre_process(context)
            except Exception as e:
                logger.error(f"Error in pre-processing capability: {e}")

        # Define processing pipeline
        pipeline_order = [
            "text_preprocessor",
            "concept_extractor",
            "summarization_tool",
            "summary_validator",
            "output_generator"
        ]

        # Execute tools in sequence
        for tool_name in pipeline_order:
            tool = self.tool_registry.get_tool(tool_name)
            if tool is None:
                logger.error(f"Tool {tool_name} not found in registry")
                continue

            try:
                result = tool.execute(context)

                # Log tool results
                logger.info(f"Tool {tool_name} result: {result}")
                print(f"Tool {tool_name} result: {result}")  # Also print for console visibility
            except Exception as e:
                logger.error(f"Error executing tool {tool_name}: {e}")

        # Apply post-processing capabilities
        for capability in self.capabilities:
            try:
                capability.post_process(context)
            except Exception as e:
                logger.error(f"Error in post-processing capability: {e}")

        # Ensure summary_drafts is not empty
        if not context.summary_drafts:
            context.summary_drafts.append("No summary generated")

        return context

# 8. Initialization and Wiring
def setup_document_processing_agent() -> DocumentProcessingAgent:
    # Create tool registry
    registry = ToolRegistry()

    # Register tools
    registry.register_tool(TextPreprocessingTool())
    registry.register_tool(ConceptExtractionTool())
    registry.register_tool(SummarizationTool())
    registry.register_tool(ValidationTool())
    registry.register_tool(OutputGenerationTool())

    # Create capabilities
    capabilities = [
        QualityAssuranceCapability(),
        ProgressTrackingCapability()
    ]

    # Create and return agent
    return DocumentProcessingAgent(registry, capabilities)


# Logging Configuration
import logging
import sys

def setup_logging():
    # Create logger
    logger = logging.getLogger()
    logger.setLevel(logging.INFO)

    # Create handlers
    c_handler = logging.StreamHandler(sys.stdout)  # Console handler
    f_handler = logging.FileHandler("/content/agent_processing.log")

    # Create formatters and add it to handlers
    log_format = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
    c_handler.setFormatter(log_format)
    f_handler.setFormatter(log_format)

    # Add handlers to the logger
    logger.addHandler(c_handler)
    logger.addHandler(f_handler)

    return logger

# Call this at the start of your script
logger = setup_logging()

# Main function
def main():
    # Create the agent
    agent = setup_document_processing_agent()

    # Sample documents for testing
    sample_documents = [
        """Machine learning is a subset of artificial intelligence that focuses on the use of data
        and algorithms to imitate the way that humans learn, gradually improving its accuracy.
        Unlike traditional programming, machine learning allows computers to learn from and make
        predictions or decisions based on data.""",

        """Natural language processing (NLP) is a branch of artificial intelligence that helps
        computers understand, interpret, and manipulate human language. It bridges the communication
        gap between computers and humans by enabling machines to process and analyze large amounts
        of natural language data."""
    ]

    # Process multiple documents
    results = []
    for i, document in enumerate(sample_documents, 1):
        print(f"\n--- Processing Document {i} ---")
        result = agent.process_document(document)
        results.append(result)

        # Print out results
        print(f"Summary Drafts (Document {i}):", result.summary_drafts)
        print(f"Document Metadata (Document {i}):")
        for key, value in result.document_metadata.items():
            print(f"{key}: {value}")

        print(f"Extracted Concepts (Document {i}):")
        print(result.extracted_concepts)

    return results

# Optional: Add error handling wrapper
def run_main():
    try:
        results = main()
        return results
    except Exception as e:
        logger.error(f"Error in main execution: {e}")
        print(f"An error occurred: {e}")
        return None

# Ensure the main block runs
if __name__ == "__main__":
    run_main()

'''

with open("agent_script.py", "w") as file:
    file.write(agent_script)

print("Script successfully written to agent_script.py")
# Out:
# Script successfully written to agent_script.py

# %%
# Read a file from Colab
with open('/content/agent_script.py', 'r') as f:
    doc_content = f.read()

prompt='''
I made the modifications. Can you review the agent_script now please?
'''
# chat_with_claude(prompt)
chat_with_claude(f"{prompt} {doc_content}")
# Out:
# The script looks good overall. However, I noticed a few potential improvements and suggestions:
#
#  1 Enhance Sentence Splitting in SummarizationTool:
#
#
#  import re
#
#  class SummarizationTool(Tool):
#      def execute(self, context: DocumentProcessingContext) -> Dict[str, Any]:
#          try:
#              # Log input document details
#              logger.info(f"Summarization input document length: {len(context.input_document)}")
#
#              # More robust summary generation
#              if not context.input_document:
#                  logger.warning("Input document is empty")
#                  return {
#                      "status": "error",
#                      "error_message": "Input document is empty"
#                  }
#
#              # Improved sentence splitting
#              sentences = re.split(r'(?<=[.!?])\s+', context.input_document)
#
#              # Generate a summary
#              summary = f"Summary of document (length: {len(context.input_document)} characters):\n\n"
#              summary += "Key Points:\n"
#
#              # Take first 3 non-empty sentences
#              key_points = [s.strip() for s in sentences if s.strip()][:3]
#
#              for i, sentence in enumerate(key_points, 1):
#                  summary += f"{i}. {sentence}\n"
#
#              # Append summary to context
#              context.summary_drafts.append(summary)
#
#              logger.info(f"Generated summary: {summary}")
#
#              return {
#                  "status": "success",
#                  "summary_draft": summary,
#                  "summary_metadata": {
#                      "length": len(summary),
#                      "complexity_level": context.processing_config.get("complexity_level"),
#                      "sentences_used": len(key_points)
#                  }
#              }
#          except Exception as e:
#              logger.error(f"Error in summarization: {e}")
#              return {
#                  "status": "error",
#                  "error_message": str(e)
#              }
#
#
#  2 Enhance Concept Extraction Tool:
#
#
#  class ConceptExtractionTool(Tool):
#      def execute(self, context: DocumentProcessingContext) -> Dict[str, Any]:
#          try:
#              # More sophisticated concept extraction
#              if not context.input_document:
#                  logger.warning("Input document is empty")
#                  return {
#                      "status": "error",
#                      "error_message": "Input document is empty"
#                  }
#
#              # Basic keyword extraction (very simple implementation)
#              words = context.input_document.lower().split()
#              word_freq = {}
#
#              for word in words:
#                  if len(word) > 3:  # Filter out very short words
#                      word_freq[word] = word_freq.get(word, 0) + 1
#
#              # Sort words by frequency
#              top_concepts = sorted(word_freq.items(), key=lambda x: x[1], reverse=True)[:5]
#
#              # Convert to concept format
#              concepts = [
#                  {
#                      "term": concept,
#                      "frequency": freq,
#                      "importance_score": freq / len(words)
#                  }
#                  for concept, freq in top_concepts
#              ]
#
#              # Store concepts in context
#              context.extracted_concepts = concepts
#
#              return {
#                  "status": "success",
#                  "extracted_concepts": concepts,
#                  "concept_count": len(concepts)
#              }
#          except Exception as e:
#              logger.error(f"Concept extraction error: {e}")
#              return {
#                  "status": "error",
#                  "error_message": str(e)
#              }
#
#
#  3 Add More Robust Logging Configuration:
#
#
#  # Logging Configuration
#  import logging
#  import sys
#
#  def setup_logging():
#      # Create logger
#      logger = logging.getLogger()
#      logger.setLevel(logging.INFO)
#
#      # Create handlers
#      c_handler = logging.StreamHandler(sys.stdout)  # Console handler
#      f_handler = logging.FileHandler("/content/agent_processing.log")
#
#      # Create formatters and add it to handlers
#      log_format = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
#      c_handler.setFormatter(log_format)
#      f_handler.setFormatter(log_format)
#
#      # Add handlers to the logger
#      logger.addHandler(c_handler)
#      logger.addHandler(f_handler)
#
#      return logger
#
#  # Call this at the start of your script
#  logger = setup_logging()
#
#
#  4 Enhance Main Function for More Comprehensive Testing:
#
#
#  def main():
#      # Create the agent
#      agent = setup_document_processing_agent()
#
#      # Sample documents for testing
#      sample_documents = [
#          """Machine learning is a subset of artificial intelligence that focuses on the use of data
#          and algorithms to imitate the way that humans learn, gradually improving its accuracy.
#          Unlike traditional programming, machine learning allows computers to learn from and make
#          predictions or decisions based on data.""",
#
#          """Natural language processing (NLP) is a branch of artificial intelligence that helps
#          computers understand, interpret, and manipulate human language. It bridges the communication
#          gap between computers and humans by enabling machines to process and analyze large amounts
#          of natural language data."""
#      ]
#
#      # Process multiple documents
#      results = []
#      for i, document in enumerate(sample_documents, 1):
#          print(f"\n--- Processing Document {i} ---")
#          result = agent.process_document(document)
#          results.append(result)
#
#          # Print out results
#          print(f"Summary Drafts (Document {i}):", result.summary_drafts)
#          print(f"Document Metadata (Document {i}):")
#          for key, value in result.document_metadata.items():
#              print(f"{key}: {value}")
#
#          print(f"Extracted Concepts (Document {i}):")
#          print(result.extracted_concepts)
#
#      return results
#
#  # Optional: Add error handling wrapper
#  def run_main():
#      try:
#          results = main()
#          return results
#      except Exception as e:
#          logger.error(f"Error in main execution: {e}")
#          print(f"An error occurred: {e}")
#          return None
#
#  # Ensure the main block runs
#  if __name__ == "__main__":
#      run_main()
#
#
# Recommendations:
#
#  1 More robust sentence and concept extraction
#  2 Enhanced error handling
#  3 Improved logging
#  4 Flexible configuration
#
# Would you like me to elaborate on any of these suggestions or help you implement them?

# %% [markdown]
# ### Run Script III

# %%
prompt = '''
I ran this code but gothe return was minimal:

 import os
 import logging

 # Configure logging to see more details
 logging.basicConfig(level=logging.DEBUG)

 # Import the agent
 from agent_script import setup_document_processing_agent

 # Create the agent
 agent = setup_document_processing_agent()

 # Process a file
 file_path = "/content/files/_Agent_04_Tool_Design_Best_Practices.txt"

 # Read the file
 with open(file_path, 'r', encoding='utf-8') as file:
     document_text = file.read()

 # Print document length for verification
 print("Document Length:", len(document_text))
 print("First 200 characters:", document_text[:200])

 # Process the document
 result = agent.process_document(document_text)

 # Detailed debugging
 print("\n--- Debugging Information ---")
 print("Summary Drafts:", result.summary_drafts)
 print("Extracted Concepts:", result.extracted_concepts)
 print("Processing Time:", result.document_metadata.get('total_processing_time'))

 # Check each tool's execution
 print("\n--- Tool Execution Logs ---")
 # You might want to add more logging in your agent_script.py to capture tool execution details

 return =------------

 Document Length: 1127
First 200 characters:
## **Chapter 4: Tool Design Best Practices**

### Concept Summary

Tools are the **hands of your agent** — the way it interacts with the world. Good design makes the difference between fragile hacks

--- Debugging Information ---
Summary Drafts: []
Extracted Concepts: []
Processing Time: 5.8650970458984375e-05

--- Tool Execution Logs ---
'''
chat_with_claude(prompt)
# Out:
# Let's add more detailed debugging to understand why the summary is not being generated. Modify the
# SummarizationTool in your agent_script.py:
#
#
#  class SummarizationTool(Tool):
#      def __init__(self):
#          super().__init__(
#              name="summarization_tool",
#              category=ToolCategory.SYNTHESIS,
#              description="Generate educational summary from extracted concepts",
#              required_dependencies=["language_model", "summary_generation_library"]
#          )
#
#      def execute(self, context: DocumentProcessingContext) -> Dict[str, Any]:
#          try:
#              # Extensive logging
#              print("DEBUG: Entering SummarizationTool.execute()")
#              print(f"DEBUG: Input document length: {len(context.input_document)}")
#              print(f"DEBUG: First 500 characters: {context.input_document[:500]}")
#
#              # Log to file as well
#              logger.info("Entering SummarizationTool.execute()")
#              logger.info(f"Input document length: {len(context.input_document)}")
#
#              # More robust summary generation
#              if not context.input_document:
#                  print("DEBUG: Input document is empty")
#                  logger.warning("Input document is empty")
#                  return {
#                      "status": "error",
#                      "error_message": "Input document is empty"
#                  }
#
#              # Generate a summary
#              summary = "Summary of Document:\n\n"
#              summary += "Key Points:\n"
#
#              # Split document into lines and take first few meaningful lines
#              lines = [line.strip() for line in context.input_document.split('\n') if line.strip()]
#
#              # Take first 3-5 non-empty lines
#              key_points = lines[:5]
#
#              for i, line in enumerate(key_points, 1):
#                  summary += f"{i}. {line}\n"
#
#              print(f"DEBUG: Generated summary: {summary}")
#              logger.info(f"Generated summary: {summary}")
#
#              # Append summary to context
#              context.summary_drafts.append(summary)
#
#              return {
#                  "status": "success",
#                  "summary_draft": summary,
#                  "summary_metadata": {
#                      "length": len(summary),
#                      "lines_used": len(key_points)
#                  }
#              }
#          except Exception as e:
#              print(f"DEBUG: Error in summarization: {e}")
#              logger.error(f"Error in summarization: {e}", exc_info=True)
#              return {
#                  "status": "error",
#                  "error_message": str(e)
#              }
#
#
# Additionally, modify the process_document method in the DocumentProcessingAgent class to add more verbose logging:
#
#
#  def process_document(self, document: str, config: Dict[str, Any] = None) -> DocumentProcessingContext:
#      # Create processing context
#      context = DocumentProcessingContext(input_document=document)
#
#      # Extensive logging
#      print("DEBUG: Starting document processing")
#      print(f"DEBUG: Document length: {len(document)}")
#      logger.info(f"Starting document processing. Document length: {len(document)}")
#
#      # Use provided config or default
#      if config:
#          context.processing_config.update(config)
#
#      # Apply pre-processing capabilities
#      for capability in self.capabilities:
#          try:
#              capability.pre_process(context)
#              print(f"DEBUG: Pre-processing capability {capability.__class__.__name__} completed")
#          except Exception as e:
#              print(f"DEBUG: Error in pre-processing capability: {e}")
#              logger.error(f"Error in pre-processing capability: {e}")
#
#      # Define processing pipeline
#      pipeline_order = [
#          "text_preprocessor",
#          "concept_extractor",
#          "summarization_tool",
#          "summary_validator",
#          "output_generator"
#      ]
#
#      # Execute tools in sequence
#      for tool_name in pipeline_order:
#          print(f"DEBUG: Attempting to execute tool: {tool_name}")
#          tool = self.tool_registry.get_tool(tool_name)
#          if tool is None:
#              print(f"DEBUG: Tool {tool_name} not found in registry")
#              logger.error(f"Tool {tool_name} not found in registry")
#              continue
#
#          try:
#              result = tool.execute(context)
#
#              # More detailed logging
#              print(f"DEBUG: Tool {tool_name} execution result: {result}")
#              logger.info(f"Tool {tool_name} result: {result}")
#          except Exception as e:
#              print(f"DEBUG: Error executing tool {tool_name}: {e}")
#              logger.error(f"Error executing tool {tool_name}: {e}", exc_info=True)
#
#      # Apply post-processing capabilities
#      for capability in self.capabilities:
#          try:
#              capability.post_process(context)
#              print(f"DEBUG: Post-processing capability {capability.__class__.__name__} completed")
#          except Exception as e:
#              print(f"DEBUG: Error in post-processing capability: {e}")
#              logger.error(f"Error in post-processing capability: {e}")
#
#      # Ensure summary_drafts is not empty
#      if not context.summary_drafts:
#          print("DEBUG: No summary generated. Adding default message.")
#          context.summary_drafts.append("No summary generated")
#
#      return context
#
#
# Now, create a debugging script in your notebook:
#
#
#  import os
#  import logging
#  import traceback
#
#  # Configure logging
#  logging.basicConfig(
#      level=logging.DEBUG,
#      format='%(asctime)s - %(name)s - %(levelname)s - %(message)s',
#      handlers=[
#          logging.FileHandler("/content/detailed_debug.log"),
#          logging.StreamHandler()
#      ]
#  )
#
#  # Import the agent
#  from agent_script import setup_document_processing_agent
#
#  def debug_document_processing():
#      try:
#          # Create the agent
#          agent = setup_document_processing_agent()
#
#          # Process a file
#          file_path = "/content/files/_Agent_04_Tool_Design_Best_Practices.txt"
#
#          # Read the file
#          with open(file_path, 'r', encoding='utf-8') as file:
#              document_text = file.read()
#
#          # Print document details
#          print("Document Length:", len(document_text))
#          print("First 500 characters:", document_text[:500])
#
#          # Process the document
#          result = agent.process_document(document_text)
#
#          # Display results
#          print("\n--- Processing Results ---")
#          print("Summary Drafts:", result.summary_drafts)
#          print("Extracted Concepts:", result.extracted_concepts)
#          print("Processing Time:", result.document_metadata.get('total_processing_time'))
#
#          return result
#
#      except Exception as e:
#          print(f"An error occurred: {e}")
#          traceback.print_exc()
#          logging.error(f"Error in document processing: {e}", exc_info=True)
#          return None
#
#  # Run the debugging function
#  result = debug_document_processing()
#
#
# This approach will:
#
#  1 Add extensive logging
#  2 Print debug information to console
#  3 Log detailed error information
#  4 Help identify where the summarization process might be failing
#
# Run this script and share the output. This will help us understand exactly why the summary is not being generated.
#
# Would you like me to help you interpret the results?

# %%
 import os
 import logging

 # Configure logging to see more details
 logging.basicConfig(level=logging.DEBUG)

 # Import the agent
 from agent_script import setup_document_processing_agent

 # Create the agent
 agent = setup_document_processing_agent()

 # Process a file
 file_path = "/content/files/_Agent_04_Tool_Design_Best_Practices.txt"

 # Read the file
 with open(file_path, 'r', encoding='utf-8') as file:
     document_text = file.read()

 # Print document length for verification
 print("Document Length:", len(document_text))
 print("First 200 characters:", document_text[:200])

 # Process the document
 result = agent.process_document(document_text)

 # Detailed debugging
 print("\n--- Debugging Information ---")
 print("Summary Drafts:", result.summary_drafts)
 print("Extracted Concepts:", result.extracted_concepts)
 print("Processing Time:", result.document_metadata.get('total_processing_time'))

 # Check each tool's execution
 print("\n--- Tool Execution Logs ---")
 # You might want to add more logging in your agent_script.py to capture tool execution details
# Out:
# Document Length: 1127
# First 200 characters:
# ## **Chapter 4: Tool Design Best Practices**
#
# ### Concept Summary
#
# Tools are the **hands of your agent** — the way it interacts with the world. Good design makes the difference between fragile hacks
#
# --- Debugging Information ---
# Summary Drafts: []
# Extracted Concepts: []
# Processing Time: 5.8650970458984375e-05
#
# --- Tool Execution Logs ---

# %%
 import os
 import logging

 # Configure logging to see more details
 logging.basicConfig(level=logging.DEBUG)

 # Import the agent
 from agent_script import setup_document_processing_agent

 # Create the agent
 agent = setup_document_processing_agent()

 # Process a file
 file_path = "/content/files/_Agent_04_Tool_Design_Best_Practices.txt"

 # Read the file
 with open(file_path, 'r', encoding='utf-8') as file:
     document_text = file.read()

 # Process the document
 result = agent.process_document(document_text)

 # Display results
 print("Summary:", result.summary_drafts)
 print("Processing Time:", result.document_metadata.get('total_processing_time'))
 print("Extracted Concepts:", result.extracted_concepts)
# Out:
# Summary: []
# Processing Time: 5.364418029785156e-05
# Extracted Concepts: []

# %%
# Import specific components
from agent_script import (
    setup_document_processing_agent,
    DocumentProcessingContext
)

# Create the agent
agent = setup_document_processing_agent()

# Define your document
sample_document = """
Your text document goes here. This could be a long piece of text
that you want to process and summarize.
"""

# Process the document
result = agent.process_document(sample_document)

# Access different parts of the result
print("Summary:", result.summary_drafts)
print("Metadata:", result.document_metadata)
print("Extracted Concepts:", result.extracted_concepts)
# Out:
# Summary: []
# Metadata: {'start_time': 1757108917.048882, 'end_time': 1757108917.0489202, 'total_processing_time': 3.814697265625e-05}
# Extracted Concepts: []

# %%
 import os

 # Import the agent
 from agent_script import setup_document_processing_agent

 # Create the agent
 agent = setup_document_processing_agent()

 # Directory containing documents
 document_dir = "/content/files/"

 # Process all text files in the directory
 results = {}
 for filename in os.listdir(document_dir):
     if filename.endswith('.txt'):
         file_path = os.path.join(document_dir, filename)

         # Read the file
         with open(file_path, 'r', encoding='utf-8') as file:
             document_text = file.read()

         # Process the document
         result = agent.process_document(document_text)

         # Store results
         results[filename] = result

 # Analyze results
 for filename, result in results.items():
     print(f"\nFile: {filename}")
     print("Summary:", result.summary_drafts)
     print("Processing Time:", result.document_metadata.get('total_processing_time'))
# Out:
# File: _Agent_04_Tool_Design_Best_Practices.txt
# Summary: []
# Processing Time: 4.9114227294921875e-05
#
# File: _Agent_05_GAME_Framework.txt
# Summary: []
# Processing Time: 8.726119995117188e-05
#
# File: _Agent_06_Modular_Agent_Design.txt
# Summary: []
# Processing Time: 1.049041748046875e-05
